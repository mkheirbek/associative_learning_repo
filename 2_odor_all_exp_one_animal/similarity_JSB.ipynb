# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
# all modules necessary for this nb
import os
import sys
import pickle

import numpy as np
import pylab as pl

# setting parameters for default matplotlib plots
# %matplotlib inline

# %%
pl.style.use('fabiostyle')

# needs to find the library of functions
sys.path.append('../../../code/')  # to be replaced!

import utils as ut
import plots as pt

# %%
NOTEBOOK_NAME = 'similarity_JSB'

# %%
from pickleshare import PickleShareDB

autorestore_folder = os.path.join(os.getcwd(), 'autorestore', NOTEBOOK_NAME)
db = PickleShareDB(autorestore_folder)
import sys
from workspace import *
import IPython
ip = IPython.get_ipython()

# this will restore all the saved variables. ignore the errors listed.
#load_workspace(ip, db)

# use `save_worspace(db)` to save variables at the end

# %%
for session in '2_odor_expo','pre', 'post', 'ext1', 'ext2', 'renew':
    exec('vars_%s = {}'%session)
    folder = '../%s/notebooks/autorestore/preprocessing/'%session
    for var in ('time_ax', 'events', 'cycles', 'CYCLE_START', 'CS_DURATION', 'DELAY',
                'is_rewardt', 'is_CSmt'):
        eval('vars_%s'%session).update({var:ut.load_variable(var, folder=folder)})
    eval('vars_%s'%session).update({'selectivity':ut.load_variable('selectivity',
                                    '../%s/notebooks/autorestore/selectivity_JSB/'%session)})

# %%
vars_expo = {}
folder = '../2_odor_expo/notebooks/autorestore/preprocessing/'
for var in ('time_ax', 'events', 'cycles', 'CYCLE_START', 'CS_DURATION', 'DELAY',
                'is_rewardt', 'is_CSmt'):
    vars_expo.update({var:ut.load_variable(var, folder=folder)})
vars_expo.update({'selectivity':ut.load_variable('selectivity',
                                    '../2_odor_expo/notebooks/autorestore/selectivity_JSB/')})

# %%
sessions = 'expo', 'pre', 'post', 'ext1', 'ext2', 'renew'
for session in sessions:
    for k, v in eval('vars_%s'%session).iteritems():
        exec('%s = vars_%s[\'%s\']'%(k, session, k))

#    baseline = 4

    for odor in ['rewardt', 'CSmt']:
        for csus in ['cs', 'tr', 'cstr', 'us',]:
            tshift = CS_DURATION+DELAY if csus=='us' else CS_DURATION if csus=='tr' else 0
            exec("patterns_%s_%s_%s = np.r_[ut.compute_mean_activity_patterns(time_ax, events, cycles[is_%s],\
                  (-CYCLE_START+%f, -CYCLE_START+CS_DURATION+%f))]"%(odor, session, csus, odor, tshift, tshift))
#     exec("patterns_bs_%s = np.r_[ut.compute_mean_activity_patterns(time_ax, events, cycles,\
#                                  (-CYCLE_START+baseline, -CYCLE_START+CS_DURATION+baseline))]"%session)

# %%
from itertools import product

# %%
def scalar_prod(u, v):
    return u.dot(v)/np.sqrt(u.dot(u)*v.dot(v))

odors = 'CSmt', 'rewardt'
pattern_ids = ['%s-%s-%s'%(session, odor, csus) for session, odor, csus in product(sessions, odors, ['cs', 'tr', 'cstr', 'us'])]
all_patterns = [eval('patterns_%s_%s_%s'%(odor, session, csus))
                for session, odor, csus in product(sessions, odors, ['cs', 'tr', 'cstr', 'us'])]
corrmat_distr, corrmat = ut.compute_similarity_matrix(pattern_ids, all_patterns)
# Out:
# Cannot compute similarity between expo-CSmt-cs and pre-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cs and pre-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cs and pre-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cs and pre-CSmt-us.
# Cannot compute similarity between expo-CSmt-cs and pre-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cs and pre-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cs and pre-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cs and pre-rewardt-us.
# Cannot compute similarity between expo-CSmt-cs and post-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cs and post-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cs and post-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cs and post-CSmt-us.
# Cannot compute similarity between expo-CSmt-cs and post-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cs and post-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cs and post-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cs and post-rewardt-us.
# Cannot compute similarity between expo-CSmt-cs and ext1-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cs and ext1-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cs and ext1-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cs and ext1-CSmt-us.
# Cannot compute similarity between expo-CSmt-cs and ext1-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cs and ext1-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cs and ext1-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cs and ext1-rewardt-us.
# Cannot compute similarity between expo-CSmt-cs and ext2-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cs and ext2-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cs and ext2-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cs and ext2-CSmt-us.
# Cannot compute similarity between expo-CSmt-cs and ext2-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cs and ext2-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cs and ext2-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cs and ext2-rewardt-us.
# Cannot compute similarity between expo-CSmt-cs and renew-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cs and renew-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cs and renew-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cs and renew-CSmt-us.
# Cannot compute similarity between expo-CSmt-cs and renew-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cs and renew-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cs and renew-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cs and renew-rewardt-us.
# Cannot compute similarity between expo-CSmt-tr and pre-CSmt-cs.
# Cannot compute similarity between expo-CSmt-tr and pre-CSmt-tr.
# Cannot compute similarity between expo-CSmt-tr and pre-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-tr and pre-CSmt-us.
# Cannot compute similarity between expo-CSmt-tr and pre-rewardt-cs.
# Cannot compute similarity between expo-CSmt-tr and pre-rewardt-tr.
# Cannot compute similarity between expo-CSmt-tr and pre-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-tr and pre-rewardt-us.
# Cannot compute similarity between expo-CSmt-tr and post-CSmt-cs.
# Cannot compute similarity between expo-CSmt-tr and post-CSmt-tr.
# Cannot compute similarity between expo-CSmt-tr and post-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-tr and post-CSmt-us.
# Cannot compute similarity between expo-CSmt-tr and post-rewardt-cs.
# Cannot compute similarity between expo-CSmt-tr and post-rewardt-tr.
# Cannot compute similarity between expo-CSmt-tr and post-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-tr and post-rewardt-us.
# Cannot compute similarity between expo-CSmt-tr and ext1-CSmt-cs.
# Cannot compute similarity between expo-CSmt-tr and ext1-CSmt-tr.
# Cannot compute similarity between expo-CSmt-tr and ext1-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-tr and ext1-CSmt-us.
# Cannot compute similarity between expo-CSmt-tr and ext1-rewardt-cs.
# Cannot compute similarity between expo-CSmt-tr and ext1-rewardt-tr.
# Cannot compute similarity between expo-CSmt-tr and ext1-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-tr and ext1-rewardt-us.
# Cannot compute similarity between expo-CSmt-tr and ext2-CSmt-cs.
# Cannot compute similarity between expo-CSmt-tr and ext2-CSmt-tr.
# Cannot compute similarity between expo-CSmt-tr and ext2-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-tr and ext2-CSmt-us.
# Cannot compute similarity between expo-CSmt-tr and ext2-rewardt-cs.
# Cannot compute similarity between expo-CSmt-tr and ext2-rewardt-tr.
# Cannot compute similarity between expo-CSmt-tr and ext2-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-tr and ext2-rewardt-us.
# Cannot compute similarity between expo-CSmt-tr and renew-CSmt-cs.
# Cannot compute similarity between expo-CSmt-tr and renew-CSmt-tr.
# Cannot compute similarity between expo-CSmt-tr and renew-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-tr and renew-CSmt-us.
# Cannot compute similarity between expo-CSmt-tr and renew-rewardt-cs.
# Cannot compute similarity between expo-CSmt-tr and renew-rewardt-tr.
# Cannot compute similarity between expo-CSmt-tr and renew-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-tr and renew-rewardt-us.
# Cannot compute similarity between expo-CSmt-cstr and pre-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cstr and pre-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cstr and pre-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and pre-CSmt-us.
# Cannot compute similarity between expo-CSmt-cstr and pre-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cstr and pre-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cstr and pre-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and pre-rewardt-us.
# Cannot compute similarity between expo-CSmt-cstr and post-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cstr and post-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cstr and post-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and post-CSmt-us.
# Cannot compute similarity between expo-CSmt-cstr and post-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cstr and post-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cstr and post-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and post-rewardt-us.
# Cannot compute similarity between expo-CSmt-cstr and ext1-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cstr and ext1-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cstr and ext1-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and ext1-CSmt-us.
# Cannot compute similarity between expo-CSmt-cstr and ext1-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cstr and ext1-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cstr and ext1-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and ext1-rewardt-us.
# Cannot compute similarity between expo-CSmt-cstr and ext2-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cstr and ext2-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cstr and ext2-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and ext2-CSmt-us.
# Cannot compute similarity between expo-CSmt-cstr and ext2-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cstr and ext2-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cstr and ext2-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and ext2-rewardt-us.
# Cannot compute similarity between expo-CSmt-cstr and renew-CSmt-cs.
# Cannot compute similarity between expo-CSmt-cstr and renew-CSmt-tr.
# Cannot compute similarity between expo-CSmt-cstr and renew-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and renew-CSmt-us.
# Cannot compute similarity between expo-CSmt-cstr and renew-rewardt-cs.
# Cannot compute similarity between expo-CSmt-cstr and renew-rewardt-tr.
# Cannot compute similarity between expo-CSmt-cstr and renew-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-cstr and renew-rewardt-us.
# Cannot compute similarity between expo-CSmt-us and pre-CSmt-cs.
# Cannot compute similarity between expo-CSmt-us and pre-CSmt-tr.
# Cannot compute similarity between expo-CSmt-us and pre-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-us and pre-CSmt-us.
# Cannot compute similarity between expo-CSmt-us and pre-rewardt-cs.
# Cannot compute similarity between expo-CSmt-us and pre-rewardt-tr.
# Cannot compute similarity between expo-CSmt-us and pre-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-us and pre-rewardt-us.
# Cannot compute similarity between expo-CSmt-us and post-CSmt-cs.
# Cannot compute similarity between expo-CSmt-us and post-CSmt-tr.
# Cannot compute similarity between expo-CSmt-us and post-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-us and post-CSmt-us.
# Cannot compute similarity between expo-CSmt-us and post-rewardt-cs.
# Cannot compute similarity between expo-CSmt-us and post-rewardt-tr.
# Cannot compute similarity between expo-CSmt-us and post-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-us and post-rewardt-us.
# Cannot compute similarity between expo-CSmt-us and ext1-CSmt-cs.
# Cannot compute similarity between expo-CSmt-us and ext1-CSmt-tr.
# Cannot compute similarity between expo-CSmt-us and ext1-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-us and ext1-CSmt-us.
# Cannot compute similarity between expo-CSmt-us and ext1-rewardt-cs.
# Cannot compute similarity between expo-CSmt-us and ext1-rewardt-tr.
# Cannot compute similarity between expo-CSmt-us and ext1-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-us and ext1-rewardt-us.
# Cannot compute similarity between expo-CSmt-us and ext2-CSmt-cs.
# Cannot compute similarity between expo-CSmt-us and ext2-CSmt-tr.
# Cannot compute similarity between expo-CSmt-us and ext2-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-us and ext2-CSmt-us.
# Cannot compute similarity between expo-CSmt-us and ext2-rewardt-cs.
# Cannot compute similarity between expo-CSmt-us and ext2-rewardt-tr.
# Cannot compute similarity between expo-CSmt-us and ext2-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-us and ext2-rewardt-us.
# Cannot compute similarity between expo-CSmt-us and renew-CSmt-cs.
# Cannot compute similarity between expo-CSmt-us and renew-CSmt-tr.
# Cannot compute similarity between expo-CSmt-us and renew-CSmt-cstr.
# Cannot compute similarity between expo-CSmt-us and renew-CSmt-us.
# Cannot compute similarity between expo-CSmt-us and renew-rewardt-cs.
# Cannot compute similarity between expo-CSmt-us and renew-rewardt-tr.
# Cannot compute similarity between expo-CSmt-us and renew-rewardt-cstr.
# Cannot compute similarity between expo-CSmt-us and renew-rewardt-us.
# Cannot compute similarity between expo-rewardt-cs and pre-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cs and pre-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cs and pre-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cs and pre-CSmt-us.
# Cannot compute similarity between expo-rewardt-cs and pre-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cs and pre-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cs and pre-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cs and pre-rewardt-us.
# Cannot compute similarity between expo-rewardt-cs and post-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cs and post-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cs and post-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cs and post-CSmt-us.
# Cannot compute similarity between expo-rewardt-cs and post-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cs and post-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cs and post-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cs and post-rewardt-us.
# Cannot compute similarity between expo-rewardt-cs and ext1-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cs and ext1-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cs and ext1-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cs and ext1-CSmt-us.
# Cannot compute similarity between expo-rewardt-cs and ext1-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cs and ext1-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cs and ext1-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cs and ext1-rewardt-us.
# Cannot compute similarity between expo-rewardt-cs and ext2-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cs and ext2-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cs and ext2-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cs and ext2-CSmt-us.
# Cannot compute similarity between expo-rewardt-cs and ext2-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cs and ext2-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cs and ext2-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cs and ext2-rewardt-us.
# Cannot compute similarity between expo-rewardt-cs and renew-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cs and renew-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cs and renew-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cs and renew-CSmt-us.
# Cannot compute similarity between expo-rewardt-cs and renew-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cs and renew-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cs and renew-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cs and renew-rewardt-us.
# Cannot compute similarity between expo-rewardt-tr and pre-CSmt-cs.
# Cannot compute similarity between expo-rewardt-tr and pre-CSmt-tr.
# Cannot compute similarity between expo-rewardt-tr and pre-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-tr and pre-CSmt-us.
# Cannot compute similarity between expo-rewardt-tr and pre-rewardt-cs.
# Cannot compute similarity between expo-rewardt-tr and pre-rewardt-tr.
# Cannot compute similarity between expo-rewardt-tr and pre-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-tr and pre-rewardt-us.
# Cannot compute similarity between expo-rewardt-tr and post-CSmt-cs.
# Cannot compute similarity between expo-rewardt-tr and post-CSmt-tr.
# Cannot compute similarity between expo-rewardt-tr and post-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-tr and post-CSmt-us.
# Cannot compute similarity between expo-rewardt-tr and post-rewardt-cs.
# Cannot compute similarity between expo-rewardt-tr and post-rewardt-tr.
# Cannot compute similarity between expo-rewardt-tr and post-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-tr and post-rewardt-us.
# Cannot compute similarity between expo-rewardt-tr and ext1-CSmt-cs.
# Cannot compute similarity between expo-rewardt-tr and ext1-CSmt-tr.
# Cannot compute similarity between expo-rewardt-tr and ext1-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-tr and ext1-CSmt-us.
# Cannot compute similarity between expo-rewardt-tr and ext1-rewardt-cs.
# Cannot compute similarity between expo-rewardt-tr and ext1-rewardt-tr.
# Cannot compute similarity between expo-rewardt-tr and ext1-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-tr and ext1-rewardt-us.
# Cannot compute similarity between expo-rewardt-tr and ext2-CSmt-cs.
# Cannot compute similarity between expo-rewardt-tr and ext2-CSmt-tr.
# Cannot compute similarity between expo-rewardt-tr and ext2-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-tr and ext2-CSmt-us.
# Cannot compute similarity between expo-rewardt-tr and ext2-rewardt-cs.
# Cannot compute similarity between expo-rewardt-tr and ext2-rewardt-tr.
# Cannot compute similarity between expo-rewardt-tr and ext2-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-tr and ext2-rewardt-us.
# Cannot compute similarity between expo-rewardt-tr and renew-CSmt-cs.
# Cannot compute similarity between expo-rewardt-tr and renew-CSmt-tr.
# Cannot compute similarity between expo-rewardt-tr and renew-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-tr and renew-CSmt-us.
# Cannot compute similarity between expo-rewardt-tr and renew-rewardt-cs.
# Cannot compute similarity between expo-rewardt-tr and renew-rewardt-tr.
# Cannot compute similarity between expo-rewardt-tr and renew-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-tr and renew-rewardt-us.
# Cannot compute similarity between expo-rewardt-cstr and pre-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cstr and pre-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cstr and pre-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and pre-CSmt-us.
# Cannot compute similarity between expo-rewardt-cstr and pre-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cstr and pre-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cstr and pre-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and pre-rewardt-us.
# Cannot compute similarity between expo-rewardt-cstr and post-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cstr and post-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cstr and post-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and post-CSmt-us.
# Cannot compute similarity between expo-rewardt-cstr and post-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cstr and post-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cstr and post-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and post-rewardt-us.
# Cannot compute similarity between expo-rewardt-cstr and ext1-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cstr and ext1-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cstr and ext1-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and ext1-CSmt-us.
# Cannot compute similarity between expo-rewardt-cstr and ext1-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cstr and ext1-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cstr and ext1-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and ext1-rewardt-us.
# Cannot compute similarity between expo-rewardt-cstr and ext2-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cstr and ext2-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cstr and ext2-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and ext2-CSmt-us.
# Cannot compute similarity between expo-rewardt-cstr and ext2-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cstr and ext2-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cstr and ext2-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and ext2-rewardt-us.
# Cannot compute similarity between expo-rewardt-cstr and renew-CSmt-cs.
# Cannot compute similarity between expo-rewardt-cstr and renew-CSmt-tr.
# Cannot compute similarity between expo-rewardt-cstr and renew-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and renew-CSmt-us.
# Cannot compute similarity between expo-rewardt-cstr and renew-rewardt-cs.
# Cannot compute similarity between expo-rewardt-cstr and renew-rewardt-tr.
# Cannot compute similarity between expo-rewardt-cstr and renew-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-cstr and renew-rewardt-us.
# Cannot compute similarity between expo-rewardt-us and pre-CSmt-cs.
# Cannot compute similarity between expo-rewardt-us and pre-CSmt-tr.
# Cannot compute similarity between expo-rewardt-us and pre-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-us and pre-CSmt-us.
# Cannot compute similarity between expo-rewardt-us and pre-rewardt-cs.
# Cannot compute similarity between expo-rewardt-us and pre-rewardt-tr.
# Cannot compute similarity between expo-rewardt-us and pre-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-us and pre-rewardt-us.
# Cannot compute similarity between expo-rewardt-us and post-CSmt-cs.
# Cannot compute similarity between expo-rewardt-us and post-CSmt-tr.
# Cannot compute similarity between expo-rewardt-us and post-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-us and post-CSmt-us.
# Cannot compute similarity between expo-rewardt-us and post-rewardt-cs.
# Cannot compute similarity between expo-rewardt-us and post-rewardt-tr.
# Cannot compute similarity between expo-rewardt-us and post-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-us and post-rewardt-us.
# Cannot compute similarity between expo-rewardt-us and ext1-CSmt-cs.
# Cannot compute similarity between expo-rewardt-us and ext1-CSmt-tr.
# Cannot compute similarity between expo-rewardt-us and ext1-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-us and ext1-CSmt-us.
# Cannot compute similarity between expo-rewardt-us and ext1-rewardt-cs.
# Cannot compute similarity between expo-rewardt-us and ext1-rewardt-tr.
# Cannot compute similarity between expo-rewardt-us and ext1-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-us and ext1-rewardt-us.
# Cannot compute similarity between expo-rewardt-us and ext2-CSmt-cs.
# Cannot compute similarity between expo-rewardt-us and ext2-CSmt-tr.
# Cannot compute similarity between expo-rewardt-us and ext2-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-us and ext2-CSmt-us.
# Cannot compute similarity between expo-rewardt-us and ext2-rewardt-cs.
# Cannot compute similarity between expo-rewardt-us and ext2-rewardt-tr.
# Cannot compute similarity between expo-rewardt-us and ext2-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-us and ext2-rewardt-us.
# Cannot compute similarity between expo-rewardt-us and renew-CSmt-cs.
# Cannot compute similarity between expo-rewardt-us and renew-CSmt-tr.
# Cannot compute similarity between expo-rewardt-us and renew-CSmt-cstr.
# Cannot compute similarity between expo-rewardt-us and renew-CSmt-us.
# Cannot compute similarity between expo-rewardt-us and renew-rewardt-cs.
# Cannot compute similarity between expo-rewardt-us and renew-rewardt-tr.
# Cannot compute similarity between expo-rewardt-us and renew-rewardt-cstr.
# Cannot compute similarity between expo-rewardt-us and renew-rewardt-us.
# Cannot compute similarity between pre-CSmt-cs and expo-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cs and expo-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cs and expo-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cs and expo-CSmt-us.
# Cannot compute similarity between pre-CSmt-cs and expo-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cs and expo-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cs and expo-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cs and expo-rewardt-us.
# Cannot compute similarity between pre-CSmt-cs and post-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cs and post-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cs and post-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cs and post-CSmt-us.
# Cannot compute similarity between pre-CSmt-cs and post-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cs and post-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cs and post-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cs and post-rewardt-us.
# Cannot compute similarity between pre-CSmt-cs and ext1-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cs and ext1-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cs and ext1-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cs and ext1-CSmt-us.
# Cannot compute similarity between pre-CSmt-cs and ext1-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cs and ext1-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cs and ext1-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cs and ext1-rewardt-us.
# Cannot compute similarity between pre-CSmt-cs and ext2-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cs and ext2-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cs and ext2-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cs and ext2-CSmt-us.
# Cannot compute similarity between pre-CSmt-cs and ext2-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cs and ext2-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cs and ext2-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cs and ext2-rewardt-us.
# Cannot compute similarity between pre-CSmt-cs and renew-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cs and renew-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cs and renew-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cs and renew-CSmt-us.
# Cannot compute similarity between pre-CSmt-cs and renew-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cs and renew-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cs and renew-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cs and renew-rewardt-us.
# Cannot compute similarity between pre-CSmt-tr and expo-CSmt-cs.
# Cannot compute similarity between pre-CSmt-tr and expo-CSmt-tr.
# Cannot compute similarity between pre-CSmt-tr and expo-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-tr and expo-CSmt-us.
# Cannot compute similarity between pre-CSmt-tr and expo-rewardt-cs.
# Cannot compute similarity between pre-CSmt-tr and expo-rewardt-tr.
# Cannot compute similarity between pre-CSmt-tr and expo-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-tr and expo-rewardt-us.
# Cannot compute similarity between pre-CSmt-tr and post-CSmt-cs.
# Cannot compute similarity between pre-CSmt-tr and post-CSmt-tr.
# Cannot compute similarity between pre-CSmt-tr and post-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-tr and post-CSmt-us.
# Cannot compute similarity between pre-CSmt-tr and post-rewardt-cs.
# Cannot compute similarity between pre-CSmt-tr and post-rewardt-tr.
# Cannot compute similarity between pre-CSmt-tr and post-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-tr and post-rewardt-us.
# Cannot compute similarity between pre-CSmt-tr and ext1-CSmt-cs.
# Cannot compute similarity between pre-CSmt-tr and ext1-CSmt-tr.
# Cannot compute similarity between pre-CSmt-tr and ext1-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-tr and ext1-CSmt-us.
# Cannot compute similarity between pre-CSmt-tr and ext1-rewardt-cs.
# Cannot compute similarity between pre-CSmt-tr and ext1-rewardt-tr.
# Cannot compute similarity between pre-CSmt-tr and ext1-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-tr and ext1-rewardt-us.
# Cannot compute similarity between pre-CSmt-tr and ext2-CSmt-cs.
# Cannot compute similarity between pre-CSmt-tr and ext2-CSmt-tr.
# Cannot compute similarity between pre-CSmt-tr and ext2-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-tr and ext2-CSmt-us.
# Cannot compute similarity between pre-CSmt-tr and ext2-rewardt-cs.
# Cannot compute similarity between pre-CSmt-tr and ext2-rewardt-tr.
# Cannot compute similarity between pre-CSmt-tr and ext2-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-tr and ext2-rewardt-us.
# Cannot compute similarity between pre-CSmt-tr and renew-CSmt-cs.
# Cannot compute similarity between pre-CSmt-tr and renew-CSmt-tr.
# Cannot compute similarity between pre-CSmt-tr and renew-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-tr and renew-CSmt-us.
# Cannot compute similarity between pre-CSmt-tr and renew-rewardt-cs.
# Cannot compute similarity between pre-CSmt-tr and renew-rewardt-tr.
# Cannot compute similarity between pre-CSmt-tr and renew-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-tr and renew-rewardt-us.
# Cannot compute similarity between pre-CSmt-cstr and expo-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cstr and expo-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cstr and expo-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and expo-CSmt-us.
# Cannot compute similarity between pre-CSmt-cstr and expo-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cstr and expo-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cstr and expo-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and expo-rewardt-us.
# Cannot compute similarity between pre-CSmt-cstr and post-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cstr and post-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cstr and post-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and post-CSmt-us.
# Cannot compute similarity between pre-CSmt-cstr and post-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cstr and post-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cstr and post-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and post-rewardt-us.
# Cannot compute similarity between pre-CSmt-cstr and ext1-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cstr and ext1-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cstr and ext1-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and ext1-CSmt-us.
# Cannot compute similarity between pre-CSmt-cstr and ext1-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cstr and ext1-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cstr and ext1-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and ext1-rewardt-us.
# Cannot compute similarity between pre-CSmt-cstr and ext2-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cstr and ext2-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cstr and ext2-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and ext2-CSmt-us.
# Cannot compute similarity between pre-CSmt-cstr and ext2-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cstr and ext2-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cstr and ext2-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and ext2-rewardt-us.
# Cannot compute similarity between pre-CSmt-cstr and renew-CSmt-cs.
# Cannot compute similarity between pre-CSmt-cstr and renew-CSmt-tr.
# Cannot compute similarity between pre-CSmt-cstr and renew-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and renew-CSmt-us.
# Cannot compute similarity between pre-CSmt-cstr and renew-rewardt-cs.
# Cannot compute similarity between pre-CSmt-cstr and renew-rewardt-tr.
# Cannot compute similarity between pre-CSmt-cstr and renew-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-cstr and renew-rewardt-us.
# Cannot compute similarity between pre-CSmt-us and expo-CSmt-cs.
# Cannot compute similarity between pre-CSmt-us and expo-CSmt-tr.
# Cannot compute similarity between pre-CSmt-us and expo-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-us and expo-CSmt-us.
# Cannot compute similarity between pre-CSmt-us and expo-rewardt-cs.
# Cannot compute similarity between pre-CSmt-us and expo-rewardt-tr.
# Cannot compute similarity between pre-CSmt-us and expo-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-us and expo-rewardt-us.
# Cannot compute similarity between pre-CSmt-us and post-CSmt-cs.
# Cannot compute similarity between pre-CSmt-us and post-CSmt-tr.
# Cannot compute similarity between pre-CSmt-us and post-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-us and post-CSmt-us.
# Cannot compute similarity between pre-CSmt-us and post-rewardt-cs.
# Cannot compute similarity between pre-CSmt-us and post-rewardt-tr.
# Cannot compute similarity between pre-CSmt-us and post-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-us and post-rewardt-us.
# Cannot compute similarity between pre-CSmt-us and ext1-CSmt-cs.
# Cannot compute similarity between pre-CSmt-us and ext1-CSmt-tr.
# Cannot compute similarity between pre-CSmt-us and ext1-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-us and ext1-CSmt-us.
# Cannot compute similarity between pre-CSmt-us and ext1-rewardt-cs.
# Cannot compute similarity between pre-CSmt-us and ext1-rewardt-tr.
# Cannot compute similarity between pre-CSmt-us and ext1-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-us and ext1-rewardt-us.
# Cannot compute similarity between pre-CSmt-us and ext2-CSmt-cs.
# Cannot compute similarity between pre-CSmt-us and ext2-CSmt-tr.
# Cannot compute similarity between pre-CSmt-us and ext2-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-us and ext2-CSmt-us.
# Cannot compute similarity between pre-CSmt-us and ext2-rewardt-cs.
# Cannot compute similarity between pre-CSmt-us and ext2-rewardt-tr.
# Cannot compute similarity between pre-CSmt-us and ext2-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-us and ext2-rewardt-us.
# Cannot compute similarity between pre-CSmt-us and renew-CSmt-cs.
# Cannot compute similarity between pre-CSmt-us and renew-CSmt-tr.
# Cannot compute similarity between pre-CSmt-us and renew-CSmt-cstr.
# Cannot compute similarity between pre-CSmt-us and renew-CSmt-us.
# Cannot compute similarity between pre-CSmt-us and renew-rewardt-cs.
# Cannot compute similarity between pre-CSmt-us and renew-rewardt-tr.
# Cannot compute similarity between pre-CSmt-us and renew-rewardt-cstr.
# Cannot compute similarity between pre-CSmt-us and renew-rewardt-us.
# Cannot compute similarity between pre-rewardt-cs and expo-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cs and expo-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cs and expo-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cs and expo-CSmt-us.
# Cannot compute similarity between pre-rewardt-cs and expo-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cs and expo-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cs and expo-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cs and expo-rewardt-us.
# Cannot compute similarity between pre-rewardt-cs and post-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cs and post-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cs and post-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cs and post-CSmt-us.
# Cannot compute similarity between pre-rewardt-cs and post-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cs and post-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cs and post-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cs and post-rewardt-us.
# Cannot compute similarity between pre-rewardt-cs and ext1-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cs and ext1-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cs and ext1-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cs and ext1-CSmt-us.
# Cannot compute similarity between pre-rewardt-cs and ext1-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cs and ext1-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cs and ext1-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cs and ext1-rewardt-us.
# Cannot compute similarity between pre-rewardt-cs and ext2-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cs and ext2-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cs and ext2-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cs and ext2-CSmt-us.
# Cannot compute similarity between pre-rewardt-cs and ext2-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cs and ext2-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cs and ext2-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cs and ext2-rewardt-us.
# Cannot compute similarity between pre-rewardt-cs and renew-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cs and renew-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cs and renew-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cs and renew-CSmt-us.
# Cannot compute similarity between pre-rewardt-cs and renew-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cs and renew-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cs and renew-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cs and renew-rewardt-us.
# Cannot compute similarity between pre-rewardt-tr and expo-CSmt-cs.
# Cannot compute similarity between pre-rewardt-tr and expo-CSmt-tr.
# Cannot compute similarity between pre-rewardt-tr and expo-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-tr and expo-CSmt-us.
# Cannot compute similarity between pre-rewardt-tr and expo-rewardt-cs.
# Cannot compute similarity between pre-rewardt-tr and expo-rewardt-tr.
# Cannot compute similarity between pre-rewardt-tr and expo-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-tr and expo-rewardt-us.
# Cannot compute similarity between pre-rewardt-tr and post-CSmt-cs.
# Cannot compute similarity between pre-rewardt-tr and post-CSmt-tr.
# Cannot compute similarity between pre-rewardt-tr and post-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-tr and post-CSmt-us.
# Cannot compute similarity between pre-rewardt-tr and post-rewardt-cs.
# Cannot compute similarity between pre-rewardt-tr and post-rewardt-tr.
# Cannot compute similarity between pre-rewardt-tr and post-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-tr and post-rewardt-us.
# Cannot compute similarity between pre-rewardt-tr and ext1-CSmt-cs.
# Cannot compute similarity between pre-rewardt-tr and ext1-CSmt-tr.
# Cannot compute similarity between pre-rewardt-tr and ext1-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-tr and ext1-CSmt-us.
# Cannot compute similarity between pre-rewardt-tr and ext1-rewardt-cs.
# Cannot compute similarity between pre-rewardt-tr and ext1-rewardt-tr.
# Cannot compute similarity between pre-rewardt-tr and ext1-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-tr and ext1-rewardt-us.
# Cannot compute similarity between pre-rewardt-tr and ext2-CSmt-cs.
# Cannot compute similarity between pre-rewardt-tr and ext2-CSmt-tr.
# Cannot compute similarity between pre-rewardt-tr and ext2-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-tr and ext2-CSmt-us.
# Cannot compute similarity between pre-rewardt-tr and ext2-rewardt-cs.
# Cannot compute similarity between pre-rewardt-tr and ext2-rewardt-tr.
# Cannot compute similarity between pre-rewardt-tr and ext2-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-tr and ext2-rewardt-us.
# Cannot compute similarity between pre-rewardt-tr and renew-CSmt-cs.
# Cannot compute similarity between pre-rewardt-tr and renew-CSmt-tr.
# Cannot compute similarity between pre-rewardt-tr and renew-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-tr and renew-CSmt-us.
# Cannot compute similarity between pre-rewardt-tr and renew-rewardt-cs.
# Cannot compute similarity between pre-rewardt-tr and renew-rewardt-tr.
# Cannot compute similarity between pre-rewardt-tr and renew-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-tr and renew-rewardt-us.
# Cannot compute similarity between pre-rewardt-cstr and expo-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cstr and expo-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cstr and expo-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and expo-CSmt-us.
# Cannot compute similarity between pre-rewardt-cstr and expo-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cstr and expo-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cstr and expo-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and expo-rewardt-us.
# Cannot compute similarity between pre-rewardt-cstr and post-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cstr and post-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cstr and post-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and post-CSmt-us.
# Cannot compute similarity between pre-rewardt-cstr and post-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cstr and post-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cstr and post-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and post-rewardt-us.
# Cannot compute similarity between pre-rewardt-cstr and ext1-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cstr and ext1-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cstr and ext1-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and ext1-CSmt-us.
# Cannot compute similarity between pre-rewardt-cstr and ext1-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cstr and ext1-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cstr and ext1-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and ext1-rewardt-us.
# Cannot compute similarity between pre-rewardt-cstr and ext2-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cstr and ext2-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cstr and ext2-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and ext2-CSmt-us.
# Cannot compute similarity between pre-rewardt-cstr and ext2-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cstr and ext2-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cstr and ext2-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and ext2-rewardt-us.
# Cannot compute similarity between pre-rewardt-cstr and renew-CSmt-cs.
# Cannot compute similarity between pre-rewardt-cstr and renew-CSmt-tr.
# Cannot compute similarity between pre-rewardt-cstr and renew-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and renew-CSmt-us.
# Cannot compute similarity between pre-rewardt-cstr and renew-rewardt-cs.
# Cannot compute similarity between pre-rewardt-cstr and renew-rewardt-tr.
# Cannot compute similarity between pre-rewardt-cstr and renew-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-cstr and renew-rewardt-us.
# Cannot compute similarity between pre-rewardt-us and expo-CSmt-cs.
# Cannot compute similarity between pre-rewardt-us and expo-CSmt-tr.
# Cannot compute similarity between pre-rewardt-us and expo-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-us and expo-CSmt-us.
# Cannot compute similarity between pre-rewardt-us and expo-rewardt-cs.
# Cannot compute similarity between pre-rewardt-us and expo-rewardt-tr.
# Cannot compute similarity between pre-rewardt-us and expo-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-us and expo-rewardt-us.
# Cannot compute similarity between pre-rewardt-us and post-CSmt-cs.
# Cannot compute similarity between pre-rewardt-us and post-CSmt-tr.
# Cannot compute similarity between pre-rewardt-us and post-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-us and post-CSmt-us.
# Cannot compute similarity between pre-rewardt-us and post-rewardt-cs.
# Cannot compute similarity between pre-rewardt-us and post-rewardt-tr.
# Cannot compute similarity between pre-rewardt-us and post-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-us and post-rewardt-us.
# Cannot compute similarity between pre-rewardt-us and ext1-CSmt-cs.
# Cannot compute similarity between pre-rewardt-us and ext1-CSmt-tr.
# Cannot compute similarity between pre-rewardt-us and ext1-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-us and ext1-CSmt-us.
# Cannot compute similarity between pre-rewardt-us and ext1-rewardt-cs.
# Cannot compute similarity between pre-rewardt-us and ext1-rewardt-tr.
# Cannot compute similarity between pre-rewardt-us and ext1-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-us and ext1-rewardt-us.
# Cannot compute similarity between pre-rewardt-us and ext2-CSmt-cs.
# Cannot compute similarity between pre-rewardt-us and ext2-CSmt-tr.
# Cannot compute similarity between pre-rewardt-us and ext2-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-us and ext2-CSmt-us.
# Cannot compute similarity between pre-rewardt-us and ext2-rewardt-cs.
# Cannot compute similarity between pre-rewardt-us and ext2-rewardt-tr.
# Cannot compute similarity between pre-rewardt-us and ext2-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-us and ext2-rewardt-us.
# Cannot compute similarity between pre-rewardt-us and renew-CSmt-cs.
# Cannot compute similarity between pre-rewardt-us and renew-CSmt-tr.
# Cannot compute similarity between pre-rewardt-us and renew-CSmt-cstr.
# Cannot compute similarity between pre-rewardt-us and renew-CSmt-us.
# Cannot compute similarity between pre-rewardt-us and renew-rewardt-cs.
# Cannot compute similarity between pre-rewardt-us and renew-rewardt-tr.
# Cannot compute similarity between pre-rewardt-us and renew-rewardt-cstr.
# Cannot compute similarity between pre-rewardt-us and renew-rewardt-us.
# Cannot compute similarity between post-CSmt-cs and expo-CSmt-cs.
# Cannot compute similarity between post-CSmt-cs and expo-CSmt-tr.
# Cannot compute similarity between post-CSmt-cs and expo-CSmt-cstr.
# Cannot compute similarity between post-CSmt-cs and expo-CSmt-us.
# Cannot compute similarity between post-CSmt-cs and expo-rewardt-cs.
# Cannot compute similarity between post-CSmt-cs and expo-rewardt-tr.
# Cannot compute similarity between post-CSmt-cs and expo-rewardt-cstr.
# Cannot compute similarity between post-CSmt-cs and expo-rewardt-us.
# Cannot compute similarity between post-CSmt-cs and pre-CSmt-cs.
# Cannot compute similarity between post-CSmt-cs and pre-CSmt-tr.
# Cannot compute similarity between post-CSmt-cs and pre-CSmt-cstr.
# Cannot compute similarity between post-CSmt-cs and pre-CSmt-us.
# Cannot compute similarity between post-CSmt-cs and pre-rewardt-cs.
# Cannot compute similarity between post-CSmt-cs and pre-rewardt-tr.
# Cannot compute similarity between post-CSmt-cs and pre-rewardt-cstr.
# Cannot compute similarity between post-CSmt-cs and pre-rewardt-us.
# Cannot compute similarity between post-CSmt-cs and ext1-CSmt-cs.
# Cannot compute similarity between post-CSmt-cs and ext1-CSmt-tr.
# Cannot compute similarity between post-CSmt-cs and ext1-CSmt-cstr.
# Cannot compute similarity between post-CSmt-cs and ext1-CSmt-us.
# Cannot compute similarity between post-CSmt-cs and ext1-rewardt-cs.
# Cannot compute similarity between post-CSmt-cs and ext1-rewardt-tr.
# Cannot compute similarity between post-CSmt-cs and ext1-rewardt-cstr.
# Cannot compute similarity between post-CSmt-cs and ext1-rewardt-us.
# Cannot compute similarity between post-CSmt-cs and ext2-CSmt-cs.
# Cannot compute similarity between post-CSmt-cs and ext2-CSmt-tr.
# Cannot compute similarity between post-CSmt-cs and ext2-CSmt-cstr.
# Cannot compute similarity between post-CSmt-cs and ext2-CSmt-us.
# Cannot compute similarity between post-CSmt-cs and ext2-rewardt-cs.
# Cannot compute similarity between post-CSmt-cs and ext2-rewardt-tr.
# Cannot compute similarity between post-CSmt-cs and ext2-rewardt-cstr.
# Cannot compute similarity between post-CSmt-cs and ext2-rewardt-us.
# Cannot compute similarity between post-CSmt-cs and renew-CSmt-cs.
# Cannot compute similarity between post-CSmt-cs and renew-CSmt-tr.
# Cannot compute similarity between post-CSmt-cs and renew-CSmt-cstr.
# Cannot compute similarity between post-CSmt-cs and renew-CSmt-us.
# Cannot compute similarity between post-CSmt-cs and renew-rewardt-cs.
# Cannot compute similarity between post-CSmt-cs and renew-rewardt-tr.
# Cannot compute similarity between post-CSmt-cs and renew-rewardt-cstr.
# Cannot compute similarity between post-CSmt-cs and renew-rewardt-us.
# Cannot compute similarity between post-CSmt-tr and expo-CSmt-cs.
# Cannot compute similarity between post-CSmt-tr and expo-CSmt-tr.
# Cannot compute similarity between post-CSmt-tr and expo-CSmt-cstr.
# Cannot compute similarity between post-CSmt-tr and expo-CSmt-us.
# Cannot compute similarity between post-CSmt-tr and expo-rewardt-cs.
# Cannot compute similarity between post-CSmt-tr and expo-rewardt-tr.
# Cannot compute similarity between post-CSmt-tr and expo-rewardt-cstr.
# Cannot compute similarity between post-CSmt-tr and expo-rewardt-us.
# Cannot compute similarity between post-CSmt-tr and pre-CSmt-cs.
# Cannot compute similarity between post-CSmt-tr and pre-CSmt-tr.
# Cannot compute similarity between post-CSmt-tr and pre-CSmt-cstr.
# Cannot compute similarity between post-CSmt-tr and pre-CSmt-us.
# Cannot compute similarity between post-CSmt-tr and pre-rewardt-cs.
# Cannot compute similarity between post-CSmt-tr and pre-rewardt-tr.
# Cannot compute similarity between post-CSmt-tr and pre-rewardt-cstr.
# Cannot compute similarity between post-CSmt-tr and pre-rewardt-us.
# Cannot compute similarity between post-CSmt-tr and ext1-CSmt-cs.
# Cannot compute similarity between post-CSmt-tr and ext1-CSmt-tr.
# Cannot compute similarity between post-CSmt-tr and ext1-CSmt-cstr.
# Cannot compute similarity between post-CSmt-tr and ext1-CSmt-us.
# Cannot compute similarity between post-CSmt-tr and ext1-rewardt-cs.
# ...
# Cannot compute similarity between renew-CSmt-cstr and post-CSmt-cstr.
# Cannot compute similarity between renew-CSmt-cstr and post-CSmt-us.
# Cannot compute similarity between renew-CSmt-cstr and post-rewardt-cs.
# Cannot compute similarity between renew-CSmt-cstr and post-rewardt-tr.
# Cannot compute similarity between renew-CSmt-cstr and post-rewardt-cstr.
# Cannot compute similarity between renew-CSmt-cstr and post-rewardt-us.
# Cannot compute similarity between renew-CSmt-cstr and ext1-CSmt-cs.
# Cannot compute similarity between renew-CSmt-cstr and ext1-CSmt-tr.
# Cannot compute similarity between renew-CSmt-cstr and ext1-CSmt-cstr.
# Cannot compute similarity between renew-CSmt-cstr and ext1-CSmt-us.
# Cannot compute similarity between renew-CSmt-cstr and ext1-rewardt-cs.
# Cannot compute similarity between renew-CSmt-cstr and ext1-rewardt-tr.
# Cannot compute similarity between renew-CSmt-cstr and ext1-rewardt-cstr.
# Cannot compute similarity between renew-CSmt-cstr and ext1-rewardt-us.
# Cannot compute similarity between renew-CSmt-cstr and ext2-CSmt-cs.
# Cannot compute similarity between renew-CSmt-cstr and ext2-CSmt-tr.
# Cannot compute similarity between renew-CSmt-cstr and ext2-CSmt-cstr.
# Cannot compute similarity between renew-CSmt-cstr and ext2-CSmt-us.
# Cannot compute similarity between renew-CSmt-cstr and ext2-rewardt-cs.
# Cannot compute similarity between renew-CSmt-cstr and ext2-rewardt-tr.
# Cannot compute similarity between renew-CSmt-cstr and ext2-rewardt-cstr.
# Cannot compute similarity between renew-CSmt-cstr and ext2-rewardt-us.
# Cannot compute similarity between renew-CSmt-us and expo-CSmt-cs.
# Cannot compute similarity between renew-CSmt-us and expo-CSmt-tr.
# Cannot compute similarity between renew-CSmt-us and expo-CSmt-cstr.
# Cannot compute similarity between renew-CSmt-us and expo-CSmt-us.
# Cannot compute similarity between renew-CSmt-us and expo-rewardt-cs.
# Cannot compute similarity between renew-CSmt-us and expo-rewardt-tr.
# Cannot compute similarity between renew-CSmt-us and expo-rewardt-cstr.
# Cannot compute similarity between renew-CSmt-us and expo-rewardt-us.
# Cannot compute similarity between renew-CSmt-us and pre-CSmt-cs.
# Cannot compute similarity between renew-CSmt-us and pre-CSmt-tr.
# Cannot compute similarity between renew-CSmt-us and pre-CSmt-cstr.
# Cannot compute similarity between renew-CSmt-us and pre-CSmt-us.
# Cannot compute similarity between renew-CSmt-us and pre-rewardt-cs.
# Cannot compute similarity between renew-CSmt-us and pre-rewardt-tr.
# Cannot compute similarity between renew-CSmt-us and pre-rewardt-cstr.
# Cannot compute similarity between renew-CSmt-us and pre-rewardt-us.
# Cannot compute similarity between renew-CSmt-us and post-CSmt-cs.
# Cannot compute similarity between renew-CSmt-us and post-CSmt-tr.
# Cannot compute similarity between renew-CSmt-us and post-CSmt-cstr.
# Cannot compute similarity between renew-CSmt-us and post-CSmt-us.
# Cannot compute similarity between renew-CSmt-us and post-rewardt-cs.
# Cannot compute similarity between renew-CSmt-us and post-rewardt-tr.
# Cannot compute similarity between renew-CSmt-us and post-rewardt-cstr.
# Cannot compute similarity between renew-CSmt-us and post-rewardt-us.
# Cannot compute similarity between renew-CSmt-us and ext1-CSmt-cs.
# Cannot compute similarity between renew-CSmt-us and ext1-CSmt-tr.
# Cannot compute similarity between renew-CSmt-us and ext1-CSmt-cstr.
# Cannot compute similarity between renew-CSmt-us and ext1-CSmt-us.
# Cannot compute similarity between renew-CSmt-us and ext1-rewardt-cs.
# Cannot compute similarity between renew-CSmt-us and ext1-rewardt-tr.
# Cannot compute similarity between renew-CSmt-us and ext1-rewardt-cstr.
# Cannot compute similarity between renew-CSmt-us and ext1-rewardt-us.
# Cannot compute similarity between renew-CSmt-us and ext2-CSmt-cs.
# Cannot compute similarity between renew-CSmt-us and ext2-CSmt-tr.
# Cannot compute similarity between renew-CSmt-us and ext2-CSmt-cstr.
# Cannot compute similarity between renew-CSmt-us and ext2-CSmt-us.
# Cannot compute similarity between renew-CSmt-us and ext2-rewardt-cs.
# Cannot compute similarity between renew-CSmt-us and ext2-rewardt-tr.
# Cannot compute similarity between renew-CSmt-us and ext2-rewardt-cstr.
# Cannot compute similarity between renew-CSmt-us and ext2-rewardt-us.
# Cannot compute similarity between renew-rewardt-cs and expo-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cs and expo-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cs and expo-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cs and expo-CSmt-us.
# Cannot compute similarity between renew-rewardt-cs and expo-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cs and expo-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cs and expo-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cs and expo-rewardt-us.
# Cannot compute similarity between renew-rewardt-cs and pre-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cs and pre-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cs and pre-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cs and pre-CSmt-us.
# Cannot compute similarity between renew-rewardt-cs and pre-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cs and pre-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cs and pre-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cs and pre-rewardt-us.
# Cannot compute similarity between renew-rewardt-cs and post-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cs and post-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cs and post-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cs and post-CSmt-us.
# Cannot compute similarity between renew-rewardt-cs and post-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cs and post-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cs and post-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cs and post-rewardt-us.
# Cannot compute similarity between renew-rewardt-cs and ext1-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cs and ext1-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cs and ext1-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cs and ext1-CSmt-us.
# Cannot compute similarity between renew-rewardt-cs and ext1-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cs and ext1-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cs and ext1-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cs and ext1-rewardt-us.
# Cannot compute similarity between renew-rewardt-cs and ext2-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cs and ext2-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cs and ext2-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cs and ext2-CSmt-us.
# Cannot compute similarity between renew-rewardt-cs and ext2-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cs and ext2-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cs and ext2-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cs and ext2-rewardt-us.
# Cannot compute similarity between renew-rewardt-tr and expo-CSmt-cs.
# Cannot compute similarity between renew-rewardt-tr and expo-CSmt-tr.
# Cannot compute similarity between renew-rewardt-tr and expo-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-tr and expo-CSmt-us.
# Cannot compute similarity between renew-rewardt-tr and expo-rewardt-cs.
# Cannot compute similarity between renew-rewardt-tr and expo-rewardt-tr.
# Cannot compute similarity between renew-rewardt-tr and expo-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-tr and expo-rewardt-us.
# Cannot compute similarity between renew-rewardt-tr and pre-CSmt-cs.
# Cannot compute similarity between renew-rewardt-tr and pre-CSmt-tr.
# Cannot compute similarity between renew-rewardt-tr and pre-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-tr and pre-CSmt-us.
# Cannot compute similarity between renew-rewardt-tr and pre-rewardt-cs.
# Cannot compute similarity between renew-rewardt-tr and pre-rewardt-tr.
# Cannot compute similarity between renew-rewardt-tr and pre-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-tr and pre-rewardt-us.
# Cannot compute similarity between renew-rewardt-tr and post-CSmt-cs.
# Cannot compute similarity between renew-rewardt-tr and post-CSmt-tr.
# Cannot compute similarity between renew-rewardt-tr and post-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-tr and post-CSmt-us.
# Cannot compute similarity between renew-rewardt-tr and post-rewardt-cs.
# Cannot compute similarity between renew-rewardt-tr and post-rewardt-tr.
# Cannot compute similarity between renew-rewardt-tr and post-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-tr and post-rewardt-us.
# Cannot compute similarity between renew-rewardt-tr and ext1-CSmt-cs.
# Cannot compute similarity between renew-rewardt-tr and ext1-CSmt-tr.
# Cannot compute similarity between renew-rewardt-tr and ext1-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-tr and ext1-CSmt-us.
# Cannot compute similarity between renew-rewardt-tr and ext1-rewardt-cs.
# Cannot compute similarity between renew-rewardt-tr and ext1-rewardt-tr.
# Cannot compute similarity between renew-rewardt-tr and ext1-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-tr and ext1-rewardt-us.
# Cannot compute similarity between renew-rewardt-tr and ext2-CSmt-cs.
# Cannot compute similarity between renew-rewardt-tr and ext2-CSmt-tr.
# Cannot compute similarity between renew-rewardt-tr and ext2-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-tr and ext2-CSmt-us.
# Cannot compute similarity between renew-rewardt-tr and ext2-rewardt-cs.
# Cannot compute similarity between renew-rewardt-tr and ext2-rewardt-tr.
# Cannot compute similarity between renew-rewardt-tr and ext2-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-tr and ext2-rewardt-us.
# Cannot compute similarity between renew-rewardt-cstr and expo-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cstr and expo-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cstr and expo-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and expo-CSmt-us.
# Cannot compute similarity between renew-rewardt-cstr and expo-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cstr and expo-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cstr and expo-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and expo-rewardt-us.
# Cannot compute similarity between renew-rewardt-cstr and pre-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cstr and pre-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cstr and pre-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and pre-CSmt-us.
# Cannot compute similarity between renew-rewardt-cstr and pre-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cstr and pre-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cstr and pre-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and pre-rewardt-us.
# Cannot compute similarity between renew-rewardt-cstr and post-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cstr and post-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cstr and post-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and post-CSmt-us.
# Cannot compute similarity between renew-rewardt-cstr and post-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cstr and post-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cstr and post-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and post-rewardt-us.
# Cannot compute similarity between renew-rewardt-cstr and ext1-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cstr and ext1-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cstr and ext1-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and ext1-CSmt-us.
# Cannot compute similarity between renew-rewardt-cstr and ext1-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cstr and ext1-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cstr and ext1-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and ext1-rewardt-us.
# Cannot compute similarity between renew-rewardt-cstr and ext2-CSmt-cs.
# Cannot compute similarity between renew-rewardt-cstr and ext2-CSmt-tr.
# Cannot compute similarity between renew-rewardt-cstr and ext2-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and ext2-CSmt-us.
# Cannot compute similarity between renew-rewardt-cstr and ext2-rewardt-cs.
# Cannot compute similarity between renew-rewardt-cstr and ext2-rewardt-tr.
# Cannot compute similarity between renew-rewardt-cstr and ext2-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-cstr and ext2-rewardt-us.
# Cannot compute similarity between renew-rewardt-us and expo-CSmt-cs.
# Cannot compute similarity between renew-rewardt-us and expo-CSmt-tr.
# Cannot compute similarity between renew-rewardt-us and expo-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-us and expo-CSmt-us.
# Cannot compute similarity between renew-rewardt-us and expo-rewardt-cs.
# Cannot compute similarity between renew-rewardt-us and expo-rewardt-tr.
# Cannot compute similarity between renew-rewardt-us and expo-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-us and expo-rewardt-us.
# Cannot compute similarity between renew-rewardt-us and pre-CSmt-cs.
# Cannot compute similarity between renew-rewardt-us and pre-CSmt-tr.
# Cannot compute similarity between renew-rewardt-us and pre-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-us and pre-CSmt-us.
# Cannot compute similarity between renew-rewardt-us and pre-rewardt-cs.
# Cannot compute similarity between renew-rewardt-us and pre-rewardt-tr.
# Cannot compute similarity between renew-rewardt-us and pre-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-us and pre-rewardt-us.
# Cannot compute similarity between renew-rewardt-us and post-CSmt-cs.
# Cannot compute similarity between renew-rewardt-us and post-CSmt-tr.
# Cannot compute similarity between renew-rewardt-us and post-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-us and post-CSmt-us.
# Cannot compute similarity between renew-rewardt-us and post-rewardt-cs.
# Cannot compute similarity between renew-rewardt-us and post-rewardt-tr.
# Cannot compute similarity between renew-rewardt-us and post-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-us and post-rewardt-us.
# Cannot compute similarity between renew-rewardt-us and ext1-CSmt-cs.
# Cannot compute similarity between renew-rewardt-us and ext1-CSmt-tr.
# Cannot compute similarity between renew-rewardt-us and ext1-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-us and ext1-CSmt-us.
# Cannot compute similarity between renew-rewardt-us and ext1-rewardt-cs.
# Cannot compute similarity between renew-rewardt-us and ext1-rewardt-tr.
# Cannot compute similarity between renew-rewardt-us and ext1-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-us and ext1-rewardt-us.
# Cannot compute similarity between renew-rewardt-us and ext2-CSmt-cs.
# Cannot compute similarity between renew-rewardt-us and ext2-CSmt-tr.
# Cannot compute similarity between renew-rewardt-us and ext2-CSmt-cstr.
# Cannot compute similarity between renew-rewardt-us and ext2-CSmt-us.
# Cannot compute similarity between renew-rewardt-us and ext2-rewardt-cs.
# Cannot compute similarity between renew-rewardt-us and ext2-rewardt-tr.
# Cannot compute similarity between renew-rewardt-us and ext2-rewardt-cstr.
# Cannot compute similarity between renew-rewardt-us and ext2-rewardt-us.
# /home/fabios/anaconda2/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/fabios/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
pairs_to_plot = [('pre-CSmt-cs', 'pre-CSmt-cs'),
                 ('pre-CSmt-tr', 'pre-CSmt-tr'),
                 ('pre-CSmt-cs', 'pre-rewardt-cs'),
                 ('pre-rewardt-cs', 'pre-rewardt-cs'),
                 ('pre-rewardt-tr', 'pre-rewardt-tr'),
                 ('pre-CSmt-us', 'pre-CSmt-us'),
                 ('pre-CSmt-us', 'pre-rewardt-us'),
                 ('pre-rewardt-us', 'pre-rewardt-us'),
                 ('pre-CSmt-cs', 'pre-CSmt-us'),
                 ('pre-CSmt-cs', 'pre-rewardt-us'),
                 ('pre-rewardt-cs', 'pre-rewardt-us'),
                 ('post-CSmt-cs', 'post-CSmt-cs'),
                 ('post-CSmt-tr', 'post-CSmt-tr'),
                 ('post-CSmt-cs', 'post-rewardt-cs'),
                 ('post-rewardt-tr', 'post-rewardt-tr'),
                 ('post-rewardt-cs', 'post-rewardt-cs'),
                 ('post-CSmt-us', 'post-CSmt-us'),
                 ('post-CSmt-us', 'post-rewardt-us'),
                 ('post-rewardt-us', 'post-rewardt-us'),
                 ('post-CSmt-cs', 'post-CSmt-us'),
                 ('post-CSmt-cs', 'post-rewardt-us'),
                 ('post-rewardt-cs', 'post-rewardt-us'), 
                 ('ext2-CSmt-cs', 'ext2-CSmt-cs'),
                 ('ext2-CSmt-tr', 'ext2-CSmt-tr'),
                 ('ext2-CSmt-cs', 'ext2-rewardt-cs'),
                 ('ext2-rewardt-cs', 'ext2-rewardt-cs'),
                 ('ext2-rewardt-tr', 'ext2-rewardt-tr'),
                 ('ext2-CSmt-us', 'ext2-CSmt-us'),
                 ('ext2-CSmt-us', 'ext2-rewardt-us'),
                 ('ext2-rewardt-us', 'ext2-rewardt-us'),
                 ('ext2-CSmt-cs', 'ext2-CSmt-us'),
                 ('ext2-CSmt-cs', 'ext2-rewardt-us'),
                 ('ext2-rewardt-cs', 'ext2-rewardt-us')]

# %%
from scipy import stats

fig, ax = pl.subplots(1, 1, figsize=(8, 3))
values = [corrmat_distr[tuple(p)]
          for p in pairs_to_plot]
colors = np.repeat(['b', 'r', 'm'], len(values)/3).tolist()
# pt.plot_violins(values, ax=ax, colors=colors)
bp = ax.boxplot(values, whis=[5, 95], showfliers=False, positions=range(len(values)))
[b.set_color(c) for b, c in zip(bp['boxes'], colors)]
[b.set_color(c) for b, c in zip(bp['whiskers'], np.repeat(colors, 2))]
[b.set_color(c) for b, c in zip(bp['caps'], np.repeat(colors, 2))]


ax.set_xticks(range(len(values)))
ax.set_xticklabels(['%s\n%s'%(p[0][p[0].find('-')+1:], p[1][p[1].find('-')+1:]) for p in pairs_to_plot], fontsize=3)
ax.set_xlabel('Pre                    Post                    Ext2', fontsize=10)
ax.set_ylim(-0.2, 1)
ax.set_ylabel("Pattern similarity")
pt.nicer_plot(ax)

fig.tight_layout()
# pl.savefig("pattern_similarity_prepost_odors_violin.jpg", format="jpg", bbox_inches="tight")

# %%
from scipy import stats

pairs_to_plot = pairs_to_plot = [('pre-rewardt-cs', 'pre-rewardt-cs'),
                 ('pre-rewardt-tr', 'pre-rewardt-tr'),
                 ('pre-rewardt-us', 'pre-rewardt-us'),
                 ('pre-rewardt-cs', 'pre-rewardt-us'),
                 ('pre-rewardt-tr', 'pre-rewardt-us'),
                 ('post-rewardt-cs', 'post-rewardt-cs'),
                 ('post-rewardt-tr', 'post-rewardt-tr'),
                 ('post-rewardt-us', 'post-rewardt-us'),
                 ('post-rewardt-cs', 'post-rewardt-us'),
                 ('post-rewardt-tr', 'post-rewardt-us'),
                 ('ext2-rewardt-cs', 'ext2-rewardt-cs'),
                 ('ext2-rewardt-tr', 'ext2-rewardt-tr'),
                 ('ext2-rewardt-us', 'ext2-rewardt-us'),
                 ('ext2-rewardt-cs', 'ext2-rewardt-us'),
                 ('ext2-rewardt-tr', 'ext2-rewardt-us'),
                 ('ext1-rewardt-cs', 'ext1-rewardt-cs'),
                 ('ext1-rewardt-tr', 'ext1-rewardt-tr'),
                 ('ext1-rewardt-us', 'ext1-rewardt-us'),
                 ('ext1-rewardt-cs', 'ext1-rewardt-us'),
                 ('ext1-rewardt-tr', 'ext1-rewardt-us'),
                 ('renew-rewardt-cs', 'renew-rewardt-cs'),
                 ('renew-rewardt-tr', 'renew-rewardt-tr'),
                 ('renew-rewardt-us', 'renew-rewardt-us'),
                 ('renew-rewardt-cs', 'renew-rewardt-us'),
                 ('renew-rewardt-tr', 'renew-rewardt-us')]
fig, ax = pl.subplots(1, 1, figsize=(3, 2))
values = [corrmat_distr[tuple(p)]
          for p in pairs_to_plot]
colors = np.repeat(['b', 'r', 'silver', 'grey', 'r'], len(values)/5).tolist()
bp = ax.boxplot(values, showfliers=False, positions=range(len(values)))
[b.set_color(c) for b, c in zip(bp['boxes'], colors)]
[b.set_color(c) for b, c in zip(bp['whiskers'], np.repeat(colors, 2))]
[b.set_color(c) for b, c in zip(bp['caps'], np.repeat(colors, 2))]


ax.set_xticks(range(len(values)))
ax.set_xticklabels(['%s\n%s'%(p[0][p[0].find('-')+1:], p[1][p[1].find('-')+1:]) for p in pairs_to_plot], fontsize=3, rotation=90)
ax.set_xlabel('Pre           Post           Ext1        Ext2        Renew', fontsize=7)
ax.set_ylim(-0.2, 1)
ax.set_ylabel("Pattern similarity")
pt.nicer_plot(ax)

fig.tight_layout()
# pl.savefig("pattern_similarity_prepost_odors_violin.jpg", format="jpg", bbox_inches="tight")

# %%
from scipy import stats

pairs_to_plot = pairs_to_plot = [('expo-rewardt-cs', 'expo-rewardt-cs'),
                                 ('expo-rewardt-tr', 'expo-rewardt-tr'),
                                 ('expo-rewardt-us', 'expo-rewardt-us'),
                                 ('expo-rewardt-cstr', 'expo-rewardt-cstr'),
                                 ('expo-CSmt-cstr', 'expo-CSmt-cstr')]
fig, ax = pl.subplots(1, 1, figsize=(3, 2))
values = [corrmat_distr[tuple(p)]
          for p in pairs_to_plot]
bp = ax.boxplot(values, showfliers=False, positions=range(len(values)))


ax.set_xticks(range(len(values)))
ax.set_xticklabels(['%s\n%s'%(p[0][p[0].find('-')+1:], p[1][p[1].find('-')+1:]) for p in pairs_to_plot], fontsize=5, rotation=90)
ax.set_xlabel('Expo', fontsize=7)
ax.set_ylim(-0.2, 1)
ax.set_ylabel("Pattern similarity")
pt.nicer_plot(ax)

fig.tight_layout()
# pl.savefig("pattern_similarity_prepost_odors_violin.jpg", format="jpg", bbox_inches="tight")

# %%
save_workspace(db)
# Out:
# Could not store variable 'di'. Skipping...
# Could not store variable 'IPython'. Skipping...
# Could not store variable 'stats'. Skipping...
# Could not store variable 'os'. Skipping...
# Could not store variable 'pt'. Skipping...
# Could not store variable 'pl'. Skipping...
# Could not store variable 'ut'. Skipping...
# Could not store variable 'pickle'. Skipping...
# Could not store variable 'ip'. Skipping...
# Could not store variable 'np'. Skipping...
# Could not store variable 'sys'. Skipping...
