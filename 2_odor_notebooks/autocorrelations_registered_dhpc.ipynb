# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
# all modules necessary for this nb
import os
import sys
import pickle
import math

import numpy as np
import pylab as pl
import scipy.stats as sstats

# setting parameters for default matplotlib plots
# %matplotlib inline

#this will cause text to be exported as 'true text' which can be edited in Adobe Illustrator
pl.rcParams['pdf.fonttype']=42
pl.rcParams['ps.fonttype']=42

# %%
pl.style.use('fabiostyle')
# needs to find the library of functions
sys.path.append('../../code/')  # to be replaced!

import utils as ut
import plots as pt

# %%
#%%javascript
#var nb = IPython.notebook;
#var kernel = IPython.notebook.kernel;
#var command = "NOTEBOOK_NAME = '" + nb.base_url + nb.notebook_path + "'";
#kernel.execute(command);

# %%
NOTEBOOK_NAME = 'autocorrelations_registered_dhpc'

# %%
from pickleshare import PickleShareDB

autorestore_folder = os.path.join(os.getcwd(), 'autorestore', NOTEBOOK_NAME)
db = PickleShareDB(autorestore_folder)
import sys
from workspace import *
import IPython
ip = IPython.get_ipython()

# this will restore all the saved variables. ignore the errors listed.
load_workspace(ip, db)

# use `save_worspace(db)` to save variables at the end

# %%
all_animals =  'dhpcg1','dhpc24', 'dhpcg20','dhpc35','dhpc36'
expo_animals = 'dhpcg1','dhpc24', 'dhpcg20','dhpc35','dhpc36'
pre_animals =  'dhpcg1','dhpc24'           ,'dhpc35','dhpc36'
d2_animals =   'dhpcg1','dhpc24'          ,'dhpc35','dhpc36'
post_animals = 'dhpcg1','dhpc24', 'dhpcg20','dhpc35','dhpc36'
renew_animals =         'dhpc24', 'dhpcg20','dhpc35','dhpc36'
ext2_animals = 'dhpcg1','dhpc24', 'dhpcg20','dhpc35','dhpc36'
ext1_animals = 'dhpcg1','dhpc24', 'dhpcg20','dhpc35','dhpc36'

# %%
#find animals common to both sessions
#expopre_animals = np.intersect1d(expo_animals, pre_animals)
#expopost_animals = np.intersect1d(expo_animals, post_animals)
preVSpost_animals = np.intersect1d(pre_animals, post_animals)
preVSd2_animals = np.intersect1d(pre_animals, d2_animals)
preVSext1_animals = np.intersect1d(pre_animals, ext1_animals)
preVSext2_animals = np.intersect1d(pre_animals, ext2_animals)
preVSrenew_animals = np.intersect1d(pre_animals, renew_animals)
d2VSpost_animals = np.intersect1d(d2_animals, post_animals)
d2VSext1_animals = np.intersect1d(d2_animals, ext1_animals)
d2VSext2_animals = np.intersect1d(d2_animals, ext2_animals)
d2VSrenew_animals = np.intersect1d(d2_animals, renew_animals)
postVSext1_animals = np.intersect1d(post_animals, ext1_animals)
postVSext2_animals = np.intersect1d(post_animals, ext2_animals)
postVSrenew_animals = np.intersect1d(post_animals, renew_animals)
ext1VSext2_animals = np.intersect1d(ext1_animals, ext2_animals)
ext1VSrenew_animals = np.intersect1d(ext1_animals, renew_animals)
ext2VSrenew_animals = np.intersect1d(ext2_animals, renew_animals)

# %%
sessions = 'expo', 'pre','d2', 'post', 'ext1', 'ext2', 'renew'
session_labels = 'Pre','Early','Day2','Late','Ext1','Ext2','Reinstate'
dark_co = ('forestgreen','darkcyan','tab:purple','firebrick','lightgrey','dimgrey','goldenrod')

# %%
from itertools import product
def load_all_animals_vars(varname, animal_list, pilot_list=None, notebook='preprocessing'):
    all_of_them = {}
    for ani in animal_list:
        folder = '../%s/notebooks/autorestore/%s/' % (ani, notebook)
        all_of_them.update({ani: ut.load_variable(varname, folder)})
    return all_of_them

# %%
for sess in sessions[1:]:
    exec("%s_anivars = {}"%sess)
    for animal in eval("%s_animals"%sess):
        
        exec("vars_%s = {}"%sess)
        folder = '../%s/%s/notebooks/autorestore/preprocessing/' % (animal,sess)
        for var in ('time_ax', 'time_ax_single', 'events', 'cycles', 'is_CSmt', 'is_rewardt',
                    'traces','traces_raw', 'CYCLE_START', 'CS_DURATION'): 
            eval("vars_%s"%sess).update({var:ut.load_variable(var, folder=folder)})
        #eval("vars_%s"%sess).update({'time_ax_single_trunc':time_ax_single[11:]}) # create time_ax_sigle where fiirst ~3s are truncated
            
        eval("%s_anivars"%sess).update({animal:{}})
        eval("%s_anivars[animal]"%(sess)).update({eval("'vars_%s'"%sess):eval("vars_%s"%sess)})

    
    #    cellregs = dict(zip(conditions, [ut.load_cellreg_dict('../%s/data/cellreg_dict.txt' % animal, c) for c in conditions]))
    #    anivars[animal].update({'cellregs':cellregs})

# %%
for sess in ['expo']:
    exec("%s_anivars = {}"%sess)
    for animal in eval("%s_animals"%sess):
        exec("vars_%s = {}"%sess)
        folder = '../%s/2_odor_expo/notebooks/autorestore/preprocessing/' % (animal)
        for var in ('time_ax', 'time_ax_single', 'events', 'cycles', 'is_CSmt', 'is_rewardt',
                    'traces','traces_raw', 'CYCLE_START', 'CS_DURATION'): 
            eval("vars_%s"%sess).update({var:ut.load_variable(var, folder=folder)})
        #eval("vars_%s"%sess).update({'time_ax_single_trunc':time_ax_single[11:]}) # create time_ax_sigle where fiirst ~3s are truncated

        eval("%s_anivars"%sess).update({animal:{}})
        eval("%s_anivars[animal]"%(sess)).update({eval("'vars_%s'"%sess):eval("vars_%s"%sess)})

# %%
vars_pre['time_ax_single']
# Out:
# array([-5.        , -4.73318967, -4.46637934, -4.19956902, -3.93275869,
#        -3.66594836, -3.39913803, -3.1323277 , -2.86551738, -2.59870705,
#        -2.33189672, -2.06508639, -1.79827606, -1.53146574, -1.26465541,
#        -0.99784508, -0.73103475, -0.46422442, -0.1974141 ,  0.06939623,
#         0.33620656,  0.60301689,  0.86982722,  1.13663754,  1.40344787,
#         1.6702582 ,  1.93706853,  2.20387886,  2.47068918,  2.73749951,
#         3.00430984,  3.27112017,  3.5379305 ,  3.80474082,  4.07155115,
#         4.33836148,  4.60517181,  4.87198214,  5.13879246,  5.40560279,
#         5.67241312,  5.93922345,  6.20603378,  6.4728441 ,  6.73965443,
#         7.00646476,  7.27327509,  7.54008542,  7.80689574])

# %%
# get cellreg cells
pairs = 'preVSpost','preVSd2','preVSext1','preVSext2','preVSrenew','d2VSpost','d2VSext1','d2VSext2','d2VSrenew','postVSext1','postVSext2','postVSrenew','ext1VSext2','ext1VSrenew','ext2VSrenew'
print all_animals
animals = all_animals

for pair in pairs:
    exec("cellregs_%s = {}"%pair)
    for ani in all_animals:
        try:
            eval("cellregs_%s.update({ani:ut.load_variable('cellregs_%s',\
                 '../%s/notebooks/autorestore/decoding_all/')})" % (pair, pair, ani))
        except IOError:
            print "Empty", pair, ani

cellregs_expoVSpre = {}
for ani in expo_animals:
    try:
        eval("cellregs_expoVSpre.update({ani:ut.load_variable('cellregs_expopre',\
                 '../%s/notebooks/autorestore/decoding_expoVSall/')})" % (ani))
    except IOError:
        print "Empty cellregs_expoVSpre", ani
# Out:
# ('dhpcg1', 'dhpc24', 'dhpcg20', 'dhpc35', 'dhpc36')
# Empty preVSd2 dhpcg20
# Empty preVSrenew dhpcg1
# Empty d2VSpost dhpcg20
# Empty d2VSext1 dhpcg20
# Empty d2VSext2 dhpcg20
# Empty d2VSrenew dhpcg1
# Empty d2VSrenew dhpcg20
# Empty postVSrenew dhpcg1
# Empty ext1VSrenew dhpcg1
# Empty ext2VSrenew dhpcg1
# Empty cellregs_expoVSpre dhpc35
# Empty cellregs_expoVSpre dhpc36

# %% [markdown]
# ### make list of events with the following example structure:  all_amps_d2_CSm_evs[ani][cell][trial][time bin]

# %%
for sess in sessions:
    exec("all_amps_%s_CSm_evs={}"%sess)
    exec("all_amps_%s_Rew_evs={}"%sess)
    for animal in eval("%s_animals"%sess):
    #    cellregs = anivars[animal]['cellregs']
        exec("vars_%s = %s_anivars['%s']['vars_%s']"%(sess,sess,animal,sess))
    
        for k in eval("vars_%s.keys()"%sess):
            exec('%s = vars_%s[\'%s\']' % (k,sess,k))
    
        exec("amp_%s_CSm_evs = np.r_[[ut.compute_all_dffs(time_ax, events, cell, cycles[is_CSmt], time_ax_single)\
                        for cell in range(len(vars_%s['events'][0]))]]"%(sess,sess))
        #exec("amp_%s_CSm_evs = np.r_[[h for h in amp_%s_CSm_evs]]"%(sess,sess))
        #exec("amp_%s_CSm_evs = np.r_[[np.mean(h, 0)/np.std(h, 0) if zscored else np.mean(h, 0)/np.max(h.mean(0)) for h in amp_%s_CSm_evs]]"%(sess,sess))
        exec("amp_%s_Rew_evs = np.r_[[ut.compute_all_dffs(time_ax, events, cell, cycles[is_rewardt], time_ax_single)\
                        for cell in range(len(vars_%s['events'][0]))]]"%(sess,sess))
        #exec("amp_%s_Rew_evs = np.r_[[np.mean(h, 0)/np.std(h, 0) if zscored else np.mean(h, 0)/np.max(h.mean(0)) for h in amp_%s_Rew_evs]]"%(sess,sess))
        
        exec("all_amps_%s_CSm_evs[animal]=amp_%s_CSm_evs"%(sess, sess))
        exec("all_amps_%s_Rew_evs[animal]=amp_%s_Rew_evs"%(sess, sess))

# %%
all_amps_pre_Rew_evs.keys()
# Out:
# ['dhpcg1', 'dhpc36', 'dhpc35', 'dhpc24']

# %%
# only keep registered cells
for tt in ['Rew','CSm']:
    for pair in pairs:
        for pos,order in zip (range(2),([0,1],[1,0])):
            exec("all_amps_%s_%s_%s_evs={}"%(pair,pair.split('VS')[pos],tt))
            #print pair,pair.split('VS')[pos],tt,
            for ani in eval("%s_animals"%pair):
                exec("all_amps_%s_%s_%s_evs[ani]=all_amps_%s_%s_evs[ani][cellregs_%s[ani]['%s_%s']]"%(pair,pair.split('VS')[pos],
                      tt,pair.split('VS')[pos],tt,pair,pair.split('VS')[order[0]],pair.split('VS')[order[1]]))
                #print "all_amps_%s_%s_%s_evs['%s']=all_amps_%s_%s_evs[ani][cellregs_%s[ani]['%s_%s']]"%(pair,pair.split('VS')[pos],
                #      tt,ani,pair.split('VS')[pos],tt,pair,pair.split('VS')[order[0]],pair.split('VS')[order[1]])

# %%
# %%time
#split each trial into baseline and trial epochs
for epoch,s,e in zip(['base','trial'],[-4.6, 1],[0.4, 8]):
    for tt in ['Rew','CSm']:
        for pair in pairs:
            for pos in range(2):
                print 'working on %s %s %s %s   '%(epoch,pair,pair.split('VS')[pos],tt),
                exec("%s_%s_%s_%s_evs={}"%(epoch,pair,pair.split('VS')[pos],tt))
                for ani in eval("all_amps_%s_%s_%s_evs.keys()"%(pair,pair.split('VS')[pos],tt)):
                    exec("%s_%s_%s_%s_evs[ani]=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                    for cell in range(len(eval("all_amps_%s_%s_%s_evs[ani]"%(pair,pair.split('VS')[pos],tt)))):
                        exec("%s_%s_%s_%s_evs[ani].append([])"%(epoch,pair,pair.split('VS')[pos],tt))
                        for trial in range(len(eval("all_amps_%s_%s_%s_evs[ani][cell]"%(pair,pair.split('VS')[pos],tt)))):
                            exec("%s_%s_%s_%s_evs[ani][cell].append([])"%(epoch,pair,pair.split('VS')[pos],tt))
                            for tb in range(len(eval("all_amps_%s_%s_%s_evs[ani][cell][trial]"%(pair,pair.split('VS')[pos],tt)))):
                                if eval("%s_anivars[ani]['vars_%s']['time_ax_single'][tb]"%(pair.split('VS')[pos],pair.split('VS')[pos])) >= s:
                                    if eval("%s_anivars[ani]['vars_%s']['time_ax_single'][tb]"%(pair.split('VS')[pos],pair.split('VS')[pos])) <= e:
                                        #if eval("all_amps_%s_%s_evs[ani][cell][trial][tb]"%(sess,tt)) > 0.0:
                                            exec("%s_%s_%s_%s_evs[ani][cell][trial].append(all_amps_%s_%s_%s_evs[ani][cell][trial][tb])"%(epoch,pair,pair.split('VS')[pos],tt,pair,pair.split('VS')[pos],tt))
# Out:
# working on base preVSpost pre Rew    working on base preVSpost post Rew    working on base preVSd2 pre Rew    working on base preVSd2 d2 Rew    working on base preVSext1 pre Rew    working on base preVSext1 ext1 Rew    working on base preVSext2 pre Rew    working on base preVSext2 ext2 Rew    working on base preVSrenew pre Rew    working on base preVSrenew renew Rew    working on base d2VSpost d2 Rew    working on base d2VSpost post Rew    working on base d2VSext1 d2 Rew    working on base d2VSext1 ext1 Rew    working on base d2VSext2 d2 Rew    working on base d2VSext2 ext2 Rew    working on base d2VSrenew d2 Rew    working on base d2VSrenew renew Rew    working on base postVSext1 post Rew    working on base postVSext1 ext1 Rew    working on base postVSext2 post Rew    working on base postVSext2 ext2 Rew    working on base postVSrenew post Rew    working on base postVSrenew renew Rew    working on base ext1VSext2 ext1 Rew    working on base ext1VSext2 ext2 Rew    working on base ext1VSrenew ext1 Rew    working on base ext1VSrenew renew Rew    working on base ext2VSrenew ext2 Rew    working on base ext2VSrenew renew Rew    working on base preVSpost pre CSm    working on base preVSpost post CSm    working on base preVSd2 pre CSm    working on base preVSd2 d2 CSm    working on base preVSext1 pre CSm    working on base preVSext1 ext1 CSm    working on base preVSext2 pre CSm    working on base preVSext2 ext2 CSm    working on base preVSrenew pre CSm    working on base preVSrenew renew CSm    working on base d2VSpost d2 CSm    working on base d2VSpost post CSm    working on base d2VSext1 d2 CSm    working on base d2VSext1 ext1 CSm    working on base d2VSext2 d2 CSm    working on base d2VSext2 ext2 CSm    working on base d2VSrenew d2 CSm    working on base d2VSrenew renew CSm    working on base postVSext1 post CSm    working on base postVSext1 ext1 CSm    working on base postVSext2 post CSm    working on base postVSext2 ext2 CSm    working on base postVSrenew post CSm    working on base postVSrenew renew CSm    working on base ext1VSext2 ext1 CSm    working on base ext1VSext2 ext2 CSm    working on base ext1VSrenew ext1 CSm    working on base ext1VSrenew renew CSm    working on base ext2VSrenew ext2 CSm    working on base ext2VSrenew renew CSm    working on trial preVSpost pre Rew    working on trial preVSpost post Rew    working on trial preVSd2 pre Rew    working on trial preVSd2 d2 Rew    working on trial preVSext1 pre Rew    working on trial preVSext1 ext1 Rew    working on trial preVSext2 pre Rew    working on trial preVSext2 ext2 Rew    working on trial preVSrenew pre Rew    working on trial preVSrenew renew Rew    working on trial d2VSpost d2 Rew    working on trial d2VSpost post Rew    working on trial d2VSext1 d2 Rew    working on trial d2VSext1 ext1 Rew    working on trial d2VSext2 d2 Rew    working on trial d2VSext2 ext2 Rew    working on trial d2VSrenew d2 Rew    working on trial d2VSrenew renew Rew    working on trial postVSext1 post Rew    working on trial postVSext1 ext1 Rew    working on trial postVSext2 post Rew    working on trial postVSext2 ext2 Rew    working on trial postVSrenew post Rew    working on trial postVSrenew renew Rew    working on trial ext1VSext2 ext1 Rew    working on trial ext1VSext2 ext2 Rew    working on trial ext1VSrenew ext1 Rew    working on trial ext1VSrenew renew Rew    working on trial ext2VSrenew ext2 Rew    working on trial ext2VSrenew renew Rew    working on trial preVSpost pre CSm    working on trial preVSpost post CSm    working on trial preVSd2 pre CSm    working on trial preVSd2 d2 CSm    working on trial preVSext1 pre CSm    working on trial preVSext1 ext1 CSm    working on trial preVSext2 pre CSm    working on trial preVSext2 ext2 CSm    working on trial preVSrenew pre CSm    working on trial preVSrenew renew CSm    working on trial d2VSpost d2 CSm    working on trial d2VSpost post CSm    working on trial d2VSext1 d2 CSm    working on trial d2VSext1 ext1 CSm    working on trial d2V ...
# Wall time: 1h 28min 26s

# %%
# %%time
#get autocorrelation of every trial, for every cell, for every animal
for epoch in ['base','trial']:
    for tt in ['Rew','CSm']:
        for pair in pairs:
            for pos in range(2):
                print 'working on %s %s %s %s  '%(epoch,pair,pair.split('VS')[pos],tt),
                exec("autocorr_%s_%s_%s_%s_evs={}"%(epoch,pair,pair.split('VS')[pos],tt))
                for ani in eval("all_amps_%s_%s_%s_evs.keys()"%(pair,pair.split('VS')[pos],tt)):
                    exec("autocorr_%s_%s_%s_%s_evs[ani]=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                    for cell in range(len(eval("all_amps_%s_%s_%s_evs[ani]"%(pair,pair.split('VS')[pos],tt)))):
                        exec("autocorr_%s_%s_%s_%s_evs[ani].append([])"%(epoch,pair,pair.split('VS')[pos],tt))
                        for trial in range(len(eval("all_amps_%s_%s_%s_evs[ani][cell]"%(pair,pair.split('VS')[pos],tt)))):
                            # don't include trials where cell didn't fire
                            if np.mean(eval("%s_%s_%s_%s_evs[ani][cell][trial]"%(epoch,pair,pair.split('VS')[pos],tt))) > 0:
                                exec("ac = np.correlate(%s_%s_%s_%s_evs[ani][cell][trial],%s_%s_%s_%s_evs[ani][cell][trial],mode='full')"%(epoch,pair,pair.split('VS')[pos],tt,epoch,pair,pair.split('VS')[pos],tt))
                                # throw away distant time lag comparisons (only keep middle 35). This is also necessary to standardize the no. of tbs across animals
                                ta = len(eval("%s_%s_%s_%s_evs[ani][cell][trial]"%(epoch,pair,pair.split('VS')[pos],tt))) - 18
                                exec("autocorr_%s_%s_%s_%s_evs[ani][cell].append((ac/np.max(ac))[ta:-ta])"%(epoch,pair,pair.split('VS')[pos],tt))
first_run=True
# Out:
# working on base preVSpost pre Rew   working on base preVSpost post Rew   working on base preVSd2 pre Rew   working on base preVSd2 d2 Rew   working on base preVSext1 pre Rew   working on base preVSext1 ext1 Rew   working on base preVSext2 pre Rew   working on base preVSext2 ext2 Rew   working on base preVSrenew pre Rew   working on base preVSrenew renew Rew   working on base d2VSpost d2 Rew   working on base d2VSpost post Rew   working on base d2VSext1 d2 Rew   working on base d2VSext1 ext1 Rew   working on base d2VSext2 d2 Rew   working on base d2VSext2 ext2 Rew   working on base d2VSrenew d2 Rew   working on base d2VSrenew renew Rew   working on base postVSext1 post Rew   working on base postVSext1 ext1 Rew   working on base postVSext2 post Rew   working on base postVSext2 ext2 Rew   working on base postVSrenew post Rew   working on base postVSrenew renew Rew   working on base ext1VSext2 ext1 Rew   working on base ext1VSext2 ext2 Rew   working on base ext1VSrenew ext1 Rew   working on base ext1VSrenew renew Rew   working on base ext2VSrenew ext2 Rew   working on base ext2VSrenew renew Rew   working on base preVSpost pre CSm   working on base preVSpost post CSm   working on base preVSd2 pre CSm   working on base preVSd2 d2 CSm   working on base preVSext1 pre CSm   working on base preVSext1 ext1 CSm   working on base preVSext2 pre CSm   working on base preVSext2 ext2 CSm   working on base preVSrenew pre CSm   working on base preVSrenew renew CSm   working on base d2VSpost d2 CSm   working on base d2VSpost post CSm   working on base d2VSext1 d2 CSm   working on base d2VSext1 ext1 CSm   working on base d2VSext2 d2 CSm   working on base d2VSext2 ext2 CSm   working on base d2VSrenew d2 CSm   working on base d2VSrenew renew CSm   working on base postVSext1 post CSm   working on base postVSext1 ext1 CSm   working on base postVSext2 post CSm   working on base postVSext2 ext2 CSm   working on base postVSrenew post CSm   working on base postVSrenew renew CSm   working on base ext1VSext2 ext1 CSm   working on base ext1VSext2 ext2 CSm   working on base ext1VSrenew ext1 CSm   working on base ext1VSrenew renew CSm   working on base ext2VSrenew ext2 CSm   working on base ext2VSrenew renew CSm   working on trial preVSpost pre Rew   working on trial preVSpost post Rew   working on trial preVSd2 pre Rew   working on trial preVSd2 d2 Rew   working on trial preVSext1 pre Rew   working on trial preVSext1 ext1 Rew   working on trial preVSext2 pre Rew   working on trial preVSext2 ext2 Rew   working on trial preVSrenew pre Rew   working on trial preVSrenew renew Rew   working on trial d2VSpost d2 Rew   working on trial d2VSpost post Rew   working on trial d2VSext1 d2 Rew   working on trial d2VSext1 ext1 Rew   working on trial d2VSext2 d2 Rew   working on trial d2VSext2 ext2 Rew   working on trial d2VSrenew d2 Rew   working on trial d2VSrenew renew Rew   working on trial postVSext1 post Rew   working on trial postVSext1 ext1 Rew   working on trial postVSext2 post Rew   working on trial postVSext2 ext2 Rew   working on trial postVSrenew post Rew   working on trial postVSrenew renew Rew   working on trial ext1VSext2 ext1 Rew   working on trial ext1VSext2 ext2 Rew   working on trial ext1VSrenew ext1 Rew   working on trial ext1VSrenew renew Rew   working on trial ext2VSrenew ext2 Rew   working on trial ext2VSrenew renew Rew   working on trial preVSpost pre CSm   working on trial preVSpost post CSm   working on trial preVSd2 pre CSm   working on trial preVSd2 d2 CSm   working on trial preVSext1 pre CSm   working on trial preVSext1 ext1 CSm   working on trial preVSext2 pre CSm   working on trial preVSext2 ext2 CSm   working on trial preVSrenew pre CSm   working on trial preVSrenew renew CSm   working on trial d2VSpost d2 CSm   working on trial d2VSpost post CSm   working on trial d2VSext1 d2 CSm   working on trial d2VSext1 ext1 CSm   working on trial d2VSext2 d2 CSm   working on trial d2VSext2 ext2 CSm   working on trial d2VSrenew d2 CSm   working on trial ...
# Wall time: 3min 1s

# %%
#remove cells that have no activity
if first_run==True:
    #you can only run the below once. Must rereun cell above before doing again.
    for epoch in ['base','trial']:
        for tt in ['Rew','CSm']:
            for pair in pairs:
                for pos in range(2):
                    for x in eval("autocorr_%s_%s_%s_%s_evs.keys()"%(epoch,pair,pair.split('VS')[pos],tt)):
                        c=0
                        for y in range(len(eval("autocorr_%s_%s_%s_%s_evs[x]"%(epoch,pair,pair.split('VS')[pos],tt)))):
                            #n=0
                            if len(eval("autocorr_%s_%s_%s_%s_evs[x][y-c]"%(epoch,pair,pair.split('VS')[pos],tt)))==0:
                                #if np.mean(eval("%s_%s_%s_%s_evs[x][y][z]"%(epoch,pair,pair.split('VS')[pos],tt))) < 0.00000001:
                                #    n=n+1
                            #if n==len(eval("autocorr_%s_%s_%s_%s_evs[x][y]"%(epoch,pair,pair.split('VS')[pos],tt))):
                                print "%s_%s_%s_%s[%s][%s]"%(epoch,pair,pair.split('VS')[pos],tt,x,y-c),
                                print eval("autocorr_%s_%s_%s_%s_evs[x][%s]"%(epoch,pair,pair.split('VS')[pos],tt,y-c))
                                exec("for_del = autocorr_%s_%s_%s_%s_evs"%(epoch,pair,pair.split('VS')[pos],tt))
                                #print for_del
                                del for_del[x][y-c]
                                print "deleted autocorr_%s_%s_%s_%s[%s][%s]"%(epoch,pair,pair.split('VS')[pos],tt,x,y-c)
                                c=c+1  # since a cell has now been deleted, must subtract off that index position for the next deletion
first_run=False
# Out:
# base_preVSpost_pre_Rew[dhpc24][202] []
# deleted autocorr_base_preVSpost_pre_Rew[dhpc24][202]
# base_preVSpost_post_Rew[dhpc36][4] []
# deleted autocorr_base_preVSpost_post_Rew[dhpc36][4]
# base_preVSpost_post_Rew[dhpc24][28] []
# deleted autocorr_base_preVSpost_post_Rew[dhpc24][28]
# base_preVSpost_post_Rew[dhpc24][84] []
# deleted autocorr_base_preVSpost_post_Rew[dhpc24][84]
# base_preVSd2_pre_Rew[dhpc35][34] []
# deleted autocorr_base_preVSd2_pre_Rew[dhpc35][34]
# base_preVSd2_d2_Rew[dhpc36][12] []
# deleted autocorr_base_preVSd2_d2_Rew[dhpc36][12]
# base_preVSd2_d2_Rew[dhpc36][20] []
# deleted autocorr_base_preVSd2_d2_Rew[dhpc36][20]
# base_preVSext1_ext1_Rew[dhpc36][17] []
# deleted autocorr_base_preVSext1_ext1_Rew[dhpc36][17]
# base_preVSext2_pre_Rew[dhpc24][159] []
# deleted autocorr_base_preVSext2_pre_Rew[dhpc24][159]
# base_preVSext2_ext2_Rew[dhpc36][11] []
# deleted autocorr_base_preVSext2_ext2_Rew[dhpc36][11]
# base_preVSext2_ext2_Rew[dhpc24][22] []
# deleted autocorr_base_preVSext2_ext2_Rew[dhpc24][22]
# base_preVSrenew_pre_Rew[dhpc24][104] []
# deleted autocorr_base_preVSrenew_pre_Rew[dhpc24][104]
# base_d2VSpost_d2_Rew[dhpc36][48] []
# deleted autocorr_base_d2VSpost_d2_Rew[dhpc36][48]
# base_d2VSpost_d2_Rew[dhpc36][50] []
# deleted autocorr_base_d2VSpost_d2_Rew[dhpc36][50]
# base_d2VSpost_post_Rew[dhpc36][35] []
# deleted autocorr_base_d2VSpost_post_Rew[dhpc36][35]
# base_d2VSpost_post_Rew[dhpc24][4] []
# deleted autocorr_base_d2VSpost_post_Rew[dhpc24][4]
# base_d2VSext1_d2_Rew[dhpc36][43] []
# deleted autocorr_base_d2VSext1_d2_Rew[dhpc36][43]
# base_d2VSext1_d2_Rew[dhpc36][43] []
# deleted autocorr_base_d2VSext1_d2_Rew[dhpc36][43]
# base_d2VSext1_d2_Rew[dhpc36][45] []
# deleted autocorr_base_d2VSext1_d2_Rew[dhpc36][45]
# base_d2VSext1_d2_Rew[dhpc36][46] []
# deleted autocorr_base_d2VSext1_d2_Rew[dhpc36][46]
# base_d2VSext1_d2_Rew[dhpc36][47] []
# deleted autocorr_base_d2VSext1_d2_Rew[dhpc36][47]
# base_d2VSext1_ext1_Rew[dhpc36][39] []
# deleted autocorr_base_d2VSext1_ext1_Rew[dhpc36][39]
# base_d2VSext1_ext1_Rew[dhpc36][44] []
# deleted autocorr_base_d2VSext1_ext1_Rew[dhpc36][44]
# base_d2VSext2_d2_Rew[dhpc36][46] []
# deleted autocorr_base_d2VSext2_d2_Rew[dhpc36][46]
# base_d2VSext2_d2_Rew[dhpc36][46] []
# deleted autocorr_base_d2VSext2_d2_Rew[dhpc36][46]
# base_d2VSext2_d2_Rew[dhpc36][51] []
# deleted autocorr_base_d2VSext2_d2_Rew[dhpc36][51]
# base_d2VSext2_ext2_Rew[dhpc36][15] []
# deleted autocorr_base_d2VSext2_ext2_Rew[dhpc36][15]
# base_d2VSrenew_d2_Rew[dhpc36][49] []
# deleted autocorr_base_d2VSrenew_d2_Rew[dhpc36][49]
# base_d2VSrenew_d2_Rew[dhpc36][50] []
# deleted autocorr_base_d2VSrenew_d2_Rew[dhpc36][50]
# base_postVSext1_post_Rew[dhpc35][53] []
# deleted autocorr_base_postVSext1_post_Rew[dhpc35][53]
# base_postVSext1_post_Rew[dhpc24][14] []
# deleted autocorr_base_postVSext1_post_Rew[dhpc24][14]
# base_postVSext1_ext1_Rew[dhpc35][32] []
# deleted autocorr_base_postVSext1_ext1_Rew[dhpc35][32]
# base_postVSext1_ext1_Rew[dhpc35][53] []
# deleted autocorr_base_postVSext1_ext1_Rew[dhpc35][53]
# base_postVSext1_ext1_Rew[dhpc36][49] []
# deleted autocorr_base_postVSext1_ext1_Rew[dhpc36][49]
# base_postVSext2_post_Rew[dhpc24][20] []
# deleted autocorr_base_postVSext2_post_Rew[dhpc24][20]
# base_postVSext2_post_Rew[dhpc24][91] []
# deleted autocorr_base_postVSext2_post_Rew[dhpc24][91]
# base_postVSext2_ext2_Rew[dhpc35][12] []
# deleted autocorr_base_postVSext2_ext2_Rew[dhpc35][12]
# base_postVSext2_ext2_Rew[dhpc36][10] []
# deleted autocorr_base_postVSext2_ext2_Rew[dhpc36][10]
# base_postVSext2_ext2_Rew[dhpc24][92] []
# deleted autocorr_base_postVSext2_ext2_Rew[dhpc24][92]
# base_postVSrenew_post_Rew[dhpc36][51] []
# deleted autocorr_base_postVSrenew_post_Rew[dhpc36][51]
# base_postVSrenew_post_Rew[dhpc36][58] []
# deleted autocorr_base_postVSrenew_post_Rew[dhpc36][58]
# base_postVSrenew_post_Rew[dhpc36][61] []
# deleted autocorr_base_postVSrenew_post_Rew[dhpc36][61]
# base_postVSrenew_post_Rew[dhpc24][66] []
# deleted autocorr_base_postVSrenew_post_Rew[dhpc24][66]
# base_postVSrenew_renew_Rew[dhpc35][47] []
# deleted autocorr_base_postVSrenew_renew_Rew[dhpc35][47]
# base_ext1VSext2_ext1_Rew[dhpc36][56] []
# deleted autocorr_base_ext1VSext2_ext1_Rew[dhpc36][56]
# base_ext1VSext2_ext1_Rew[dhpc36][62] []
# deleted autocorr_base_ext1VSext2_ext1_Rew[dhpc36][62]
# base_ext1VSext2_ext2_Rew[dhpc36][21] []
# deleted autocorr_base_ext1VSext2_ext2_Rew[dhpc36][21]
# base_ext1VSext2_ext2_Rew[dhpc36][47] []
# deleted autocorr_base_ext1VSext2_ext2_Rew[dhpc36][47]
# base_ext1VSext2_ext2_Rew[dhpc36][60] []
# deleted autocorr_base_ext1VSext2_ext2_Rew[dhpc36][60]
# base_ext1VSext2_ext2_Rew[dhpc24][85] []
# deleted autocorr_base_ext1VSext2_ext2_Rew[dhpc24][85]
# base_ext1VSrenew_ext1_Rew[dhpc35][44] []
# deleted autocorr_base_ext1VSrenew_ext1_Rew[dhpc35][44]
# base_ext1VSrenew_ext1_Rew[dhpc36][54] []
# deleted autocorr_base_ext1VSrenew_ext1_Rew[dhpc36][54]
# base_ext1VSrenew_renew_Rew[dhpc36][57] []
# deleted autocorr_base_ext1VSrenew_renew_Rew[dhpc36][57]
# base_ext2VSrenew_ext2_Rew[dhpc24][164] []
# deleted autocorr_base_ext2VSrenew_ext2_Rew[dhpc24][164]
# base_preVSpost_pre_CSm[dhpc36][19] []
# deleted autocorr_base_preVSpost_pre_CSm[dhpc36][19]
# base_preVSpost_pre_CSm[dhpc36][19] []
# deleted autocorr_base_preVSpost_pre_CSm[dhpc36][19]
# base_preVSpost_pre_CSm[dhpc24][127] []
# deleted autocorr_base_preVSpost_pre_CSm[dhpc24][127]
# base_preVSpost_post_CSm[dhpc36][4] []
# deleted autocorr_base_preVSpost_post_CSm[dhpc36][4]
# base_preVSpost_post_CSm[dhpc36][13] []
# deleted autocorr_base_preVSpost_post_CSm[dhpc36][13]
# base_preVSd2_pre_CSm[dhpc35][35] []
# deleted autocorr_base_preVSd2_pre_CSm[dhpc35][35]
# base_preVSd2_pre_CSm[dhpc35][35] []
# deleted autocorr_base_preVSd2_pre_CSm[dhpc35][35]
# base_preVSd2_pre_CSm[dhpc36][21] []
# deleted autocorr_base_preVSd2_pre_CSm[dhpc36][21]
# base_preVSd2_pre_CSm[dhpc24][131] []
# deleted autocorr_base_preVSd2_pre_CSm[dhpc24][131]
# base_preVSd2_d2_CSm[dhpc36][12] []
# deleted autocorr_base_preVSd2_d2_CSm[dhpc36][12]
# base_preVSd2_d2_CSm[dhpc36][19] []
# deleted autocorr_base_preVSd2_d2_CSm[dhpc36][19]
# base_preVSd2_d2_CSm[dhpc24][77] []
# deleted autocorr_base_preVSd2_d2_CSm[dhpc24][77]
# base_preVSext2_pre_CSm[dhpc36][18] []
# deleted autocorr_base_preVSext2_pre_CSm[dhpc36][18]
# base_preVSext2_pre_CSm[dhpc24][97] []
# deleted autocorr_base_preVSext2_pre_CSm[dhpc24][97]
# base_preVSext2_ext2_CSm[dhpc35][30] []
# deleted autocorr_base_preVSext2_ext2_CSm[dhpc35][30]
# base_preVSext2_ext2_CSm[dhpc36][12] []
# deleted autocorr_base_preVSext2_ext2_CSm[dhpc36][12]
# base_preVSrenew_pre_CSm[dhpc35][22] []
# deleted autocorr_base_preVSrenew_pre_CSm[dhpc35][22]
# base_d2VSpost_d2_CSm[dhpc36][46] []
# deleted autocorr_base_d2VSpost_d2_CSm[dhpc36][46]
# base_d2VSpost_d2_CSm[dhpc36][48] []
# deleted autocorr_base_d2VSpost_d2_CSm[dhpc36][48]
# base_d2VSpost_d2_CSm[dhpc36][48] []
# deleted autocorr_base_d2VSpost_d2_CSm[dhpc36][48]
# base_d2VSpost_d2_CSm[dhpc36][48] []
# deleted autocorr_base_d2VSpost_d2_CSm[dhpc36][48]
# base_d2VSpost_d2_CSm[dhpc24][80] []
# deleted autocorr_base_d2VSpost_d2_CSm[dhpc24][80]
# base_d2VSext1_d2_CSm[dhpc36][37] []
# deleted autocorr_base_d2VSext1_d2_CSm[dhpc36][37]
# base_d2VSext1_d2_CSm[dhpc36][44] []
# deleted autocorr_base_d2VSext1_d2_CSm[dhpc36][44]
# base_d2VSext1_d2_CSm[dhpc36][45] []
# deleted autocorr_base_d2VSext1_d2_CSm[dhpc36][45]
# base_d2VSext1_ext1_CSm[dhpc36][37] []
# deleted autocorr_base_d2VSext1_ext1_CSm[dhpc36][37]
# base_d2VSext1_ext1_CSm[dhpc36][37] []
# deleted autocorr_base_d2VSext1_ext1_CSm[dhpc36][37]
# base_d2VSext2_d2_CSm[dhpc36][40] []
# deleted autocorr_base_d2VSext2_d2_CSm[dhpc36][40]
# base_d2VSext2_d2_CSm[dhpc36][49] []
# deleted autocorr_base_d2VSext2_d2_CSm[dhpc36][49]
# base_d2VSext2_d2_CSm[dhpc36][51] []
# deleted autocorr_base_d2VSext2_d2_CSm[dhpc36][51]
# base_d2VSext2_d2_CSm[dhpc24][57] []
# deleted autocorr_base_d2VSext2_d2_CSm[dhpc24][57]
# base_d2VSext2_ext2_CSm[dhpc36][41] []
# deleted autocorr_base_d2VSext2_ext2_CSm[dhpc36][41]
# base_d2VSext2_ext2_CSm[dhpc36][52] []
# deleted autocorr_base_d2VSext2_ext2_CSm[dhpc36][52]
# base_d2VSrenew_d2_CSm[dhpc36][47] []
# deleted autocorr_base_d2VSrenew_d2_CSm[dhpc36][47]
# base_d2VSrenew_d2_CSm[dhpc36][48] []
# deleted autocorr_base_d2VSrenew_d2_CSm[dhpc36][48]
# base_d2VSrenew_d2_CSm[dhpc24][56] []
# deleted autocorr_base_d2VSrenew_d2_CSm[dhpc24][56]
# base_d2VSrenew_renew_CSm[dhpc36][47] []
# deleted autocorr_base_d2VSrenew_renew_CSm[dhpc36][47]
# base_postVSext1_post_CSm[dhpc36][27] []
# deleted autocorr_base_postVSext1_post_CSm[dhpc36][27]
# base_postVSext1_post_CSm[dhpcg20][18] []
# deleted autocorr_base_postVSext1_post_CSm[dhpcg20][18]
# base_postVSext1_ext1_CSm[dhpc36][10] []
# deleted autocorr_base_postVSext1_ext1_CSm[dhpc36][10]
# base_postVSext1_ext1_CSm[dhpc36][43] []
# deleted autocorr_base_postVSext1_ext1_CSm[dhpc36][43]
# base_postVSext2_post_CSm[dhpc36][25] []
# deleted autocorr_base_postVSext2_post_CSm[dhpc36][25]
# base_postVSext2_post_CSm[dhpcg20][17] []
# deleted autocorr_base_postVSext2_post_CSm[dhpcg20][17]
# base_postVSext2_post_CSm[dhpcg20][145] []
# deleted autocorr_base_postVSext2_post_CSm[dhpcg20][145]
# base_postVSext2_ext2_CSm[dhpc36][9] []
# deleted autocorr_base_postVSext2_ext2_CSm[dhpc36][9]
# base_postVSext2_ext2_CSm[dhpc36][13] []
# deleted autocorr_base_postVSext2_ext2_CSm[dhpc36][13]
# base_postVSrenew_post_CSm[dhpc35][41] []
# deleted autocorr_base_postVSrenew_post_CSm[dhpc35][41]
# base_postVSrenew_post_CSm[dhpc36][30] []
# deleted autocorr_base_postVSrenew_post_CSm[dhpc36][30]
# base_postVSrenew_post_CSm[dhpc36][62] []
# deleted autocorr_base_postVSrenew_post_CSm[dhpc36][62]
# base_postVSrenew_post_CSm[dhpcg20][16] []
# deleted autocorr_base_postVSrenew_post_CSm[dhpcg20][16]
# base_postVSrenew_post_CSm[dhpcg20][126] []
# deleted autocorr_base_postVSrenew_post_CSm[dhpcg20][126]
# base_postVSrenew_renew_CSm[dhpc36][55] []
# deleted autocorr_base_postVSrenew_renew_CSm[dhpc36][55]
# base_postVSrenew_renew_CSm[dhpcg20][127] []
# deleted autocorr_base_postVSrenew_renew_CSm[dhpcg20][127]
# base_ext1VSext2_ext1_CSm[dhpc36][25] []
# deleted autocorr_base_ext1VSext2_ext1_CSm[dhpc36][25]
# base_ext1VSext2_ext1_CSm[dhpc36][54] []
# deleted autocorr_base_ext1VSext2_ext1_CSm[dhpc36][54]
# base_ext1VSext2_ext1_CSm[dhpc36][62] []
# deleted autocorr_base_ext1VSext2_ext1_CSm[dhpc36][62]
# base_ext1VSext2_ext2_CSm[dhpc36][25] []
# deleted autocorr_base_ext1VSext2_ext2_CSm[dhpc36][25]
# base_ext1VSext2_ext2_CSm[dhpc36][29] []
# deleted autocorr_base_ext1VSext2_ext2_CSm[dhpc36][29]
# base_ext1VSrenew_ext1_CSm[dhpc35][46] []
# deleted autocorr_base_ext1VSrenew_ext1_CSm[dhpc35][46]
# base_ext1VSrenew_ext1_CSm[dhpc36][27] []
# deleted autocorr_base_ext1VSrenew_ext1_CSm[dhpc36][27]
# base_ext1VSrenew_ext1_CSm[dhpc36][54] []
# deleted autocorr_base_ext1VSrenew_ext1_CSm[dhpc36][54]
# base_ext1VSrenew_renew_CSm[dhpc36][54] []
# deleted autocorr_base_ext1VSrenew_renew_CSm[dhpc36][54]
# base_ext1VSrenew_renew_CSm[dhpc36][56] []
# deleted autocorr_base_ext1VSrenew_renew_CSm[dhpc36][56]
# base_ext2VSrenew_ext2_CSm[dhpc36][42] []
# deleted autocorr_base_ext2VSrenew_ext2_CSm[dhpc36][42]
# base_ext2VSrenew_ext2_CSm[dhpc36][45] []
# deleted autocorr_base_ext2VSrenew_ext2_CSm[dhpc36][45]
# base_ext2VSrenew_renew_CSm[dhpc36][43] []
# deleted autocorr_base_ext2VSrenew_renew_CSm[dhpc36][43]
# base_ext2VSrenew_renew_CSm[dhpcg20][122] []
# deleted autocorr_base_ext2VSrenew_renew_CSm[dhpcg20][122]
# trial_preVSpost_pre_Rew[dhpc36][18] []
# deleted autocorr_trial_preVSpost_pre_Rew[dhpc36][18]
# trial_preVSpost_post_Rew[dhpc36][0] []
# deleted autocorr_trial_preVSpost_post_Rew[dhpc36][0]
# trial_preVSpost_post_Rew[dhpc36][19] []
# deleted autocorr_trial_preVSpost_post_Rew[dhpc36][19]
# trial_preVSd2_pre_Rew[dhpc35][31] []
# deleted autocorr_trial_preVSd2_pre_Rew[dhpc35][31]
# trial_preVSd2_d2_Rew[dhpc35][31] []
# deleted autocorr_trial_preVSd2_d2_Rew[dhpc35][31]
# trial_preVSd2_d2_Rew[dhpc35][34] []
# deleted autocorr_trial_preVSd2_d2_Rew[dhpc35][34]
# trial_preVSd2_d2_Rew[dhpc36][20] []
# deleted autocorr_trial_preVSd2_d2_Rew[dhpc36][20]
# trial_preVSd2_d2_Rew[dhpcg1][130] []
# deleted autocorr_trial_preVSd2_d2_Rew[dhpcg1][130]
# trial_preVSd2_d2_Rew[dhpcg1][146] []
# deleted autocorr_trial_preVSd2_d2_Rew[dhpcg1][146]
# trial_preVSext1_pre_Rew[dhpc35][24] []
# deleted autocorr_trial_preVSext1_pre_Rew[dhpc35][24]
# trial_preVSext1_pre_Rew[dhpc36][19] []
# deleted autocorr_trial_preVSext1_pre_Rew[dhpc36][19]
# trial_preVSext2_pre_Rew[dhpc35][27] []
# deleted autocorr_trial_preVSext2_pre_Rew[dhpc35][27]
# trial_preVSext2_pre_Rew[dhpc35][29] []
# deleted autocorr_trial_preVSext2_pre_Rew[dhpc35][29]
# trial_preVSext2_ext2_Rew[dhpc36][12] []
# deleted autocorr_trial_preVSext2_ext2_Rew[dhpc36][12]
# trial_preVSrenew_pre_Rew[dhpc35][20] []
# deleted autocorr_trial_preVSrenew_pre_Rew[dhpc35][20]
# trial_preVSrenew_pre_Rew[dhpc36][13] []
# deleted autocorr_trial_preVSrenew_pre_Rew[dhpc36][13]
# trial_preVSrenew_renew_Rew[dhpc35][2] []
# deleted autocorr_trial_preVSrenew_renew_Rew[dhpc35][2]
# trial_preVSrenew_renew_Rew[dhpc35][2] []
# deleted autocorr_trial_preVSrenew_renew_Rew[dhpc35][2]
# trial_preVSrenew_renew_Rew[dhpc35][19] []
# deleted autocorr_trial_preVSrenew_renew_Rew[dhpc35][19]
# trial_preVSrenew_renew_Rew[dhpc36][1] []
# deleted autocorr_trial_preVSrenew_renew_Rew[dhpc36][1]
# trial_preVSrenew_renew_Rew[dhpc36][5] []
# deleted autocorr_trial_preVSrenew_renew_Rew[dhpc36][5]
# trial_preVSrenew_renew_Rew[dhpc36][8] []
# deleted autocorr_trial_preVSrenew_renew_Rew[dhpc36][8]
# trial_d2VSpost_d2_Rew[dhpc35][23] []
# deleted autocorr_trial_d2VSpost_d2_Rew[dhpc35][23]
# trial_d2VSpost_d2_Rew[dhpc35][26] []
# deleted autocorr_trial_d2VSpost_d2_Rew[dhpc35][26]
# trial_d2VSpost_d2_Rew[dhpc36][32] []
# deleted autocorr_trial_d2VSpost_d2_Rew[dhpc36][32]
# trial_d2VSpost_d2_Rew[dhpc36][45] []
# deleted autocorr_trial_d2VSpost_d2_Rew[dhpc36][45]
# trial_d2VSpost_d2_Rew[dhpc36][48] []
# deleted autocorr_trial_d2VSpost_d2_Rew[dhpc36][48]
# trial_d2VSpost_d2_Rew[dhpcg1][7] []
# deleted autocorr_trial_d2VSpost_d2_Rew[dhpcg1][7]
# trial_d2VSpost_d2_Rew[dhpcg1][105] []
# deleted autocorr_trial_d2VSpost_d2_Rew[dhpcg1][105]
# trial_d2VSpost_d2_Rew[dhpcg1][129] []
# deleted autocorr_trial_d2VSpost_d2_Rew[dhpcg1][129]
# trial_d2VSpost_post_Rew[dhpc35][19] []
# deleted autocorr_trial_d2VSpost_post_Rew[dhpc35][19]
# trial_d2VSpost_post_Rew[dhpc36][7] []
# deleted autocorr_trial_d2VSpost_post_Rew[dhpc36][7]
# trial_d2VSpost_post_Rew[dhpc36][47] []
# deleted autocorr_trial_d2VSpost_post_Rew[dhpc36][47]
# trial_d2VSext1_d2_Rew[dhpc35][22] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc35][22]
# trial_d2VSext1_d2_Rew[dhpc35][25] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc35][25]
# trial_d2VSext1_d2_Rew[dhpc36][27] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc36][27]
# trial_d2VSext1_d2_Rew[dhpc36][36] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc36][36]
# trial_d2VSext1_d2_Rew[dhpc36][39] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc36][39]
# trial_d2VSext1_d2_Rew[dhpc36][42] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc36][42]
# trial_d2VSext1_d2_Rew[dhpc36][42] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc36][42]
# trial_d2VSext1_d2_Rew[dhpc36][45] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc36][45]
# trial_d2VSext1_d2_Rew[dhpc36][45] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpc36][45]
# trial_d2VSext1_d2_Rew[dhpcg1][8] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpcg1][8]
# trial_d2VSext1_d2_Rew[dhpcg1][112] []
# deleted autocorr_trial_d2VSext1_d2_Rew[dhpcg1][112]
# trial_d2VSext2_d2_Rew[dhpc35][17] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpc35][17]
# trial_d2VSext2_d2_Rew[dhpc36][27] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpc36][27]
# trial_d2VSext2_d2_Rew[dhpc36][39] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpc36][39]
# trial_d2VSext2_d2_Rew[dhpc36][42] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpc36][42]
# trial_d2VSext2_d2_Rew[dhpc36][46] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpc36][46]
# trial_d2VSext2_d2_Rew[dhpc36][46] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpc36][46]
# trial_d2VSext2_d2_Rew[dhpc36][47] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpc36][47]
# trial_d2VSext2_d2_Rew[dhpc36][51] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpc36][51]
# trial_d2VSext2_d2_Rew[dhpcg1][5] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpcg1][5]
# trial_d2VSext2_d2_Rew[dhpcg1][101] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpcg1][101]
# trial_d2VSext2_d2_Rew[dhpcg1][123] []
# deleted autocorr_trial_d2VSext2_d2_Rew[dhpcg1][123]
# trial_d2VSext2_ext2_Rew[dhpc36][51] []
# deleted autocorr_trial_d2VSext2_ext2_Rew[dhpc36][51]
# trial_d2VSext2_ext2_Rew[dhpc36][52] []
# deleted autocorr_trial_d2VSext2_ext2_Rew[dhpc36][52]
# trial_d2VSrenew_d2_Rew[dhpc35][28] []
# deleted autocorr_trial_d2VSrenew_d2_Rew[dhpc35][28]
# trial_d2VSrenew_d2_Rew[dhpc36][27] []
# deleted autocorr_trial_d2VSrenew_d2_Rew[dhpc36][27]
# trial_d2VSrenew_d2_Rew[dhpc36][42] []
# deleted autocorr_trial_d2VSrenew_d2_Rew[dhpc36][42]
# trial_d2VSrenew_d2_Rew[dhpc36][42] []
# deleted autocorr_trial_d2VSrenew_d2_Rew[dhpc36][42]
# trial_d2VSrenew_d2_Rew[dhpc36][43] []
# deleted autocorr_trial_d2VSrenew_d2_Rew[dhpc36][43]
# trial_d2VSrenew_d2_Rew[dhpc36][43] []
# deleted autocorr_trial_d2VSrenew_d2_Rew[dhpc36][43]
# trial_d2VSrenew_d2_Rew[dhpc36][47] []
# deleted autocorr_trial_d2VSrenew_d2_Rew[dhpc36][47]
# trial_d2VSrenew_renew_Rew[dhpc35][1] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc35][1]
# trial_d2VSrenew_renew_Rew[dhpc35][4] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc35][4]
# trial_d2VSrenew_renew_Rew[dhpc35][13] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc35][13]
# trial_d2VSrenew_renew_Rew[dhpc35][24] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc35][24]
# trial_d2VSrenew_renew_Rew[dhpc36][19] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc36][19]
# trial_d2VSrenew_renew_Rew[dhpc36][26] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc36][26]
# trial_d2VSrenew_renew_Rew[dhpc36][45] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc36][45]
# trial_d2VSrenew_renew_Rew[dhpc36][45] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc36][45]
# trial_d2VSrenew_renew_Rew[dhpc36][47] []
# deleted autocorr_trial_d2VSrenew_renew_Rew[dhpc36][47]
# trial_postVSext1_post_Rew[dhpc35][23] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpc35][23]
# trial_postVSext1_post_Rew[dhpc35][25] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpc35][25]
# trial_postVSext1_post_Rew[dhpc35][33] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpc35][33]
# trial_postVSext1_post_Rew[dhpc35][47] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpc35][47]
# trial_postVSext1_post_Rew[dhpc35][48] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpc35][48]
# trial_postVSext1_post_Rew[dhpc36][50] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpc36][50]
# trial_postVSext1_post_Rew[dhpc36][51] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpc36][51]
# trial_postVSext1_post_Rew[dhpc36][52] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpc36][52]
# trial_postVSext1_post_Rew[dhpcg1][132] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpcg1][132]
# trial_postVSext1_post_Rew[dhpcg1][147] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpcg1][147]
# trial_postVSext1_post_Rew[dhpcg1][190] []
# deleted autocorr_trial_postVSext1_post_Rew[dhpcg1][190]
# trial_postVSext2_post_Rew[dhpc35][20] []
# deleted autocorr_trial_postVSext2_post_Rew[dhpc35][20]
# trial_postVSext2_post_Rew[dhpc35][21] []
# deleted autocorr_trial_postVSext2_post_Rew[dhpc35][21]
# trial_postVSext2_post_Rew[dhpc35][28] []
# deleted autocorr_trial_postVSext2_post_Rew[dhpc35][28]
# trial_postVSext2_post_Rew[dhpc35][39] []
# deleted autocorr_trial_postVSext2_post_Rew[dhpc35][39]
# trial_postVSext2_post_Rew[dhpc35][40] []
# deleted autocorr_trial_postVSext2_post_Rew[dhpc35][40]
# trial_postVSext2_post_Rew[dhpc36][48] []
# deleted autocorr_trial_postVSext2_post_Rew[dhpc36][48]
# trial_postVSext2_post_Rew[dhpc36][50] []
# deleted autocorr_trial_postVSext2_post_Rew[dhpc36][50]
# trial_postVSext2_ext2_Rew[dhpc36][14] []
# deleted autocorr_trial_postVSext2_ext2_Rew[dhpc36][14]
# trial_postVSrenew_post_Rew[dhpc35][25] []
# deleted autocorr_trial_postVSrenew_post_Rew[dhpc35][25]
# trial_postVSrenew_post_Rew[dhpc35][27] []
# deleted autocorr_trial_postVSrenew_post_Rew[dhpc35][27]
# trial_postVSrenew_post_Rew[dhpc35][31] []
# deleted autocorr_trial_postVSrenew_post_Rew[dhpc35][31]
# trial_postVSrenew_post_Rew[dhpc35][41] []
# deleted autocorr_trial_postVSrenew_post_Rew[dhpc35][41]
# trial_postVSrenew_post_Rew[dhpc35][42] []
# deleted autocorr_trial_postVSrenew_post_Rew[dhpc35][42]
# trial_postVSrenew_post_Rew[dhpc35][42] []
# deleted autocorr_trial_postVSrenew_post_Rew[dhpc35][42]
# trial_postVSrenew_post_Rew[dhpc36][56] []
# deleted autocorr_trial_postVSrenew_post_Rew[dhpc36][56]
# trial_postVSrenew_post_Rew[dhpc36][57] []
# deleted autocorr_trial_postVSrenew_post_Rew[dhpc36][57]
# trial_postVSrenew_renew_Rew[dhpc35][9] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc35][9]
# trial_postVSrenew_renew_Rew[dhpc35][15] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc35][15]
# trial_postVSrenew_renew_Rew[dhpc35][19] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc35][19]
# trial_postVSrenew_renew_Rew[dhpc35][30] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc35][30]
# trial_postVSrenew_renew_Rew[dhpc35][41] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc35][41]
# trial_postVSrenew_renew_Rew[dhpc35][41] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc35][41]
# trial_postVSrenew_renew_Rew[dhpc36][21] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc36][21]
# trial_postVSrenew_renew_Rew[dhpc36][49] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc36][49]
# trial_postVSrenew_renew_Rew[dhpc36][53] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc36][53]
# trial_postVSrenew_renew_Rew[dhpc36][53] []
# deleted autocorr_trial_postVSrenew_renew_Rew[dhpc36][53]
# trial_ext1VSext2_ext2_Rew[dhpc36][30] []
# deleted autocorr_trial_ext1VSext2_ext2_Rew[dhpc36][30]
# trial_ext1VSext2_ext2_Rew[dhpc36][61] []
# deleted autocorr_trial_ext1VSext2_ext2_Rew[dhpc36][61]
# trial_ext1VSrenew_ext1_Rew[dhpc36][53] []
# deleted autocorr_trial_ext1VSrenew_ext1_Rew[dhpc36][53]
# trial_ext1VSrenew_renew_Rew[dhpc35][0] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc35][0]
# trial_ext1VSrenew_renew_Rew[dhpc35][6] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc35][6]
# trial_ext1VSrenew_renew_Rew[dhpc35][15] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc35][15]
# trial_ext1VSrenew_renew_Rew[dhpc35][22] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc35][22]
# trial_ext1VSrenew_renew_Rew[dhpc35][25] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc35][25]
# trial_ext1VSrenew_renew_Rew[dhpc35][38] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc35][38]
# trial_ext1VSrenew_renew_Rew[dhpc35][40] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc35][40]
# trial_ext1VSrenew_renew_Rew[dhpc36][14] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc36][14]
# trial_ext1VSrenew_renew_Rew[dhpc36][25] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc36][25]
# trial_ext1VSrenew_renew_Rew[dhpc36][38] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc36][38]
# trial_ext1VSrenew_renew_Rew[dhpc36][51] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpc36][51]
# trial_ext1VSrenew_renew_Rew[dhpcg20][79] []
# deleted autocorr_trial_ext1VSrenew_renew_Rew[dhpcg20][79]
# trial_ext2VSrenew_ext2_Rew[dhpc36][44] []
# deleted autocorr_trial_ext2VSrenew_ext2_Rew[dhpc36][44]
# trial_ext2VSrenew_ext2_Rew[dhpc36][45] []
# deleted autocorr_trial_ext2VSrenew_ext2_Rew[dhpc36][45]
# trial_ext2VSrenew_renew_Rew[dhpc35][3] []
# deleted autocorr_trial_ext2VSrenew_renew_Rew[dhpc35][3]
# trial_ext2VSrenew_renew_Rew[dhpc36][20] []
# deleted autocorr_trial_ext2VSrenew_renew_Rew[dhpc36][20]
# trial_ext2VSrenew_renew_Rew[dhpc36][26] []
# deleted autocorr_trial_ext2VSrenew_renew_Rew[dhpc36][26]
# trial_ext2VSrenew_renew_Rew[dhpc36][41] []
# deleted autocorr_trial_ext2VSrenew_renew_Rew[dhpc36][41]
# trial_ext2VSrenew_renew_Rew[dhpc36][41] []
# deleted autocorr_trial_ext2VSrenew_renew_Rew[dhpc36][41]
# trial_ext2VSrenew_renew_Rew[dhpcg20][66] []
# deleted autocorr_trial_ext2VSrenew_renew_Rew[dhpcg20][66]
# trial_preVSpost_post_CSm[dhpc36][4] []
# deleted autocorr_trial_preVSpost_post_CSm[dhpc36][4]
# trial_preVSpost_post_CSm[dhpc36][6] []
# deleted autocorr_trial_preVSpost_post_CSm[dhpc36][6]
# trial_preVSd2_d2_CSm[dhpc36][2] []
# deleted autocorr_trial_preVSd2_d2_CSm[dhpc36][2]
# trial_preVSext1_ext1_CSm[dhpc36][17] []
# deleted autocorr_trial_preVSext1_ext1_CSm[dhpc36][17]
# trial_preVSrenew_pre_CSm[dhpc36][9] []
# deleted autocorr_trial_preVSrenew_pre_CSm[dhpc36][9]
# trial_d2VSpost_post_CSm[dhpc36][24] []
# deleted autocorr_trial_d2VSpost_post_CSm[dhpc36][24]
# trial_d2VSpost_post_CSm[dhpc36][42] []
# deleted autocorr_trial_d2VSpost_post_CSm[dhpc36][42]
# trial_d2VSext1_d2_CSm[dhpc36][51] []
# deleted autocorr_trial_d2VSext1_d2_CSm[dhpc36][51]
# trial_d2VSrenew_d2_CSm[dhpc36][52] []
# deleted autocorr_trial_d2VSrenew_d2_CSm[dhpc36][52]
# trial_d2VSrenew_d2_CSm[dhpc36][52] []
# deleted autocorr_trial_d2VSrenew_d2_CSm[dhpc36][52]
# trial_postVSext1_post_CSm[dhpc36][43] []
# deleted autocorr_trial_postVSext1_post_CSm[dhpc36][43]
# trial_postVSext1_post_CSm[dhpc36][51] []
# deleted autocorr_trial_postVSext1_post_CSm[dhpc36][51]
# trial_postVSext2_post_CSm[dhpc36][39] []
# deleted autocorr_trial_postVSext2_post_CSm[dhpc36][39]
# trial_postVSext2_post_CSm[dhpc36][47] []
# deleted autocorr_trial_postVSext2_post_CSm[dhpc36][47]
# trial_postVSrenew_post_CSm[dhpc36][58] []
# deleted autocorr_trial_postVSrenew_post_CSm[dhpc36][58]
# trial_postVSrenew_post_CSm[dhpc36][62] []
# deleted autocorr_trial_postVSrenew_post_CSm[dhpc36][62]
# trial_postVSrenew_renew_CSm[dhpcg20][43] []
# deleted autocorr_trial_postVSrenew_renew_CSm[dhpcg20][43]
# trial_ext1VSrenew_ext1_CSm[dhpc35][46] []
# deleted autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][46]
# trial_ext1VSrenew_ext1_CSm[dhpc36][57] []
# deleted autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][57]
# trial_ext1VSrenew_renew_CSm[dhpc36][57] []
# deleted autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][57]
# trial_ext1VSrenew_renew_CSm[dhpcg20][106] []
# deleted autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][106]
# trial_ext2VSrenew_renew_CSm[dhpc36][45] []
# deleted autocorr_trial_ext2VSrenew_renew_CSm[dhpc36][45]
# trial_ext2VSrenew_renew_CSm[dhpcg20][40] []
# deleted autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][40]

# %%
#check to make sure all empty cells have been removed. NOTHING SHOULD PRINT OUT.
for epoch in ['base','trial']:
    for tt in ['Rew','CSm']:
        for pair in pairs:
            for pos in range(2):
                for ani in eval("autocorr_%s_%s_%s_%s_evs.keys()"%(epoch,pair,pair.split('VS')[pos],tt)):
                    for y in range(len(eval("autocorr_%s_%s_%s_%s_evs[ani]"%(epoch,pair,pair.split('VS')[pos],tt)))):
                        if np.mean(eval("autocorr_%s_%s_%s_%s_evs[ani][y]"%(epoch,pair,pair.split('VS')[pos],tt))) >= 0.0000000001:
                            i=0 # just a random operation to fulfill the requirement to do "something" here
                        else:
                            print epoch,pair,pair.split('VS')[pos],tt,ani,y

# %%
# %%time
#get the means for each level of anlaysis (trials, cells, animals)
for epoch in ['base','trial']:
    for tt in ['Rew','CSm']:
        for pair in pairs:
            for pos in range(2):
                print 'working on %s %s %s %s   '%(epoch,pair,pair.split('VS')[pos],tt),
                exec("autocorr_meanoftrials_%s_%s_%s_%s_evs={}"%(epoch,pair,pair.split('VS')[pos],tt))
                exec("autocorr_meanofcells_%s_%s_%s_%s_evs=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                for ani in eval("all_amps_%s_%s_%s_evs.keys()"%(pair,pair.split('VS')[pos],tt)):
                    exec("autocorr_meanoftrials_%s_%s_%s_%s_evs[ani]=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                    for cell in range(len(eval("autocorr_%s_%s_%s_%s_evs[ani]"%(epoch,pair,pair.split('VS')[pos],tt)))):
                #only include cells that have some activity
                        if np.mean(eval("autocorr_%s_%s_%s_%s_evs[ani][cell]"%(epoch,pair,pair.split('VS')[pos],tt)))>0:
                #for each cell, get the mean over all trials
                            exec("autocorr_meanoftrials_%s_%s_%s_%s_evs[ani].append(np.mean(autocorr_%s_%s_%s_%s_evs[ani][cell],0))"%(epoch,
                                                               pair,pair.split('VS')[pos],tt,epoch,pair,pair.split('VS')[pos],tt))
                #for each animal, take the mean of all cells
                        if np.mean(eval("autocorr_%s_%s_%s_%s_evs[ani][cell]"%(epoch,pair,pair.split('VS')[pos],tt)))>0: 
                            exec("autocorr_meanofcells_%s_%s_%s_%s_evs.append(np.mean(autocorr_meanoftrials_%s_%s_%s_%s_evs[ani],0))"%(epoch,
                                                               pair,pair.split('VS')[pos],tt,epoch,pair,pair.split('VS')[pos],tt))
                #get the mean of the whole pseudopopulation
                    exec("autocorr_overallmean_%s_%s_%s_%s_evs = np.mean(autocorr_meanofcells_%s_%s_%s_%s_evs,0)"%(epoch,
                                                               pair,pair.split('VS')[pos],tt,epoch,pair,pair.split('VS')[pos],tt))
# Out:
# working on base preVSpost pre Rew    working on base preVSpost post Rew    working on base preVSd2 pre Rew    working on base preVSd2 d2 Rew    working on base preVSext1 pre Rew    working on base preVSext1 ext1 Rew    working on base preVSext2 pre Rew    working on base preVSext2 ext2 Rew    working on base preVSrenew pre Rew    working on base preVSrenew renew Rew    working on base d2VSpost d2 Rew    working on base d2VSpost post Rew    working on base d2VSext1 d2 Rew    working on base d2VSext1 ext1 Rew    working on base d2VSext2 d2 Rew    working on base d2VSext2 ext2 Rew    working on base d2VSrenew d2 Rew    working on base d2VSrenew renew Rew    working on base postVSext1 post Rew    working on base postVSext1 ext1 Rew    working on base postVSext2 post Rew    working on base postVSext2 ext2 Rew    working on base postVSrenew post Rew    working on base postVSrenew renew Rew    working on base ext1VSext2 ext1 Rew    working on base ext1VSext2 ext2 Rew    working on base ext1VSrenew ext1 Rew    working on base ext1VSrenew renew Rew    working on base ext2VSrenew ext2 Rew    working on base ext2VSrenew renew Rew    working on base preVSpost pre CSm    working on base preVSpost post CSm    working on base preVSd2 pre CSm    working on base preVSd2 d2 CSm    working on base preVSext1 pre CSm    working on base preVSext1 ext1 CSm    working on base preVSext2 pre CSm    working on base preVSext2 ext2 CSm    working on base preVSrenew pre CSm    working on base preVSrenew renew CSm    working on base d2VSpost d2 CSm    working on base d2VSpost post CSm    working on base d2VSext1 d2 CSm    working on base d2VSext1 ext1 CSm    working on base d2VSext2 d2 CSm    working on base d2VSext2 ext2 CSm    working on base d2VSrenew d2 CSm    working on base d2VSrenew renew CSm    working on base postVSext1 post CSm    working on base postVSext1 ext1 CSm    working on base postVSext2 post CSm    working on base postVSext2 ext2 CSm    working on base postVSrenew post CSm    working on base postVSrenew renew CSm    working on base ext1VSext2 ext1 CSm    working on base ext1VSext2 ext2 CSm    working on base ext1VSrenew ext1 CSm    working on base ext1VSrenew renew CSm    working on base ext2VSrenew ext2 CSm    working on base ext2VSrenew renew CSm    working on trial preVSpost pre Rew    working on trial preVSpost post Rew    working on trial preVSd2 pre Rew    working on trial preVSd2 d2 Rew    working on trial preVSext1 pre Rew    working on trial preVSext1 ext1 Rew    working on trial preVSext2 pre Rew    working on trial preVSext2 ext2 Rew    working on trial preVSrenew pre Rew    working on trial preVSrenew renew Rew    working on trial d2VSpost d2 Rew    working on trial d2VSpost post Rew    working on trial d2VSext1 d2 Rew    working on trial d2VSext1 ext1 Rew    working on trial d2VSext2 d2 Rew    working on trial d2VSext2 ext2 Rew    working on trial d2VSrenew d2 Rew    working on trial d2VSrenew renew Rew    working on trial postVSext1 post Rew    working on trial postVSext1 ext1 Rew    working on trial postVSext2 post Rew    working on trial postVSext2 ext2 Rew    working on trial postVSrenew post Rew    working on trial postVSrenew renew Rew    working on trial ext1VSext2 ext1 Rew    working on trial ext1VSext2 ext2 Rew    working on trial ext1VSrenew ext1 Rew    working on trial ext1VSrenew renew Rew    working on trial ext2VSrenew ext2 Rew    working on trial ext2VSrenew renew Rew    working on trial preVSpost pre CSm    working on trial preVSpost post CSm    working on trial preVSd2 pre CSm    working on trial preVSd2 d2 CSm    working on trial preVSext1 pre CSm    working on trial preVSext1 ext1 CSm    working on trial preVSext2 pre CSm    working on trial preVSext2 ext2 CSm    working on trial preVSrenew pre CSm    working on trial preVSrenew renew CSm    working on trial d2VSpost d2 CSm    working on trial d2VSpost post CSm    working on trial d2VSext1 d2 CSm    working on trial d2VSext1 ext1 CSm    working on trial d2V ...
# Wall time: 9.21 s

# %%
for x in autocorr_meanoftrials_trial_preVSpost_post_Rew_evs.keys():
    for y in range(len(autocorr_meanoftrials_trial_preVSpost_post_Rew_evs[x])):
        pl.plot(autocorr_meanoftrials_trial_preVSpost_post_Rew_evs[x][y])

# %%
def monoExp(x, m, t, b):
    return m * np.exp(-t * x) + b

import scipy.optimize

xs = np.linspace(0,16,16) # lag of 20 bins
ys = autocorr_overallmean_trial_preVSpost_post_Rew_evs[17:33]

# perform the fit
p0 = (1,0,0) # start with values near those we expect (starting value, starting x bin, ending value (decays to what?))
params, cv = scipy.optimize.curve_fit(monoExp, xs, ys, p0)
m, t, b = params
sampleRate = 3.75 # Hz
tauSec = (1 / t) / sampleRate

# determine quality of the fit
squaredDiffs = np.square(ys - monoExp(xs, m, t, b))
squaredDiffsFromMean = np.square(ys - np.mean(ys))
rSquared = 1 - np.sum(squaredDiffs) / np.sum(squaredDiffsFromMean)
print "R² =", rSquared

# plot the results
pl.plot(xs, ys, '.', label="data")
pl.plot(xs, monoExp(xs, m, t, b), '--', label="fitted")
pl.title("Fitted Exponential Curve")

# inspect the parameters
print "Y =", m, "* e^(",-t,"* x) +", b
print "Tau =", tauSec, "sec"
# Out:
# R² = 0.995229161459
# Y = 0.979980051257 * e^( -1.44575364367 * x) + 0.0174289690407
# Tau = 0.184448206535 sec

# %%
#fit each cell's autocorrelation with an exponential decay function. Store the R2 and the tau time constant (t) for comparison later

def monoExp(x, m, t, b):
    return m * np.exp(-t * x) + b

import scipy.optimize

n=0
xs = np.linspace(0,16,16) # lag of 20 bins
p0 = (1,0.25,0) # start with values near those we expect (starting value, starting x bin, ending value (decays to what?))
sampleRate = 3.75 # Hz

for epoch in ['base','trial']:
    for tt in ['CSm','Rew']:
        for pair in pairs:
            for pos in range(2):
                exec("decay_%s_%s_%s_%s = {}"%(epoch,pair,pair.split('VS')[pos],tt))
                exec("decay_%s_%s_%s_%s['r2']=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                exec("decay_%s_%s_%s_%s['tau']=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                print 'working on %s %s %s_%s   '%(epoch,pair,pair.split('VS')[pos],tt),
                for x in range(len(eval("autocorr_meanofcells_%s_%s_%s_%s_evs"%(epoch,pair,pair.split('VS')[pos],tt)))):
                    ys =eval("autocorr_meanofcells_%s_%s_%s_%s_evs[x][17:33]"%(epoch,pair,pair.split('VS')[pos],tt))
                    try:
                        # perform the fit
                        params, cv = scipy.optimize.curve_fit(monoExp, xs, ys, p0)
                        m, t, b = params
                        tauSec = (1 / t) / sampleRate
                        
                        # determine quality of the fit
                        squaredDiffs = np.square(ys - monoExp(xs, m, t, b))
                        squaredDiffsFromMean = np.square(ys - np.mean(ys))
                        rSquared = 1 - np.sum(squaredDiffs) / np.sum(squaredDiffsFromMean)
                        exec("decay_%s_%s_%s_%s['r2'].append(rSquared)"%(epoch,pair,pair.split('VS')[pos],tt))
                        exec("decay_%s_%s_%s_%s['tau'].append(t)"%(epoch,pair,pair.split('VS')[pos],tt))
                    except:
                        print "skip cell",x
                        n=n+1
print "\nskipped",n,"cells"
# Out:
# working on base preVSpost pre_CSm    working on base preVSpost post_CSm    skip cell 26
# working on base preVSd2 pre_CSm    working on base preVSd2 d2_CSm    working on base preVSext1 pre_CSm    working on base preVSext1 ext1_CSm    working on base preVSext2 pre_CSm    working on base preVSext2 ext2_CSm    working on base preVSrenew pre_CSm    working on base preVSrenew renew_CSm    working on base d2VSpost d2_CSm    working on base d2VSpost post_CSm    working on base d2VSext1 d2_CSm    skip cell 0
# working on base d2VSext1 ext1_CSm    working on base d2VSext2 d2_CSm    skip cell 0
# working on base d2VSext2 ext2_CSm    working on base d2VSrenew d2_CSm    working on base d2VSrenew renew_CSm    working on base postVSext1 post_CSm    working on base postVSext1 ext1_CSm    working on base postVSext2 post_CSm    working on base postVSext2 ext2_CSm    working on base postVSrenew post_CSm    working on base postVSrenew renew_CSm    working on base ext1VSext2 ext1_CSm    working on base ext1VSext2 ext2_CSm    working on base ext1VSrenew ext1_CSm    working on base ext1VSrenew renew_CSm    skip cell 0
# working on base ext2VSrenew ext2_CSm    working on base ext2VSrenew renew_CSm    working on base preVSpost pre_Rew    working on base preVSpost post_Rew    skip cell 26
# working on base preVSd2 pre_Rew    working on base preVSd2 d2_Rew    working on base preVSext1 pre_Rew    working on base preVSext1 ext1_Rew    working on base preVSext2 pre_Rew    working on base preVSext2 ext2_Rew    working on base preVSrenew pre_Rew    working on base preVSrenew renew_Rew    working on base d2VSpost d2_Rew    working on base d2VSpost post_Rew    working on base d2VSext1 d2_Rew    working on base d2VSext1 ext1_Rew    working on base d2VSext2 d2_Rew    working on base d2VSext2 ext2_Rew    skip cell 0
# working on base d2VSrenew d2_Rew    working on base d2VSrenew renew_Rew    working on base postVSext1 post_Rew    working on base postVSext1 ext1_Rew    working on base postVSext2 post_Rew    working on base postVSext2 ext2_Rew    working on base postVSrenew post_Rew    working on base postVSrenew renew_Rew    working on base ext1VSext2 ext1_Rew    working on base ext1VSext2 ext2_Rew    working on base ext1VSrenew ext1_Rew    working on base ext1VSrenew renew_Rew    skip cell 0
# working on base ext2VSrenew ext2_Rew    working on base ext2VSrenew renew_Rew    working on trial preVSpost pre_CSm    working on trial preVSpost post_CSm    working on trial preVSd2 pre_CSm    working on trial preVSd2 d2_CSm    working on trial preVSext1 pre_CSm    working on trial preVSext1 ext1_CSm    working on trial preVSext2 pre_CSm    working on trial preVSext2 ext2_CSm    working on trial preVSrenew pre_CSm    working on trial preVSrenew renew_CSm    working on trial d2VSpost d2_CSm    working on trial d2VSpost post_CSm    working on trial d2VSext1 d2_CSm    working on trial d2VSext1 ext1_CSm    working on trial d2VSext2 d2_CSm    working on trial d2VSext2 ext2_CSm    working on trial d2VSrenew d2_CSm    working on trial d2VSrenew renew_CSm    working on trial postVSext1 post_CSm    working on trial postVSext1 ext1_CSm    working on trial postVSext2 post_CSm    working on trial postVSext2 ext2_CSm    working on trial postVSrenew post_CSm    working on trial postVSrenew renew_CSm    working on trial ext1VSext2 ext1_CSm    working on trial ext1VSext2 ext2_CSm    working on trial ext1VSrenew ext1_CSm    working on trial ext1VSrenew renew_CSm    skip cell 0
# working on trial ext2VSrenew ext2_CSm    working on trial ext2VSrenew renew_CSm    working on trial preVSpost pre_Rew    working on trial preVSpost post_Rew    working on trial preVSd2 pre_Rew    working on trial preVSd2 d2_Rew    working on trial preVSext1 pre_Rew    working on trial preVSext1 ext1_Rew    working on trial preVSext2 pre_Rew    working on trial preVSext2 ext2_Rew    working on trial preVSrenew pre_Rew    working on trial preVSrenew renew_Rew    working on trial d2VSpost d2_Rew    working on trial d2VSpost post_Rew    working on trial d2VSext1 d2_Rew    working on trial d2VSext1 ext1_Rew    working on trial d2VSext2 d2_Rew    working on trial d2VSext2 ext2_Rew    working on trial d2VSrenew d2_Rew    working on trial d2VSrenew renew_Rew    skip cell 0
# working on trial postVSext1 post_Rew    working on trial postVSext1 ext1_Rew    working on trial postVSext2 post_Rew    working on trial postVSext2 ext2_Rew    working on trial postVSrenew post_Rew    working on trial postVSrenew renew_Rew    working on trial ext1VSext2 ext1_Rew    working on trial ext1VSext2 ext2_Rew    working on trial ext1VSrenew ext1_Rew    working on trial ext1VSrenew renew_Rew    working on trial ext2VSrenew ext2_Rew    working on trial ext2VSrenew renew_Rew
# skipped 9 cells

# %%
#method that didn't work

#import statsmodels.api as sm
#from statsmodels.graphics.tsaplots import plot_acf

##calculate autocorrelations
#sm.tsa.acf(all_amps_d2_CSm_evs[0][0][0])

# %% [markdown]
# # Now same analysis, but only using first 15 trials of each trial type (to n-match expo session)

# %%
# %%time
#get first15_autocorrelation of first 15 trials, for every cell, for every animal
for epoch in ['base','trial']:
    for tt in ['Rew','CSm']:
        for pair in pairs:
            for pos in range(2):
                print 'working on %s %s %s %s  '%(epoch,pair,pair.split('VS')[pos],tt),
                exec("first15_autocorr_%s_%s_%s_%s_evs={}"%(epoch,pair,pair.split('VS')[pos],tt))
                for ani in eval("all_amps_%s_%s_%s_evs.keys()"%(pair,pair.split('VS')[pos],tt)):
                    exec("first15_autocorr_%s_%s_%s_%s_evs[ani]=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                    for cell in range(len(eval("all_amps_%s_%s_%s_evs[ani]"%(pair,pair.split('VS')[pos],tt)))):
                        exec("first15_autocorr_%s_%s_%s_%s_evs[ani].append([])"%(epoch,pair,pair.split('VS')[pos],tt))
                        for trial in range(15):
                            # don't include trials where cell didn't fire
                            if np.mean(eval("%s_%s_%s_%s_evs[ani][cell][trial]"%(epoch,pair,pair.split('VS')[pos],tt))) > 0:
                                exec("ac = np.correlate(%s_%s_%s_%s_evs[ani][cell][trial],%s_%s_%s_%s_evs[ani][cell][trial],mode='full')"%(epoch,pair,pair.split('VS')[pos],tt,epoch,pair,pair.split('VS')[pos],tt))
                                # throw away distant time lag comparisons (only keep middle 35). This is also necessary to standardize the no. of tbs across animals
                                ta = len(eval("%s_%s_%s_%s_evs[ani][cell][trial]"%(epoch,pair,pair.split('VS')[pos],tt))) - 18
                                exec("first15_autocorr_%s_%s_%s_%s_evs[ani][cell].append((ac/np.max(ac))[ta:-ta])"%(epoch,pair,pair.split('VS')[pos],tt))
first_run=True
# Out:
# working on base preVSpost pre Rew   working on base preVSpost post Rew   working on base preVSd2 pre Rew   working on base preVSd2 d2 Rew   working on base preVSext1 pre Rew   working on base preVSext1 ext1 Rew   working on base preVSext2 pre Rew   working on base preVSext2 ext2 Rew   working on base preVSrenew pre Rew   working on base preVSrenew renew Rew   working on base d2VSpost d2 Rew   working on base d2VSpost post Rew   working on base d2VSext1 d2 Rew   working on base d2VSext1 ext1 Rew   working on base d2VSext2 d2 Rew   working on base d2VSext2 ext2 Rew   working on base d2VSrenew d2 Rew   working on base d2VSrenew renew Rew   working on base postVSext1 post Rew   working on base postVSext1 ext1 Rew   working on base postVSext2 post Rew   working on base postVSext2 ext2 Rew   working on base postVSrenew post Rew   working on base postVSrenew renew Rew   working on base ext1VSext2 ext1 Rew   working on base ext1VSext2 ext2 Rew   working on base ext1VSrenew ext1 Rew   working on base ext1VSrenew renew Rew   working on base ext2VSrenew ext2 Rew   working on base ext2VSrenew renew Rew   working on base preVSpost pre CSm   working on base preVSpost post CSm   working on base preVSd2 pre CSm   working on base preVSd2 d2 CSm   working on base preVSext1 pre CSm   working on base preVSext1 ext1 CSm   working on base preVSext2 pre CSm   working on base preVSext2 ext2 CSm   working on base preVSrenew pre CSm   working on base preVSrenew renew CSm   working on base d2VSpost d2 CSm   working on base d2VSpost post CSm   working on base d2VSext1 d2 CSm   working on base d2VSext1 ext1 CSm   working on base d2VSext2 d2 CSm   working on base d2VSext2 ext2 CSm   working on base d2VSrenew d2 CSm   working on base d2VSrenew renew CSm   working on base postVSext1 post CSm   working on base postVSext1 ext1 CSm   working on base postVSext2 post CSm   working on base postVSext2 ext2 CSm   working on base postVSrenew post CSm   working on base postVSrenew renew CSm   working on base ext1VSext2 ext1 CSm   working on base ext1VSext2 ext2 CSm   working on base ext1VSrenew ext1 CSm   working on base ext1VSrenew renew CSm   working on base ext2VSrenew ext2 CSm   working on base ext2VSrenew renew CSm   working on trial preVSpost pre Rew   working on trial preVSpost post Rew   working on trial preVSd2 pre Rew   working on trial preVSd2 d2 Rew   working on trial preVSext1 pre Rew   working on trial preVSext1 ext1 Rew   working on trial preVSext2 pre Rew   working on trial preVSext2 ext2 Rew   working on trial preVSrenew pre Rew   working on trial preVSrenew renew Rew   working on trial d2VSpost d2 Rew   working on trial d2VSpost post Rew   working on trial d2VSext1 d2 Rew   working on trial d2VSext1 ext1 Rew   working on trial d2VSext2 d2 Rew   working on trial d2VSext2 ext2 Rew   working on trial d2VSrenew d2 Rew   working on trial d2VSrenew renew Rew   working on trial postVSext1 post Rew   working on trial postVSext1 ext1 Rew   working on trial postVSext2 post Rew   working on trial postVSext2 ext2 Rew   working on trial postVSrenew post Rew   working on trial postVSrenew renew Rew   working on trial ext1VSext2 ext1 Rew   working on trial ext1VSext2 ext2 Rew   working on trial ext1VSrenew ext1 Rew   working on trial ext1VSrenew renew Rew   working on trial ext2VSrenew ext2 Rew   working on trial ext2VSrenew renew Rew   working on trial preVSpost pre CSm   working on trial preVSpost post CSm   working on trial preVSd2 pre CSm   working on trial preVSd2 d2 CSm   working on trial preVSext1 pre CSm   working on trial preVSext1 ext1 CSm   working on trial preVSext2 pre CSm   working on trial preVSext2 ext2 CSm   working on trial preVSrenew pre CSm   working on trial preVSrenew renew CSm   working on trial d2VSpost d2 CSm   working on trial d2VSpost post CSm   working on trial d2VSext1 d2 CSm   working on trial d2VSext1 ext1 CSm   working on trial d2VSext2 d2 CSm   working on trial d2VSext2 ext2 CSm   working on trial d2VSrenew d2 CSm   working on trial ...
# Wall time: 49.3 s

# %%
#remove cells that have no activity
if first_run==True:
    #you can only run the below once. Must rereun cell above before doing again.
    for epoch in ['base','trial']:
        for tt in ['Rew','CSm']:
            for pair in pairs:
                for pos in range(2):
                    for x in eval("first15_autocorr_%s_%s_%s_%s_evs.keys()"%(epoch,pair,pair.split('VS')[pos],tt)):
                        c=0
                        for y in range(len(eval("first15_autocorr_%s_%s_%s_%s_evs[x]"%(epoch,pair,pair.split('VS')[pos],tt)))):
                            #n=0
                            if len(eval("first15_autocorr_%s_%s_%s_%s_evs[x][y-c]"%(epoch,pair,pair.split('VS')[pos],tt)))==0:
                                #if np.mean(eval("%s_%s_%s_%s_evs[x][y][z]"%(epoch,pair,pair.split('VS')[pos],tt))) < 0.00000001:
                                #    n=n+1
                            #if n==len(eval("first15_autocorr_%s_%s_%s_%s_evs[x][y]"%(epoch,pair,pair.split('VS')[pos],tt))):
                                print "%s_%s_%s_%s[%s][%s]"%(epoch,pair,pair.split('VS')[pos],tt,x,y-c),
                                print eval("first15_autocorr_%s_%s_%s_%s_evs[x][%s]"%(epoch,pair,pair.split('VS')[pos],tt,y-c))
                                exec("for_del = first15_autocorr_%s_%s_%s_%s_evs"%(epoch,pair,pair.split('VS')[pos],tt))
                                #print for_del
                                del for_del[x][y-c]
                                print "deleted first15_autocorr_%s_%s_%s_%s[%s][%s]"%(epoch,pair,pair.split('VS')[pos],tt,x,y-c)
                                c=c+1  # since a cell has now been deleted, must subtract off that index position for the next deletion
first_run=False
# Out:
# base_preVSpost_pre_Rew[dhpc36][10] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc36][10]
# base_preVSpost_pre_Rew[dhpc36][13] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc36][13]
# base_preVSpost_pre_Rew[dhpc36][14] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc36][14]
# base_preVSpost_pre_Rew[dhpc36][16] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc36][16]
# base_preVSpost_pre_Rew[dhpc24][15] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][15]
# base_preVSpost_pre_Rew[dhpc24][27] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][27]
# base_preVSpost_pre_Rew[dhpc24][27] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][27]
# base_preVSpost_pre_Rew[dhpc24][32] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][32]
# base_preVSpost_pre_Rew[dhpc24][45] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][45]
# base_preVSpost_pre_Rew[dhpc24][74] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][74]
# base_preVSpost_pre_Rew[dhpc24][76] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][76]
# base_preVSpost_pre_Rew[dhpc24][86] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][86]
# base_preVSpost_pre_Rew[dhpc24][89] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][89]
# base_preVSpost_pre_Rew[dhpc24][92] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][92]
# base_preVSpost_pre_Rew[dhpc24][101] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][101]
# base_preVSpost_pre_Rew[dhpc24][107] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][107]
# base_preVSpost_pre_Rew[dhpc24][108] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][108]
# base_preVSpost_pre_Rew[dhpc24][110] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][110]
# base_preVSpost_pre_Rew[dhpc24][110] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][110]
# base_preVSpost_pre_Rew[dhpc24][110] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][110]
# base_preVSpost_pre_Rew[dhpc24][111] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][111]
# base_preVSpost_pre_Rew[dhpc24][111] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][111]
# base_preVSpost_pre_Rew[dhpc24][112] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][112]
# base_preVSpost_pre_Rew[dhpc24][114] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][114]
# base_preVSpost_pre_Rew[dhpc24][122] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][122]
# base_preVSpost_pre_Rew[dhpc24][124] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][124]
# base_preVSpost_pre_Rew[dhpc24][143] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][143]
# base_preVSpost_pre_Rew[dhpc24][146] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][146]
# base_preVSpost_pre_Rew[dhpc24][156] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][156]
# base_preVSpost_pre_Rew[dhpc24][158] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][158]
# base_preVSpost_pre_Rew[dhpc24][161] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][161]
# base_preVSpost_pre_Rew[dhpc24][164] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][164]
# base_preVSpost_pre_Rew[dhpc24][165] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][165]
# base_preVSpost_pre_Rew[dhpc24][173] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpc24][173]
# base_preVSpost_pre_Rew[dhpcg1][16] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpcg1][16]
# base_preVSpost_pre_Rew[dhpcg1][20] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpcg1][20]
# base_preVSpost_pre_Rew[dhpcg1][70] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpcg1][70]
# base_preVSpost_pre_Rew[dhpcg1][79] []
# deleted first15_autocorr_base_preVSpost_pre_Rew[dhpcg1][79]
# base_preVSpost_post_Rew[dhpc35][7] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc35][7]
# base_preVSpost_post_Rew[dhpc35][12] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc35][12]
# base_preVSpost_post_Rew[dhpc35][17] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc35][17]
# base_preVSpost_post_Rew[dhpc35][19] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc35][19]
# base_preVSpost_post_Rew[dhpc35][20] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc35][20]
# base_preVSpost_post_Rew[dhpc36][0] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc36][0]
# base_preVSpost_post_Rew[dhpc36][3] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc36][3]
# base_preVSpost_post_Rew[dhpc36][4] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc36][4]
# base_preVSpost_post_Rew[dhpc36][11] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc36][11]
# base_preVSpost_post_Rew[dhpc36][14] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc36][14]
# base_preVSpost_post_Rew[dhpc36][14] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc36][14]
# base_preVSpost_post_Rew[dhpc36][14] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc36][14]
# base_preVSpost_post_Rew[dhpc24][6] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][6]
# base_preVSpost_post_Rew[dhpc24][22] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][22]
# base_preVSpost_post_Rew[dhpc24][26] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][26]
# base_preVSpost_post_Rew[dhpc24][36] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][36]
# base_preVSpost_post_Rew[dhpc24][70] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][70]
# base_preVSpost_post_Rew[dhpc24][73] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][73]
# base_preVSpost_post_Rew[dhpc24][75] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][75]
# base_preVSpost_post_Rew[dhpc24][75] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][75]
# base_preVSpost_post_Rew[dhpc24][77] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][77]
# base_preVSpost_post_Rew[dhpc24][83] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][83]
# base_preVSpost_post_Rew[dhpc24][85] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][85]
# base_preVSpost_post_Rew[dhpc24][112] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][112]
# base_preVSpost_post_Rew[dhpc24][124] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][124]
# base_preVSpost_post_Rew[dhpc24][136] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][136]
# base_preVSpost_post_Rew[dhpc24][136] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][136]
# base_preVSpost_post_Rew[dhpc24][141] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][141]
# base_preVSpost_post_Rew[dhpc24][149] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][149]
# base_preVSpost_post_Rew[dhpc24][153] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][153]
# base_preVSpost_post_Rew[dhpc24][155] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][155]
# base_preVSpost_post_Rew[dhpc24][164] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][164]
# base_preVSpost_post_Rew[dhpc24][164] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][164]
# base_preVSpost_post_Rew[dhpc24][167] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][167]
# base_preVSpost_post_Rew[dhpc24][169] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][169]
# base_preVSpost_post_Rew[dhpc24][170] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpc24][170]
# base_preVSpost_post_Rew[dhpcg1][11] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpcg1][11]
# base_preVSpost_post_Rew[dhpcg1][31] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpcg1][31]
# base_preVSpost_post_Rew[dhpcg1][55] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpcg1][55]
# base_preVSpost_post_Rew[dhpcg1][56] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpcg1][56]
# base_preVSpost_post_Rew[dhpcg1][70] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpcg1][70]
# base_preVSpost_post_Rew[dhpcg1][75] []
# deleted first15_autocorr_base_preVSpost_post_Rew[dhpcg1][75]
# base_preVSd2_pre_Rew[dhpc35][29] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc35][29]
# base_preVSd2_pre_Rew[dhpc35][33] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc35][33]
# base_preVSd2_pre_Rew[dhpc35][33] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc35][33]
# base_preVSd2_pre_Rew[dhpc36][5] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc36][5]
# base_preVSd2_pre_Rew[dhpc36][8] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc36][8]
# base_preVSd2_pre_Rew[dhpc36][10] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc36][10]
# base_preVSd2_pre_Rew[dhpc36][17] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc36][17]
# base_preVSd2_pre_Rew[dhpc24][17] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][17]
# base_preVSd2_pre_Rew[dhpc24][28] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][28]
# base_preVSd2_pre_Rew[dhpc24][28] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][28]
# base_preVSd2_pre_Rew[dhpc24][32] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][32]
# base_preVSd2_pre_Rew[dhpc24][46] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][46]
# base_preVSd2_pre_Rew[dhpc24][73] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][73]
# base_preVSd2_pre_Rew[dhpc24][74] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][74]
# base_preVSd2_pre_Rew[dhpc24][88] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][88]
# base_preVSd2_pre_Rew[dhpc24][93] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][93]
# base_preVSd2_pre_Rew[dhpc24][108] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][108]
# base_preVSd2_pre_Rew[dhpc24][108] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][108]
# base_preVSd2_pre_Rew[dhpc24][113] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][113]
# base_preVSd2_pre_Rew[dhpc24][116] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][116]
# base_preVSd2_pre_Rew[dhpc24][116] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][116]
# base_preVSd2_pre_Rew[dhpc24][117] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][117]
# base_preVSd2_pre_Rew[dhpc24][120] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][120]
# base_preVSd2_pre_Rew[dhpc24][122] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][122]
# base_preVSd2_pre_Rew[dhpc24][128] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][128]
# base_preVSd2_pre_Rew[dhpc24][130] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][130]
# base_preVSd2_pre_Rew[dhpc24][139] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][139]
# base_preVSd2_pre_Rew[dhpc24][142] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][142]
# base_preVSd2_pre_Rew[dhpc24][148] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][148]
# base_preVSd2_pre_Rew[dhpc24][157] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][157]
# base_preVSd2_pre_Rew[dhpc24][157] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][157]
# base_preVSd2_pre_Rew[dhpc24][160] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][160]
# base_preVSd2_pre_Rew[dhpc24][160] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][160]
# base_preVSd2_pre_Rew[dhpc24][160] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][160]
# base_preVSd2_pre_Rew[dhpc24][168] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpc24][168]
# base_preVSd2_pre_Rew[dhpcg1][30] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpcg1][30]
# base_preVSd2_pre_Rew[dhpcg1][44] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpcg1][44]
# base_preVSd2_pre_Rew[dhpcg1][82] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpcg1][82]
# base_preVSd2_pre_Rew[dhpcg1][108] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpcg1][108]
# base_preVSd2_pre_Rew[dhpcg1][109] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpcg1][109]
# base_preVSd2_pre_Rew[dhpcg1][143] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpcg1][143]
# base_preVSd2_pre_Rew[dhpcg1][149] []
# deleted first15_autocorr_base_preVSd2_pre_Rew[dhpcg1][149]
# base_preVSd2_d2_Rew[dhpc35][27] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc35][27]
# base_preVSd2_d2_Rew[dhpc35][30] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc35][30]
# base_preVSd2_d2_Rew[dhpc36][10] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc36][10]
# base_preVSd2_d2_Rew[dhpc36][11] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc36][11]
# base_preVSd2_d2_Rew[dhpc36][12] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc36][12]
# base_preVSd2_d2_Rew[dhpc36][15] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc36][15]
# base_preVSd2_d2_Rew[dhpc36][17] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc36][17]
# base_preVSd2_d2_Rew[dhpc24][35] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][35]
# base_preVSd2_d2_Rew[dhpc24][76] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][76]
# base_preVSd2_d2_Rew[dhpc24][80] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][80]
# base_preVSd2_d2_Rew[dhpc24][84] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][84]
# base_preVSd2_d2_Rew[dhpc24][85] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][85]
# base_preVSd2_d2_Rew[dhpc24][89] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][89]
# base_preVSd2_d2_Rew[dhpc24][97] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][97]
# base_preVSd2_d2_Rew[dhpc24][97] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][97]
# base_preVSd2_d2_Rew[dhpc24][106] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][106]
# base_preVSd2_d2_Rew[dhpc24][106] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][106]
# base_preVSd2_d2_Rew[dhpc24][107] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][107]
# base_preVSd2_d2_Rew[dhpc24][125] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][125]
# base_preVSd2_d2_Rew[dhpc24][127] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][127]
# base_preVSd2_d2_Rew[dhpc24][128] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][128]
# base_preVSd2_d2_Rew[dhpc24][129] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][129]
# base_preVSd2_d2_Rew[dhpc24][130] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][130]
# base_preVSd2_d2_Rew[dhpc24][145] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][145]
# base_preVSd2_d2_Rew[dhpc24][156] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][156]
# base_preVSd2_d2_Rew[dhpc24][160] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][160]
# base_preVSd2_d2_Rew[dhpc24][160] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][160]
# base_preVSd2_d2_Rew[dhpc24][165] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][165]
# base_preVSd2_d2_Rew[dhpc24][170] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpc24][170]
# base_preVSd2_d2_Rew[dhpcg1][4] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][4]
# base_preVSd2_d2_Rew[dhpcg1][92] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][92]
# base_preVSd2_d2_Rew[dhpcg1][109] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][109]
# base_preVSd2_d2_Rew[dhpcg1][115] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][115]
# base_preVSd2_d2_Rew[dhpcg1][116] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][116]
# base_preVSd2_d2_Rew[dhpcg1][131] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][131]
# base_preVSd2_d2_Rew[dhpcg1][137] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][137]
# base_preVSd2_d2_Rew[dhpcg1][142] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][142]
# base_preVSd2_d2_Rew[dhpcg1][146] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][146]
# base_preVSd2_d2_Rew[dhpcg1][157] []
# deleted first15_autocorr_base_preVSd2_d2_Rew[dhpcg1][157]
# base_preVSext1_pre_Rew[dhpc36][6] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc36][6]
# base_preVSext1_pre_Rew[dhpc36][7] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc36][7]
# base_preVSext1_pre_Rew[dhpc36][7] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc36][7]
# base_preVSext1_pre_Rew[dhpc36][11] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc36][11]
# base_preVSext1_pre_Rew[dhpc36][11] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc36][11]
# base_preVSext1_pre_Rew[dhpc36][13] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc36][13]
# base_preVSext1_pre_Rew[dhpc24][4] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][4]
# base_preVSext1_pre_Rew[dhpc24][9] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][9]
# base_preVSext1_pre_Rew[dhpc24][12] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][12]
# base_preVSext1_pre_Rew[dhpc24][22] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][22]
# base_preVSext1_pre_Rew[dhpc24][24] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][24]
# base_preVSext1_pre_Rew[dhpc24][34] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][34]
# base_preVSext1_pre_Rew[dhpc24][34] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][34]
# base_preVSext1_pre_Rew[dhpc24][37] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][37]
# base_preVSext1_pre_Rew[dhpc24][48] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][48]
# base_preVSext1_pre_Rew[dhpc24][51] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][51]
# base_preVSext1_pre_Rew[dhpc24][53] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][53]
# base_preVSext1_pre_Rew[dhpc24][55] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][55]
# base_preVSext1_pre_Rew[dhpc24][56] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][56]
# base_preVSext1_pre_Rew[dhpc24][61] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpc24][61]
# base_preVSext1_pre_Rew[dhpcg1][13] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpcg1][13]
# base_preVSext1_pre_Rew[dhpcg1][16] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpcg1][16]
# base_preVSext1_pre_Rew[dhpcg1][57] []
# deleted first15_autocorr_base_preVSext1_pre_Rew[dhpcg1][57]
# base_preVSext1_ext1_Rew[dhpc35][0] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc35][0]
# base_preVSext1_ext1_Rew[dhpc35][22] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc35][22]
# base_preVSext1_ext1_Rew[dhpc36][5] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc36][5]
# base_preVSext1_ext1_Rew[dhpc36][6] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc36][6]
# base_preVSext1_ext1_Rew[dhpc36][7] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc36][7]
# base_preVSext1_ext1_Rew[dhpc36][14] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc36][14]
# base_preVSext1_ext1_Rew[dhpc24][26] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc24][26]
# base_preVSext1_ext1_Rew[dhpc24][41] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc24][41]
# base_preVSext1_ext1_Rew[dhpc24][57] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpc24][57]
# base_preVSext1_ext1_Rew[dhpcg1][56] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpcg1][56]
# base_preVSext1_ext1_Rew[dhpcg1][57] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpcg1][57]
# base_preVSext1_ext1_Rew[dhpcg1][61] []
# deleted first15_autocorr_base_preVSext1_ext1_Rew[dhpcg1][61]
# base_preVSext2_pre_Rew[dhpc36][3] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc36][3]
# base_preVSext2_pre_Rew[dhpc36][8] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc36][8]
# base_preVSext2_pre_Rew[dhpc36][10] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc36][10]
# base_preVSext2_pre_Rew[dhpc36][11] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc36][11]
# base_preVSext2_pre_Rew[dhpc36][12] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc36][12]
# base_preVSext2_pre_Rew[dhpc24][11] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][11]
# base_preVSext2_pre_Rew[dhpc24][21] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][21]
# base_preVSext2_pre_Rew[dhpc24][31] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][31]
# base_preVSext2_pre_Rew[dhpc24][50] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][50]
# base_preVSext2_pre_Rew[dhpc24][52] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][52]
# base_preVSext2_pre_Rew[dhpc24][53] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][53]
# base_preVSext2_pre_Rew[dhpc24][57] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][57]
# base_preVSext2_pre_Rew[dhpc24][57] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][57]
# base_preVSext2_pre_Rew[dhpc24][61] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][61]
# base_preVSext2_pre_Rew[dhpc24][63] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][63]
# base_preVSext2_pre_Rew[dhpc24][63] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][63]
# base_preVSext2_pre_Rew[dhpc24][78] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][78]
# base_preVSext2_pre_Rew[dhpc24][79] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][79]
# base_preVSext2_pre_Rew[dhpc24][81] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][81]
# base_preVSext2_pre_Rew[dhpc24][81] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][81]
# base_preVSext2_pre_Rew[dhpc24][82] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][82]
# base_preVSext2_pre_Rew[dhpc24][85] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][85]
# base_preVSext2_pre_Rew[dhpc24][93] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][93]
# base_preVSext2_pre_Rew[dhpc24][95] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][95]
# base_preVSext2_pre_Rew[dhpc24][118] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][118]
# base_preVSext2_pre_Rew[dhpc24][123] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][123]
# base_preVSext2_pre_Rew[dhpc24][127] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][127]
# base_preVSext2_pre_Rew[dhpc24][128] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][128]
# base_preVSext2_pre_Rew[dhpc24][129] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][129]
# base_preVSext2_pre_Rew[dhpc24][134] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][134]
# base_preVSext2_pre_Rew[dhpc24][134] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][134]
# base_preVSext2_pre_Rew[dhpc24][135] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpc24][135]
# base_preVSext2_pre_Rew[dhpcg1][7] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpcg1][7]
# base_preVSext2_pre_Rew[dhpcg1][10] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpcg1][10]
# base_preVSext2_pre_Rew[dhpcg1][35] []
# deleted first15_autocorr_base_preVSext2_pre_Rew[dhpcg1][35]
# base_preVSext2_ext2_Rew[dhpc35][5] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc35][5]
# base_preVSext2_ext2_Rew[dhpc35][23] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc35][23]
# base_preVSext2_ext2_Rew[dhpc35][28] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc35][28]
# base_preVSext2_ext2_Rew[dhpc36][5] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc36][5]
# base_preVSext2_ext2_Rew[dhpc36][5] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc36][5]
# base_preVSext2_ext2_Rew[dhpc36][9] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc36][9]
# base_preVSext2_ext2_Rew[dhpc36][9] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc36][9]
# base_preVSext2_ext2_Rew[dhpc36][9] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc36][9]
# base_preVSext2_ext2_Rew[dhpc36][12] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc36][12]
# base_preVSext2_ext2_Rew[dhpc24][19] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc24][19]
# base_preVSext2_ext2_Rew[dhpc24][21] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc24][21]
# base_preVSext2_ext2_Rew[dhpc24][108] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc24][108]
# base_preVSext2_ext2_Rew[dhpc24][127] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc24][127]
# base_preVSext2_ext2_Rew[dhpc24][132] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc24][132]
# base_preVSext2_ext2_Rew[dhpc24][142] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc24][142]
# base_preVSext2_ext2_Rew[dhpc24][147] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc24][147]
# base_preVSext2_ext2_Rew[dhpc24][153] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpc24][153]
# base_preVSext2_ext2_Rew[dhpcg1][35] []
# deleted first15_autocorr_base_preVSext2_ext2_Rew[dhpcg1][35]
# base_preVSrenew_pre_Rew[dhpc35][22] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc35][22]
# base_preVSrenew_pre_Rew[dhpc36][9] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc36][9]
# base_preVSrenew_pre_Rew[dhpc36][9] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc36][9]
# base_preVSrenew_pre_Rew[dhpc36][10] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc36][10]
# base_preVSrenew_pre_Rew[dhpc36][11] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc36][11]
# base_preVSrenew_pre_Rew[dhpc24][8] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][8]
# base_preVSrenew_pre_Rew[dhpc24][14] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][14]
# base_preVSrenew_pre_Rew[dhpc24][14] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][14]
# base_preVSrenew_pre_Rew[dhpc24][33] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][33]
# base_preVSrenew_pre_Rew[dhpc24][41] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][41]
# base_preVSrenew_pre_Rew[dhpc24][49] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][49]
# base_preVSrenew_pre_Rew[dhpc24][53] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][53]
# base_preVSrenew_pre_Rew[dhpc24][55] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][55]
# base_preVSrenew_pre_Rew[dhpc24][57] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][57]
# base_preVSrenew_pre_Rew[dhpc24][62] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][62]
# base_preVSrenew_pre_Rew[dhpc24][72] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][72]
# base_preVSrenew_pre_Rew[dhpc24][80] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][80]
# base_preVSrenew_pre_Rew[dhpc24][84] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][84]
# base_preVSrenew_pre_Rew[dhpc24][86] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][86]
# base_preVSrenew_pre_Rew[dhpc24][89] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][89]
# base_preVSrenew_pre_Rew[dhpc24][89] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][89]
# base_preVSrenew_pre_Rew[dhpc24][89] []
# deleted first15_autocorr_base_preVSrenew_pre_Rew[dhpc24][89]
# base_preVSrenew_renew_Rew[dhpc35][1] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc35][1]
# base_preVSrenew_renew_Rew[dhpc35][17] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc35][17]
# base_preVSrenew_renew_Rew[dhpc35][19] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc35][19]
# base_preVSrenew_renew_Rew[dhpc36][1] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc36][1]
# base_preVSrenew_renew_Rew[dhpc36][8] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc36][8]
# base_preVSrenew_renew_Rew[dhpc36][8] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc36][8]
# base_preVSrenew_renew_Rew[dhpc24][12] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][12]
# base_preVSrenew_renew_Rew[dhpc24][29] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][29]
# base_preVSrenew_renew_Rew[dhpc24][34] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][34]
# base_preVSrenew_renew_Rew[dhpc24][44] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][44]
# base_preVSrenew_renew_Rew[dhpc24][44] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][44]
# base_preVSrenew_renew_Rew[dhpc24][75] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][75]
# base_preVSrenew_renew_Rew[dhpc24][77] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][77]
# base_preVSrenew_renew_Rew[dhpc24][81] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][81]
# base_preVSrenew_renew_Rew[dhpc24][97] []
# deleted first15_autocorr_base_preVSrenew_renew_Rew[dhpc24][97]
# base_d2VSpost_d2_Rew[dhpc35][23] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc35][23]
# base_d2VSpost_d2_Rew[dhpc36][26] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][26]
# base_d2VSpost_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][38]
# base_d2VSpost_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][38]
# base_d2VSpost_d2_Rew[dhpc36][41] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][41]
# base_d2VSpost_d2_Rew[dhpc36][43] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][43]
# base_d2VSpost_d2_Rew[dhpc36][43] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][43]
# base_d2VSpost_d2_Rew[dhpc36][43] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][43]
# base_d2VSpost_d2_Rew[dhpc36][44] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][44]
# base_d2VSpost_d2_Rew[dhpc36][44] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc36][44]
# base_d2VSpost_d2_Rew[dhpc24][63] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][63]
# base_d2VSpost_d2_Rew[dhpc24][79] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][79]
# base_d2VSpost_d2_Rew[dhpc24][82] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][82]
# base_d2VSpost_d2_Rew[dhpc24][106] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][106]
# base_d2VSpost_d2_Rew[dhpc24][109] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][109]
# base_d2VSpost_d2_Rew[dhpc24][128] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][128]
# base_d2VSpost_d2_Rew[dhpc24][130] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][130]
# base_d2VSpost_d2_Rew[dhpc24][135] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][135]
# base_d2VSpost_d2_Rew[dhpc24][135] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][135]
# base_d2VSpost_d2_Rew[dhpc24][146] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][146]
# base_d2VSpost_d2_Rew[dhpc24][150] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][150]
# base_d2VSpost_d2_Rew[dhpc24][152] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][152]
# base_d2VSpost_d2_Rew[dhpc24][153] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][153]
# base_d2VSpost_d2_Rew[dhpc24][167] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][167]
# base_d2VSpost_d2_Rew[dhpc24][172] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpc24][172]
# base_d2VSpost_d2_Rew[dhpcg1][22] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][22]
# base_d2VSpost_d2_Rew[dhpcg1][36] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][36]
# base_d2VSpost_d2_Rew[dhpcg1][48] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][48]
# base_d2VSpost_d2_Rew[dhpcg1][87] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][87]
# base_d2VSpost_d2_Rew[dhpcg1][100] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][100]
# base_d2VSpost_d2_Rew[dhpcg1][100] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][100]
# base_d2VSpost_d2_Rew[dhpcg1][101] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][101]
# base_d2VSpost_d2_Rew[dhpcg1][127] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][127]
# base_d2VSpost_d2_Rew[dhpcg1][129] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][129]
# base_d2VSpost_d2_Rew[dhpcg1][144] []
# deleted first15_autocorr_base_d2VSpost_d2_Rew[dhpcg1][144]
# base_d2VSpost_post_Rew[dhpc35][2] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc35][2]
# base_d2VSpost_post_Rew[dhpc35][3] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc35][3]
# base_d2VSpost_post_Rew[dhpc35][14] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc35][14]
# base_d2VSpost_post_Rew[dhpc35][14] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc35][14]
# base_d2VSpost_post_Rew[dhpc35][23] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc35][23]
# base_d2VSpost_post_Rew[dhpc36][10] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][10]
# base_d2VSpost_post_Rew[dhpc36][19] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][19]
# base_d2VSpost_post_Rew[dhpc36][19] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][19]
# base_d2VSpost_post_Rew[dhpc36][22] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][22]
# base_d2VSpost_post_Rew[dhpc36][31] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][31]
# base_d2VSpost_post_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][38]
# base_d2VSpost_post_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][38]
# base_d2VSpost_post_Rew[dhpc36][41] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][41]
# base_d2VSpost_post_Rew[dhpc36][41] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc36][41]
# base_d2VSpost_post_Rew[dhpc24][3] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][3]
# base_d2VSpost_post_Rew[dhpc24][3] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][3]
# base_d2VSpost_post_Rew[dhpc24][12] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][12]
# base_d2VSpost_post_Rew[dhpc24][23] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][23]
# base_d2VSpost_post_Rew[dhpc24][37] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][37]
# base_d2VSpost_post_Rew[dhpc24][49] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][49]
# base_d2VSpost_post_Rew[dhpc24][79] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][79]
# base_d2VSpost_post_Rew[dhpc24][130] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][130]
# base_d2VSpost_post_Rew[dhpc24][134] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][134]
# base_d2VSpost_post_Rew[dhpc24][138] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][138]
# base_d2VSpost_post_Rew[dhpc24][148] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][148]
# base_d2VSpost_post_Rew[dhpc24][173] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][173]
# base_d2VSpost_post_Rew[dhpc24][174] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpc24][174]
# base_d2VSpost_post_Rew[dhpcg1][12] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][12]
# base_d2VSpost_post_Rew[dhpcg1][53] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][53]
# base_d2VSpost_post_Rew[dhpcg1][57] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][57]
# base_d2VSpost_post_Rew[dhpcg1][63] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][63]
# base_d2VSpost_post_Rew[dhpcg1][64] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][64]
# base_d2VSpost_post_Rew[dhpcg1][101] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][101]
# base_d2VSpost_post_Rew[dhpcg1][101] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][101]
# base_d2VSpost_post_Rew[dhpcg1][115] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][115]
# base_d2VSpost_post_Rew[dhpcg1][121] []
# deleted first15_autocorr_base_d2VSpost_post_Rew[dhpcg1][121]
# base_d2VSext1_d2_Rew[dhpc35][18] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc35][18]
# base_d2VSext1_d2_Rew[dhpc35][21] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc35][21]
# base_d2VSext1_d2_Rew[dhpc36][32] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][32]
# base_d2VSext1_d2_Rew[dhpc36][32] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][32]
# base_d2VSext1_d2_Rew[dhpc36][33] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][33]
# base_d2VSext1_d2_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][35]
# base_d2VSext1_d2_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][35]
# base_d2VSext1_d2_Rew[dhpc36][36] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][36]
# base_d2VSext1_d2_Rew[dhpc36][36] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][36]
# base_d2VSext1_d2_Rew[dhpc36][36] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][36]
# base_d2VSext1_d2_Rew[dhpc36][36] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][36]
# base_d2VSext1_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][38]
# base_d2VSext1_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][38]
# base_d2VSext1_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][38]
# base_d2VSext1_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][38]
# base_d2VSext1_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc36][38]
# base_d2VSext1_d2_Rew[dhpc24][47] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][47]
# base_d2VSext1_d2_Rew[dhpc24][61] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][61]
# base_d2VSext1_d2_Rew[dhpc24][63] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][63]
# base_d2VSext1_d2_Rew[dhpc24][87] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][87]
# base_d2VSext1_d2_Rew[dhpc24][96] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][96]
# base_d2VSext1_d2_Rew[dhpc24][97] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][97]
# base_d2VSext1_d2_Rew[dhpc24][98] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][98]
# base_d2VSext1_d2_Rew[dhpc24][98] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][98]
# base_d2VSext1_d2_Rew[dhpc24][106] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpc24][106]
# base_d2VSext1_d2_Rew[dhpcg1][21] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpcg1][21]
# base_d2VSext1_d2_Rew[dhpcg1][50] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpcg1][50]
# base_d2VSext1_d2_Rew[dhpcg1][93] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpcg1][93]
# base_d2VSext1_d2_Rew[dhpcg1][109] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpcg1][109]
# base_d2VSext1_d2_Rew[dhpcg1][128] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpcg1][128]
# base_d2VSext1_d2_Rew[dhpcg1][130] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpcg1][130]
# base_d2VSext1_d2_Rew[dhpcg1][132] []
# deleted first15_autocorr_base_d2VSext1_d2_Rew[dhpcg1][132]
# base_d2VSext1_ext1_Rew[dhpc35][3] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc35][3]
# base_d2VSext1_ext1_Rew[dhpc35][17] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc35][17]
# base_d2VSext1_ext1_Rew[dhpc35][23] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc35][23]
# base_d2VSext1_ext1_Rew[dhpc35][23] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc35][23]
# base_d2VSext1_ext1_Rew[dhpc36][18] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][18]
# base_d2VSext1_ext1_Rew[dhpc36][21] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][21]
# base_d2VSext1_ext1_Rew[dhpc36][22] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][22]
# base_d2VSext1_ext1_Rew[dhpc36][27] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][27]
# base_d2VSext1_ext1_Rew[dhpc36][28] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][28]
# base_d2VSext1_ext1_Rew[dhpc36][28] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][28]
# base_d2VSext1_ext1_Rew[dhpc36][29] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][29]
# base_d2VSext1_ext1_Rew[dhpc36][29] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][29]
# base_d2VSext1_ext1_Rew[dhpc36][31] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][31]
# base_d2VSext1_ext1_Rew[dhpc36][31] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][31]
# base_d2VSext1_ext1_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][35]
# base_d2VSext1_ext1_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][35]
# base_d2VSext1_ext1_Rew[dhpc36][39] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc36][39]
# base_d2VSext1_ext1_Rew[dhpc24][2] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc24][2]
# base_d2VSext1_ext1_Rew[dhpc24][15] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc24][15]
# base_d2VSext1_ext1_Rew[dhpc24][26] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc24][26]
# base_d2VSext1_ext1_Rew[dhpc24][51] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc24][51]
# base_d2VSext1_ext1_Rew[dhpc24][72] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc24][72]
# base_d2VSext1_ext1_Rew[dhpc24][89] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc24][89]
# base_d2VSext1_ext1_Rew[dhpc24][94] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpc24][94]
# base_d2VSext1_ext1_Rew[dhpcg1][54] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][54]
# base_d2VSext1_ext1_Rew[dhpcg1][62] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][62]
# base_d2VSext1_ext1_Rew[dhpcg1][68] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][68]
# base_d2VSext1_ext1_Rew[dhpcg1][76] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][76]
# base_d2VSext1_ext1_Rew[dhpcg1][84] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][84]
# base_d2VSext1_ext1_Rew[dhpcg1][103] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][103]
# base_d2VSext1_ext1_Rew[dhpcg1][106] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][106]
# base_d2VSext1_ext1_Rew[dhpcg1][115] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][115]
# base_d2VSext1_ext1_Rew[dhpcg1][128] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][128]
# base_d2VSext1_ext1_Rew[dhpcg1][129] []
# deleted first15_autocorr_base_d2VSext1_ext1_Rew[dhpcg1][129]
# base_d2VSext2_d2_Rew[dhpc35][17] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc35][17]
# base_d2VSext2_d2_Rew[dhpc36][24] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][24]
# base_d2VSext2_d2_Rew[dhpc36][32] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][32]
# base_d2VSext2_d2_Rew[dhpc36][32] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][32]
# base_d2VSext2_d2_Rew[dhpc36][32] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][32]
# base_d2VSext2_d2_Rew[dhpc36][32] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][32]
# base_d2VSext2_d2_Rew[dhpc36][32] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][32]
# base_d2VSext2_d2_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][35]
# base_d2VSext2_d2_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][35]
# base_d2VSext2_d2_Rew[dhpc36][36] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][36]
# base_d2VSext2_d2_Rew[dhpc36][36] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][36]
# base_d2VSext2_d2_Rew[dhpc36][36] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][36]
# base_d2VSext2_d2_Rew[dhpc36][36] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][36]
# base_d2VSext2_d2_Rew[dhpc36][39] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][39]
# base_d2VSext2_d2_Rew[dhpc36][40] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][40]
# base_d2VSext2_d2_Rew[dhpc36][41] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][41]
# base_d2VSext2_d2_Rew[dhpc36][41] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][41]
# base_d2VSext2_d2_Rew[dhpc36][41] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc36][41]
# base_d2VSext2_d2_Rew[dhpc24][31] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][31]
# base_d2VSext2_d2_Rew[dhpc24][40] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][40]
# base_d2VSext2_d2_Rew[dhpc24][55] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][55]
# base_d2VSext2_d2_Rew[dhpc24][72] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][72]
# base_d2VSext2_d2_Rew[dhpc24][82] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][82]
# base_d2VSext2_d2_Rew[dhpc24][83] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][83]
# base_d2VSext2_d2_Rew[dhpc24][88] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][88]
# base_d2VSext2_d2_Rew[dhpc24][95] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][95]
# base_d2VSext2_d2_Rew[dhpc24][99] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][99]
# base_d2VSext2_d2_Rew[dhpc24][101] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][101]
# base_d2VSext2_d2_Rew[dhpc24][105] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][105]
# base_d2VSext2_d2_Rew[dhpc24][116] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][116]
# base_d2VSext2_d2_Rew[dhpc24][118] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpc24][118]
# base_d2VSext2_d2_Rew[dhpcg1][13] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpcg1][13]
# base_d2VSext2_d2_Rew[dhpcg1][42] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpcg1][42]
# base_d2VSext2_d2_Rew[dhpcg1][82] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpcg1][82]
# base_d2VSext2_d2_Rew[dhpcg1][98] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpcg1][98]
# base_d2VSext2_d2_Rew[dhpcg1][123] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpcg1][123]
# base_d2VSext2_d2_Rew[dhpcg1][124] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpcg1][124]
# base_d2VSext2_d2_Rew[dhpcg1][126] []
# deleted first15_autocorr_base_d2VSext2_d2_Rew[dhpcg1][126]
# base_d2VSext2_ext2_Rew[dhpc35][7] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc35][7]
# base_d2VSext2_ext2_Rew[dhpc35][10] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc35][10]
# base_d2VSext2_ext2_Rew[dhpc36][8] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][8]
# base_d2VSext2_ext2_Rew[dhpc36][14] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][14]
# base_d2VSext2_ext2_Rew[dhpc36][17] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][17]
# base_d2VSext2_ext2_Rew[dhpc36][18] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][18]
# base_d2VSext2_ext2_Rew[dhpc36][18] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][18]
# base_d2VSext2_ext2_Rew[dhpc36][24] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][24]
# base_d2VSext2_ext2_Rew[dhpc36][24] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][24]
# base_d2VSext2_ext2_Rew[dhpc36][25] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][25]
# base_d2VSext2_ext2_Rew[dhpc36][26] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][26]
# base_d2VSext2_ext2_Rew[dhpc36][27] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][27]
# base_d2VSext2_ext2_Rew[dhpc36][29] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][29]
# base_d2VSext2_ext2_Rew[dhpc36][30] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][30]
# base_d2VSext2_ext2_Rew[dhpc36][33] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][33]
# base_d2VSext2_ext2_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][35]
# base_d2VSext2_ext2_Rew[dhpc36][39] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][39]
# base_d2VSext2_ext2_Rew[dhpc36][42] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc36][42]
# base_d2VSext2_ext2_Rew[dhpc24][43] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc24][43]
# base_d2VSext2_ext2_Rew[dhpc24][118] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpc24][118]
# base_d2VSext2_ext2_Rew[dhpcg1][47] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpcg1][47]
# base_d2VSext2_ext2_Rew[dhpcg1][103] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpcg1][103]
# base_d2VSext2_ext2_Rew[dhpcg1][130] []
# deleted first15_autocorr_base_d2VSext2_ext2_Rew[dhpcg1][130]
# base_d2VSrenew_d2_Rew[dhpc36][21] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][21]
# base_d2VSrenew_d2_Rew[dhpc36][33] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][33]
# base_d2VSrenew_d2_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][35]
# base_d2VSrenew_d2_Rew[dhpc36][35] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][35]
# base_d2VSrenew_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][38]
# base_d2VSrenew_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][38]
# base_d2VSrenew_d2_Rew[dhpc36][38] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][38]
# base_d2VSrenew_d2_Rew[dhpc36][41] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][41]
# base_d2VSrenew_d2_Rew[dhpc36][41] []
# deleted first15_autocorr_base_d2VSrenew_d2_Rew[dhpc36][41]
# base_d2VSrenew_d2_Rew[dhpc36][41] []
# ...
# trial_ext1VSext2_ext2_CSm[dhpc24][31] []
# deleted first15_autocorr_trial_ext1VSext2_ext2_CSm[dhpc24][31]
# trial_ext1VSext2_ext2_CSm[dhpc24][61] []
# deleted first15_autocorr_trial_ext1VSext2_ext2_CSm[dhpc24][61]
# trial_ext1VSext2_ext2_CSm[dhpc24][73] []
# deleted first15_autocorr_trial_ext1VSext2_ext2_CSm[dhpc24][73]
# trial_ext1VSext2_ext2_CSm[dhpc24][75] []
# deleted first15_autocorr_trial_ext1VSext2_ext2_CSm[dhpc24][75]
# trial_ext1VSext2_ext2_CSm[dhpc24][82] []
# deleted first15_autocorr_trial_ext1VSext2_ext2_CSm[dhpc24][82]
# trial_ext1VSext2_ext2_CSm[dhpc24][112] []
# deleted first15_autocorr_trial_ext1VSext2_ext2_CSm[dhpc24][112]
# trial_ext1VSext2_ext2_CSm[dhpcg1][122] []
# deleted first15_autocorr_trial_ext1VSext2_ext2_CSm[dhpcg1][122]
# trial_ext1VSrenew_ext1_CSm[dhpc35][25] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][25]
# trial_ext1VSrenew_ext1_CSm[dhpc35][25] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][25]
# trial_ext1VSrenew_ext1_CSm[dhpc35][25] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][25]
# trial_ext1VSrenew_ext1_CSm[dhpc35][37] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][37]
# trial_ext1VSrenew_ext1_CSm[dhpc35][38] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][38]
# trial_ext1VSrenew_ext1_CSm[dhpc35][40] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][40]
# trial_ext1VSrenew_ext1_CSm[dhpc35][40] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][40]
# trial_ext1VSrenew_ext1_CSm[dhpc35][41] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc35][41]
# trial_ext1VSrenew_ext1_CSm[dhpc36][38] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][38]
# trial_ext1VSrenew_ext1_CSm[dhpc36][38] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][38]
# trial_ext1VSrenew_ext1_CSm[dhpc36][39] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][39]
# trial_ext1VSrenew_ext1_CSm[dhpc36][40] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][40]
# trial_ext1VSrenew_ext1_CSm[dhpc36][41] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][41]
# trial_ext1VSrenew_ext1_CSm[dhpc36][42] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][42]
# trial_ext1VSrenew_ext1_CSm[dhpc36][46] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][46]
# trial_ext1VSrenew_ext1_CSm[dhpc36][50] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc36][50]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][21] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][21]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][25] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][25]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][27] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][27]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][29] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][29]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][42] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][42]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][68] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][68]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][69] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][69]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][71] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][71]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][74] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][74]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][84] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][84]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][90] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][90]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][92] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][92]
# trial_ext1VSrenew_ext1_CSm[dhpcg20][93] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpcg20][93]
# trial_ext1VSrenew_ext1_CSm[dhpc24][5] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc24][5]
# trial_ext1VSrenew_ext1_CSm[dhpc24][50] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc24][50]
# trial_ext1VSrenew_ext1_CSm[dhpc24][73] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc24][73]
# trial_ext1VSrenew_ext1_CSm[dhpc24][84] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc24][84]
# trial_ext1VSrenew_ext1_CSm[dhpc24][108] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc24][108]
# trial_ext1VSrenew_ext1_CSm[dhpc24][108] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc24][108]
# trial_ext1VSrenew_ext1_CSm[dhpc24][116] []
# deleted first15_autocorr_trial_ext1VSrenew_ext1_CSm[dhpc24][116]
# trial_ext1VSrenew_renew_CSm[dhpc35][0] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc35][0]
# trial_ext1VSrenew_renew_CSm[dhpc35][15] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc35][15]
# trial_ext1VSrenew_renew_CSm[dhpc35][40] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc35][40]
# trial_ext1VSrenew_renew_CSm[dhpc36][15] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][15]
# trial_ext1VSrenew_renew_CSm[dhpc36][17] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][17]
# trial_ext1VSrenew_renew_CSm[dhpc36][35] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][35]
# trial_ext1VSrenew_renew_CSm[dhpc36][38] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][38]
# trial_ext1VSrenew_renew_CSm[dhpc36][38] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][38]
# trial_ext1VSrenew_renew_CSm[dhpc36][41] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][41]
# trial_ext1VSrenew_renew_CSm[dhpc36][41] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][41]
# trial_ext1VSrenew_renew_CSm[dhpc36][50] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc36][50]
# trial_ext1VSrenew_renew_CSm[dhpcg20][34] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][34]
# trial_ext1VSrenew_renew_CSm[dhpcg20][36] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][36]
# trial_ext1VSrenew_renew_CSm[dhpcg20][47] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][47]
# trial_ext1VSrenew_renew_CSm[dhpcg20][60] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][60]
# trial_ext1VSrenew_renew_CSm[dhpcg20][60] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][60]
# trial_ext1VSrenew_renew_CSm[dhpcg20][63] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][63]
# trial_ext1VSrenew_renew_CSm[dhpcg20][68] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][68]
# trial_ext1VSrenew_renew_CSm[dhpcg20][68] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][68]
# trial_ext1VSrenew_renew_CSm[dhpcg20][83] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][83]
# trial_ext1VSrenew_renew_CSm[dhpcg20][89] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][89]
# trial_ext1VSrenew_renew_CSm[dhpcg20][93] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][93]
# trial_ext1VSrenew_renew_CSm[dhpcg20][94] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][94]
# trial_ext1VSrenew_renew_CSm[dhpcg20][94] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpcg20][94]
# trial_ext1VSrenew_renew_CSm[dhpc24][26] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][26]
# trial_ext1VSrenew_renew_CSm[dhpc24][29] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][29]
# trial_ext1VSrenew_renew_CSm[dhpc24][43] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][43]
# trial_ext1VSrenew_renew_CSm[dhpc24][51] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][51]
# trial_ext1VSrenew_renew_CSm[dhpc24][58] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][58]
# trial_ext1VSrenew_renew_CSm[dhpc24][70] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][70]
# trial_ext1VSrenew_renew_CSm[dhpc24][94] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][94]
# trial_ext1VSrenew_renew_CSm[dhpc24][95] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][95]
# trial_ext1VSrenew_renew_CSm[dhpc24][102] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][102]
# trial_ext1VSrenew_renew_CSm[dhpc24][110] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][110]
# trial_ext1VSrenew_renew_CSm[dhpc24][111] []
# deleted first15_autocorr_trial_ext1VSrenew_renew_CSm[dhpc24][111]
# trial_ext2VSrenew_ext2_CSm[dhpc35][1] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc35][1]
# trial_ext2VSrenew_ext2_CSm[dhpc35][11] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc35][11]
# trial_ext2VSrenew_ext2_CSm[dhpc35][14] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc35][14]
# trial_ext2VSrenew_ext2_CSm[dhpc36][11] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][11]
# trial_ext2VSrenew_ext2_CSm[dhpc36][18] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][18]
# trial_ext2VSrenew_ext2_CSm[dhpc36][19] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][19]
# trial_ext2VSrenew_ext2_CSm[dhpc36][26] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][26]
# trial_ext2VSrenew_ext2_CSm[dhpc36][26] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][26]
# trial_ext2VSrenew_ext2_CSm[dhpc36][26] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][26]
# trial_ext2VSrenew_ext2_CSm[dhpc36][26] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][26]
# trial_ext2VSrenew_ext2_CSm[dhpc36][26] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][26]
# trial_ext2VSrenew_ext2_CSm[dhpc36][29] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][29]
# trial_ext2VSrenew_ext2_CSm[dhpc36][30] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][30]
# trial_ext2VSrenew_ext2_CSm[dhpc36][32] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][32]
# trial_ext2VSrenew_ext2_CSm[dhpc36][34] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][34]
# trial_ext2VSrenew_ext2_CSm[dhpc36][34] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc36][34]
# trial_ext2VSrenew_ext2_CSm[dhpcg20][22] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpcg20][22]
# trial_ext2VSrenew_ext2_CSm[dhpcg20][73] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpcg20][73]
# trial_ext2VSrenew_ext2_CSm[dhpcg20][107] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpcg20][107]
# trial_ext2VSrenew_ext2_CSm[dhpcg20][118] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpcg20][118]
# trial_ext2VSrenew_ext2_CSm[dhpc24][11] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][11]
# trial_ext2VSrenew_ext2_CSm[dhpc24][56] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][56]
# trial_ext2VSrenew_ext2_CSm[dhpc24][120] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][120]
# trial_ext2VSrenew_ext2_CSm[dhpc24][144] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][144]
# trial_ext2VSrenew_ext2_CSm[dhpc24][176] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][176]
# trial_ext2VSrenew_ext2_CSm[dhpc24][178] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][178]
# trial_ext2VSrenew_ext2_CSm[dhpc24][184] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][184]
# trial_ext2VSrenew_ext2_CSm[dhpc24][185] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][185]
# trial_ext2VSrenew_ext2_CSm[dhpc24][185] []
# deleted first15_autocorr_trial_ext2VSrenew_ext2_CSm[dhpc24][185]
# trial_ext2VSrenew_renew_CSm[dhpc35][12] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc35][12]
# trial_ext2VSrenew_renew_CSm[dhpc36][18] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc36][18]
# trial_ext2VSrenew_renew_CSm[dhpc36][23] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc36][23]
# trial_ext2VSrenew_renew_CSm[dhpc36][27] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc36][27]
# trial_ext2VSrenew_renew_CSm[dhpc36][29] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc36][29]
# trial_ext2VSrenew_renew_CSm[dhpc36][29] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc36][29]
# trial_ext2VSrenew_renew_CSm[dhpc36][32] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc36][32]
# trial_ext2VSrenew_renew_CSm[dhpc36][39] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc36][39]
# trial_ext2VSrenew_renew_CSm[dhpcg20][40] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][40]
# trial_ext2VSrenew_renew_CSm[dhpcg20][64] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][64]
# trial_ext2VSrenew_renew_CSm[dhpcg20][66] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][66]
# trial_ext2VSrenew_renew_CSm[dhpcg20][89] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][89]
# trial_ext2VSrenew_renew_CSm[dhpcg20][92] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][92]
# trial_ext2VSrenew_renew_CSm[dhpcg20][102] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][102]
# trial_ext2VSrenew_renew_CSm[dhpcg20][103] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][103]
# trial_ext2VSrenew_renew_CSm[dhpcg20][107] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][107]
# trial_ext2VSrenew_renew_CSm[dhpcg20][107] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][107]
# trial_ext2VSrenew_renew_CSm[dhpcg20][112] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][112]
# trial_ext2VSrenew_renew_CSm[dhpcg20][114] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpcg20][114]
# trial_ext2VSrenew_renew_CSm[dhpc24][7] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][7]
# trial_ext2VSrenew_renew_CSm[dhpc24][49] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][49]
# trial_ext2VSrenew_renew_CSm[dhpc24][49] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][49]
# trial_ext2VSrenew_renew_CSm[dhpc24][52] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][52]
# trial_ext2VSrenew_renew_CSm[dhpc24][64] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][64]
# trial_ext2VSrenew_renew_CSm[dhpc24][70] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][70]
# trial_ext2VSrenew_renew_CSm[dhpc24][70] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][70]
# trial_ext2VSrenew_renew_CSm[dhpc24][74] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][74]
# trial_ext2VSrenew_renew_CSm[dhpc24][76] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][76]
# trial_ext2VSrenew_renew_CSm[dhpc24][90] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][90]
# trial_ext2VSrenew_renew_CSm[dhpc24][92] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][92]
# trial_ext2VSrenew_renew_CSm[dhpc24][95] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][95]
# trial_ext2VSrenew_renew_CSm[dhpc24][110] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][110]
# trial_ext2VSrenew_renew_CSm[dhpc24][116] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][116]
# trial_ext2VSrenew_renew_CSm[dhpc24][121] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][121]
# trial_ext2VSrenew_renew_CSm[dhpc24][123] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][123]
# trial_ext2VSrenew_renew_CSm[dhpc24][125] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][125]
# trial_ext2VSrenew_renew_CSm[dhpc24][130] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][130]
# trial_ext2VSrenew_renew_CSm[dhpc24][133] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][133]
# trial_ext2VSrenew_renew_CSm[dhpc24][134] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][134]
# trial_ext2VSrenew_renew_CSm[dhpc24][149] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][149]
# trial_ext2VSrenew_renew_CSm[dhpc24][154] []
# deleted first15_autocorr_trial_ext2VSrenew_renew_CSm[dhpc24][154]

# %%
#check to make sure all empty cells have been removed. NOTHING SHOULD PRINT OUT.
for epoch in ['base','trial']:
    for tt in ['Rew','CSm']:
        for pair in pairs:
            for pos in range(2):
                for ani in eval("first15_autocorr_%s_%s_%s_%s_evs.keys()"%(epoch,pair,pair.split('VS')[pos],tt)):
                    for y in range(len(eval("first15_autocorr_%s_%s_%s_%s_evs[ani]"%(epoch,pair,pair.split('VS')[pos],tt)))):
                        if np.mean(eval("first15_autocorr_%s_%s_%s_%s_evs[ani][y]"%(epoch,pair,pair.split('VS')[pos],tt))) >= 0.0000000001:
                            i=0 # just a random operation to fulfill the requirement to do "something" here
                        else:
                            print epoch,pair,pair.split('VS')[pos],tt,ani,y

# %%
# %%time
#get the means for each level of anlaysis (trials, cells, animals)
for epoch in ['base','trial']:
    for tt in ['Rew','CSm']:
        for pair in pairs:
            for pos in range(2):
                print 'working on %s %s %s %s   '%(epoch,pair,pair.split('VS')[pos],tt),
                exec("first15_autocorr_meanoftrials_%s_%s_%s_%s_evs={}"%(epoch,pair,pair.split('VS')[pos],tt))
                exec("first15_autocorr_meanofcells_%s_%s_%s_%s_evs=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                for ani in eval("all_amps_%s_%s_%s_evs.keys()"%(pair,pair.split('VS')[pos],tt)):
                    exec("first15_autocorr_meanoftrials_%s_%s_%s_%s_evs[ani]=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                    for cell in range(len(eval("first15_autocorr_%s_%s_%s_%s_evs[ani]"%(epoch,pair,pair.split('VS')[pos],tt)))):
                #only include cells that have some activity
                        if np.mean(eval("first15_autocorr_%s_%s_%s_%s_evs[ani][cell]"%(epoch,pair,pair.split('VS')[pos],tt)))>0:
                #for each cell, get the mean over all trials
                            exec("first15_autocorr_meanoftrials_%s_%s_%s_%s_evs[ani].append(np.mean(first15_autocorr_%s_%s_%s_%s_evs[ani][cell],0))"%(epoch,
                                                               pair,pair.split('VS')[pos],tt,epoch,pair,pair.split('VS')[pos],tt))
                #for each animal, take the mean of all cells
                        if np.mean(eval("first15_autocorr_%s_%s_%s_%s_evs[ani][cell]"%(epoch,pair,pair.split('VS')[pos],tt)))>0: 
                            exec("first15_autocorr_meanofcells_%s_%s_%s_%s_evs.append(np.mean(first15_autocorr_meanoftrials_%s_%s_%s_%s_evs[ani],0))"%(epoch,
                                                               pair,pair.split('VS')[pos],tt,epoch,pair,pair.split('VS')[pos],tt))
                #get the mean of the whole pseudopopulation
                    exec("first15_autocorr_overallmean_%s_%s_%s_%s_evs = np.mean(first15_autocorr_meanofcells_%s_%s_%s_%s_evs,0)"%(epoch,
                                                               pair,pair.split('VS')[pos],tt,epoch,pair,pair.split('VS')[pos],tt))
# Out:
# working on base preVSpost pre Rew    working on base preVSpost post Rew    working on base preVSd2 pre Rew    working on base preVSd2 d2 Rew    working on base preVSext1 pre Rew    working on base preVSext1 ext1 Rew    working on base preVSext2 pre Rew    working on base preVSext2 ext2 Rew    working on base preVSrenew pre Rew    working on base preVSrenew renew Rew    working on base d2VSpost d2 Rew    working on base d2VSpost post Rew    working on base d2VSext1 d2 Rew    working on base d2VSext1 ext1 Rew    working on base d2VSext2 d2 Rew    working on base d2VSext2 ext2 Rew    working on base d2VSrenew d2 Rew    working on base d2VSrenew renew Rew    working on base postVSext1 post Rew    working on base postVSext1 ext1 Rew    working on base postVSext2 post Rew    working on base postVSext2 ext2 Rew    working on base postVSrenew post Rew    working on base postVSrenew renew Rew    working on base ext1VSext2 ext1 Rew    working on base ext1VSext2 ext2 Rew    working on base ext1VSrenew ext1 Rew    working on base ext1VSrenew renew Rew    working on base ext2VSrenew ext2 Rew    working on base ext2VSrenew renew Rew    working on base preVSpost pre CSm    working on base preVSpost post CSm    working on base preVSd2 pre CSm    working on base preVSd2 d2 CSm    working on base preVSext1 pre CSm    working on base preVSext1 ext1 CSm    working on base preVSext2 pre CSm    working on base preVSext2 ext2 CSm    working on base preVSrenew pre CSm    working on base preVSrenew renew CSm    working on base d2VSpost d2 CSm    working on base d2VSpost post CSm    working on base d2VSext1 d2 CSm    working on base d2VSext1 ext1 CSm    working on base d2VSext2 d2 CSm    working on base d2VSext2 ext2 CSm    working on base d2VSrenew d2 CSm    working on base d2VSrenew renew CSm    working on base postVSext1 post CSm    working on base postVSext1 ext1 CSm    working on base postVSext2 post CSm    working on base postVSext2 ext2 CSm    working on base postVSrenew post CSm    working on base postVSrenew renew CSm    working on base ext1VSext2 ext1 CSm    working on base ext1VSext2 ext2 CSm    working on base ext1VSrenew ext1 CSm    working on base ext1VSrenew renew CSm    working on base ext2VSrenew ext2 CSm    working on base ext2VSrenew renew CSm    working on trial preVSpost pre Rew    working on trial preVSpost post Rew    working on trial preVSd2 pre Rew    working on trial preVSd2 d2 Rew    working on trial preVSext1 pre Rew    working on trial preVSext1 ext1 Rew    working on trial preVSext2 pre Rew    working on trial preVSext2 ext2 Rew    working on trial preVSrenew pre Rew    working on trial preVSrenew renew Rew    working on trial d2VSpost d2 Rew    working on trial d2VSpost post Rew    working on trial d2VSext1 d2 Rew    working on trial d2VSext1 ext1 Rew    working on trial d2VSext2 d2 Rew    working on trial d2VSext2 ext2 Rew    working on trial d2VSrenew d2 Rew    working on trial d2VSrenew renew Rew    working on trial postVSext1 post Rew    working on trial postVSext1 ext1 Rew    working on trial postVSext2 post Rew    working on trial postVSext2 ext2 Rew    working on trial postVSrenew post Rew    working on trial postVSrenew renew Rew    working on trial ext1VSext2 ext1 Rew    working on trial ext1VSext2 ext2 Rew    working on trial ext1VSrenew ext1 Rew    working on trial ext1VSrenew renew Rew    working on trial ext2VSrenew ext2 Rew    working on trial ext2VSrenew renew Rew    working on trial preVSpost pre CSm    working on trial preVSpost post CSm    working on trial preVSd2 pre CSm    working on trial preVSd2 d2 CSm    working on trial preVSext1 pre CSm    working on trial preVSext1 ext1 CSm    working on trial preVSext2 pre CSm    working on trial preVSext2 ext2 CSm    working on trial preVSrenew pre CSm    working on trial preVSrenew renew CSm    working on trial d2VSpost d2 CSm    working on trial d2VSpost post CSm    working on trial d2VSext1 d2 CSm    working on trial d2VSext1 ext1 CSm    working on trial d2V ...
# Wall time: 8.04 s

# %%
for x in first15_autocorr_meanoftrials_trial_preVSpost_post_Rew_evs.keys():
    for y in range(len(first15_autocorr_meanoftrials_trial_preVSpost_post_Rew_evs[x])):
        pl.plot(first15_autocorr_meanoftrials_trial_preVSpost_post_Rew_evs[x][y])

# %%
def monoExp(x, m, t, b):
    return m * np.exp(-t * x) + b

import scipy.optimize

xs = np.linspace(0,16,16) # lag of 20 bins
ys = first15_autocorr_overallmean_trial_preVSpost_post_Rew_evs[17:33]

# perform the fit
p0 = (1,0.25,0) # start with values near those we expect (starting value, starting x bin, ending value (decays to what?))
params, cv = scipy.optimize.curve_fit(monoExp, xs, ys, p0)
m, t, b = params
sampleRate = 3.75 # Hz
tauSec = (1 / t) / sampleRate

# determine quality of the fit
squaredDiffs = np.square(ys - monoExp(xs, m, t, b))
squaredDiffsFromMean = np.square(ys - np.mean(ys))
rSquared = 1 - np.sum(squaredDiffs) / np.sum(squaredDiffsFromMean)
print "R² =", rSquared

# plot the results
pl.plot(xs, ys, '.', label="data")
pl.plot(xs, monoExp(xs, m, t, b), '--', label="fitted")
pl.title("Fitted Exponential Curve")

# inspect the parameters
print "Y =", m, "* e^(",-t,"* x) +", b
print "Tau =", tauSec, "sec"
# Out:
# R² = 0.996288551692
# Y = 0.980887540401 * e^( -1.43094667861 * x) + 0.0167146627277
# Tau = 0.186356815843 sec

# %%
#fit each cell's first15_autocorrelation with an exponential decay function. Store the R2 and the tau time constant (t) for comparison later

def monoExp(x, m, t, b):
    return m * np.exp(-t * x) + b

import scipy.optimize

n=0
xs = np.linspace(0,16,16) # lag of 20 bins
p0 = (1,0.25,0) # start with values near those we expect (starting value, starting x bin, ending value (decays to what?))
sampleRate = 3.75 # Hz

for epoch in ['base','trial']:
    for tt in ['CSm','Rew']:
        for pair in pairs:
            for pos in range(2):
                exec("first15_decay_%s_%s_%s_%s = {}"%(epoch,pair,pair.split('VS')[pos],tt))
                exec("first15_decay_%s_%s_%s_%s['r2']=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                exec("first15_decay_%s_%s_%s_%s['tau']=[]"%(epoch,pair,pair.split('VS')[pos],tt))
                print 'working on %s %s %s_%s   '%(epoch,pair,pair.split('VS')[pos],tt),
                for x in range(len(eval("first15_autocorr_meanofcells_%s_%s_%s_%s_evs"%(epoch,pair,pair.split('VS')[pos],tt)))):
                    ys =eval("first15_autocorr_meanofcells_%s_%s_%s_%s_evs[x][17:33]"%(epoch,pair,pair.split('VS')[pos],tt))
                    try:
                        # perform the fit
                        params, cv = scipy.optimize.curve_fit(monoExp, xs, ys, p0)
                        m, t, b = params
                        tauSec = (1 / t) / sampleRate
                        
                        # determine quality of the fit
                        squaredDiffs = np.square(ys - monoExp(xs, m, t, b))
                        squaredDiffsFromMean = np.square(ys - np.mean(ys))
                        rSquared = 1 - np.sum(squaredDiffs) / np.sum(squaredDiffsFromMean)
                        exec("first15_decay_%s_%s_%s_%s['r2'].append(rSquared)"%(epoch,pair,pair.split('VS')[pos],tt))
                        exec("first15_decay_%s_%s_%s_%s['tau'].append(t)"%(epoch,pair,pair.split('VS')[pos],tt))
                    except:
                        print "skip cell",x
                        n=n+1
print "\nskipped",n,"cells"
# Out:
# working on base preVSpost pre_CSm    working on base preVSpost post_CSm    skip cell 20
# working on base preVSd2 pre_CSm    skip cell 0
# skip cell 1
# working on base preVSd2 d2_CSm    working on base preVSext1 pre_CSm    skip cell 0
# skip cell 1
# working on base preVSext1 ext1_CSm    skip cell 23
# working on base preVSext2 pre_CSm    working on base preVSext2 ext2_CSm    working on base preVSrenew pre_CSm    working on base preVSrenew renew_CSm    working on base d2VSpost d2_CSm    working on base d2VSpost post_CSm    working on base d2VSext1 d2_CSm    skip cell 0
# working on base d2VSext1 ext1_CSm    skip cell 22
# skip cell 23
# working on base d2VSext2 d2_CSm    skip cell 0
# working on base d2VSext2 ext2_CSm    skip cell 18
# skip cell 60
# working on base d2VSrenew d2_CSm    working on base d2VSrenew renew_CSm    skip cell 25
# working on base postVSext1 post_CSm    working on base postVSext1 ext1_CSm    skip cell 47
# skip cell 48
# working on base postVSext2 post_CSm    working on base postVSext2 ext2_CSm    skip cell 39
# skip cell 79
# working on base postVSrenew post_CSm    working on base postVSrenew renew_CSm    skip cell 37
# skip cell 38
# skip cell 39
# skip cell 40
# working on base ext1VSext2 ext1_CSm    skip cell 39
# skip cell 40
# skip cell 41
# working on base ext1VSext2 ext2_CSm    working on base ext1VSrenew ext1_CSm    skip cell 41
# skip cell 42
# skip cell 43
# skip cell 44
# working on base ext1VSrenew renew_CSm    skip cell 0
# skip cell 38
# skip cell 82
# working on base ext2VSrenew ext2_CSm    working on base ext2VSrenew renew_CSm    skip cell 53
# working on base preVSpost pre_Rew    working on base preVSpost post_Rew    working on base preVSd2 pre_Rew    skip cell 0
# working on base preVSd2 d2_Rew    working on base preVSext1 pre_Rew    skip cell 0
# working on base preVSext1 ext1_Rew    skip cell 0
# skip cell 23
# skip cell 24
# skip cell 104
# working on base preVSext2 pre_Rew    working on base preVSext2 ext2_Rew    working on base preVSrenew pre_Rew    working on base preVSrenew renew_Rew    working on base d2VSpost d2_Rew    working on base d2VSpost post_Rew    working on base d2VSext1 d2_Rew    skip cell 0
# working on base d2VSext1 ext1_Rew    skip cell 0
# skip cell 191
# working on base d2VSext2 d2_Rew    skip cell 0
# working on base d2VSext2 ext2_Rew    skip cell 0
# skip cell 18
# working on base d2VSrenew d2_Rew    working on base d2VSrenew renew_Rew    working on base postVSext1 post_Rew    working on base postVSext1 ext1_Rew    working on base postVSext2 post_Rew    working on base postVSext2 ext2_Rew    skip cell 37
# skip cell 38
# working on base postVSrenew post_Rew    working on base postVSrenew renew_Rew    working on base ext1VSext2 ext1_Rew    working on base ext1VSext2 ext2_Rew    skip cell 39
# working on base ext1VSrenew ext1_Rew    skip cell 0
# skip cell 1
# skip cell 2
# skip cell 39
# working on base ext1VSrenew renew_Rew    skip cell 0
# working on base ext2VSrenew ext2_Rew    working on base ext2VSrenew renew_Rew    skip cell 17
# working on trial preVSpost pre_CSm    working on trial preVSpost post_CSm    skip cell 21
# working on trial preVSd2 pre_CSm    working on trial preVSd2 d2_CSm    working on trial preVSext1 pre_CSm    working on trial preVSext1 ext1_CSm    working on trial preVSext2 pre_CSm    working on trial preVSext2 ext2_CSm    working on trial preVSrenew pre_CSm    working on trial preVSrenew renew_CSm    working on trial d2VSpost d2_CSm    working on trial d2VSpost post_CSm    working on trial d2VSext1 d2_CSm    working on trial d2VSext1 ext1_CSm    working on trial d2VSext2 d2_CSm    working on trial d2VSext2 ext2_CSm    working on trial d2VSrenew d2_CSm    working on trial d2VSrenew renew_CSm    skip cell 27
# working on trial postVSext1 post_CSm    working on trial postVSext1 ext1_CSm    working on trial postVSext2 post_CSm    working on trial postVSext2 ext2_CSm    working on trial postVSrenew post_CSm    working on trial postVSrenew renew_CSm    skip cell 43
# working on trial ext1VSext2 ext1_CSm    working on trial ext1VSext2 ext2_CSm    skip cell 39
# working on trial ext1VSrenew ext1_CSm    skip cell 41
# working on trial ext1VSrenew renew_CSm    working on trial ext2VSrenew ext2_CSm    working on trial ext2VSrenew renew_CSm    working on trial preVSpost pre_Rew    working on trial preVSpost post_Rew    skip cell 0
# skip cell 1
# skip cell 2
# working on trial preVSd2 pre_Rew    working on trial preVSd2 d2_Rew    working on trial preVSext1 pre_Rew    working on trial preVSext1 ext1_Rew    skip cell 105
# working on trial preVSext2 pre_Rew    working on trial preVSext2 ext2_Rew    working on trial preVSrenew pre_Rew    working on trial preVSrenew renew_Rew    working on trial d2VSpost d2_Rew    working on trial d2VSpost post_Rew    working on trial d2VSext1 d2_Rew    working on trial d2VSext1 ext1_Rew    skip cell 205
# working on trial d2VSext2 d2_Rew    working on trial d2VSext2 ext2_Rew    skip cell 0
# working on trial d2VSrenew d2_Rew    working on trial d2VSrenew renew_Rew    skip cell 0
# working on trial postVSext1 post_Rew    working on trial postVSext1 ext1_Rew    skip cell 422
# working on trial postVSext2 post_Rew    skip cell 0
# working on trial postVSext2 ext2_Rew    working on trial postVSrenew post_Rew    skip cell 0
# working on trial postVSrenew renew_Rew    working on trial ext1VSext2 ext1_Rew    working on trial ext1VSext2 ext2_Rew    working on trial ext1VSrenew ext1_Rew    working on trial ext1VSrenew renew_Rew    skip cell 0
# skip cell 1
# working on trial ext2VSrenew ext2_Rew    working on trial ext2VSrenew renew_Rew
# skipped 70 cells

# %%
save_workspace(db)
# Out:
# Could not store variable 'math'. Skipping...
# Could not store variable 'sstats'. Skipping...
# Could not store variable 'di'. Skipping...
# Could not store variable 'ip'. Skipping...
# Could not store variable 'np'. Skipping...
# Could not store variable 'os'. Skipping...
# Could not store variable 'IPython'. Skipping...
# Could not store variable 'pickle'. Skipping...
# Could not store variable 'scipy'. Skipping...
# Could not store variable 'pt'. Skipping...
# Could not store variable 'pl'. Skipping...
# Could not store variable 'sys'. Skipping...
# Could not store variable 'ut'. Skipping...

# %% [markdown]
# # If want to look at averaged activity bins instead, can start with the following

# %% [markdown]
# #get patterns of CellReg'd cells
# expopre_patterns_expo_first30 = load_all_animals_vars('patterns_evs_expopre', expopre_animals, '', notebook='decoding_expoVSpre_30trials')
# expopre_patterns_pre_first30 = load_all_animals_vars('patterns_evs_pre_first30', expopre_animals, '', notebook='decoding_expoVSpre_30trials')
# expopre_labels_expo_first30 = load_all_animals_vars('labels_expo',expopre_animals, '', notebook='decoding_expoVSpre_30trials')
# expopre_labels_pre_first30 = load_all_animals_vars('labels_pre_first30',expopre_animals, '', notebook='decoding_expoVSpre_30trials')
# prepost_patterns_pre = load_all_animals_vars('patterns_evs_1s_pre_post', prepost_animals, '', notebook='patterns_time_bins')
# prepost_patterns_post = load_all_animals_vars('patterns_evs_1s_post_pre', prepost_animals, '', notebook='patterns_time_bins')
# prepost_labels_pre = load_all_animals_vars('labels_pre',prepost_animals, '', notebook='patterns_time_bins')
# prepost_labels_post = load_all_animals_vars('labels_post',prepost_animals, '', notebook='patterns_time_bins')
# preext1_patterns_pre = load_all_animals_vars('patterns_evs_1s_pre_ext1', preext1_animals, '', notebook='patterns_time_bins')
# preext1_patterns_ext1 = load_all_animals_vars('patterns_evs_1s_ext1_pre', preext1_animals, '', notebook='patterns_time_bins')
# preext1_labels_pre = load_all_animals_vars('labels_pre',preext1_animals, '', notebook='patterns_time_bins')
# preext1_labels_ext1 = load_all_animals_vars('labels_ext1',preext1_animals, '', notebook='patterns_time_bins')
# preext2_patterns_pre = load_all_animals_vars('patterns_evs_1s_pre_ext2', preext2_animals, '', notebook='patterns_time_bins')
# preext2_patterns_ext2 = load_all_animals_vars('patterns_evs_1s_ext2_pre', preext2_animals, '', notebook='patterns_time_bins')
# preext2_labels_pre = load_all_animals_vars('labels_pre',preext2_animals, '', notebook='patterns_time_bins')
# preext2_labels_ext2 = load_all_animals_vars('labels_ext2',preext2_animals, '', notebook='patterns_time_bins')
# prerenew_patterns_pre = load_all_animals_vars('patterns_evs_1s_pre_renew', prerenew_animals, '', notebook='patterns_time_bins')
# prerenew_patterns_renew = load_all_animals_vars('patterns_evs_1s_renew_pre', prerenew_animals, '', notebook='patterns_time_bins')
# prerenew_labels_pre = load_all_animals_vars('labels_pre',prerenew_animals, '', notebook='patterns_time_bins')
# prerenew_labels_renew = load_all_animals_vars('labels_renew',prerenew_animals, '', notebook='patterns_time_bins')
# postext1_patterns_post = load_all_animals_vars('patterns_evs_1s_post_ext1',postext1_animals, '', notebook='patterns_time_bins')
# postext1_patterns_ext1 = load_all_animals_vars('patterns_evs_1s_ext1_post',postext1_animals, '', notebook='patterns_time_bins')
# postext1_labels_post = load_all_animals_vars('labels_post',postext1_animals, '', notebook='patterns_time_bins')
# postext1_labels_ext1 = load_all_animals_vars('labels_ext1',postext1_animals, '', notebook='patterns_time_bins')
# postext2_patterns_post = load_all_animals_vars('patterns_evs_1s_post_ext2',postext2_animals, '', notebook='patterns_time_bins')
# postext2_patterns_ext2 = load_all_animals_vars('patterns_evs_1s_ext2_post',postext2_animals, '', notebook='patterns_time_bins')
# postext2_labels_post = load_all_animals_vars('labels_post',postext2_animals, '', notebook='patterns_time_bins')
# postext2_labels_ext2 = load_all_animals_vars('labels_ext2',postext2_animals, '', notebook='patterns_time_bins')
# postrenew_patterns_post = load_all_animals_vars('patterns_evs_1s_post_renew',postrenew_animals, '', notebook='patterns_time_bins')
# postrenew_patterns_renew = load_all_animals_vars('patterns_evs_1s_renew_post',postrenew_animals, '', notebook='patterns_time_bins')
# postrenew_labels_post = load_all_animals_vars('labels_post',postrenew_animals, '', notebook='patterns_time_bins')
# postrenew_labels_renew = load_all_animals_vars('labels_renew',postrenew_animals, '', notebook='patterns_time_bins')
# ext1ext2_patterns_ext1 = load_all_animals_vars('patterns_evs_1s_ext1_ext2', ext1ext2_animals, '', notebook='patterns_time_bins')
# ext1ext2_patterns_ext2 = load_all_animals_vars('patterns_evs_1s_ext2_ext1', ext1ext2_animals, '', notebook='patterns_time_bins')
# ext1ext2_labels_ext1 = load_all_animals_vars('labels_ext1',ext1ext2_animals, '', notebook='patterns_time_bins')
# ext1ext2_labels_ext2 = load_all_animals_vars('labels_ext2',ext1ext2_animals, '', notebook='patterns_time_bins')
# ext1renew_patterns_ext1 = load_all_animals_vars('patterns_evs_1s_ext1_renew', ext1renew_animals, '', notebook='patterns_time_bins')
# ext1renew_patterns_renew = load_all_animals_vars('patterns_evs_1s_renew_ext1', ext1renew_animals, '', notebook='patterns_time_bins')
# ext1renew_labels_ext1 = load_all_animals_vars('labels_ext1',ext1renew_animals, '', notebook='patterns_time_bins')
# ext1renew_labels_renew = load_all_animals_vars('labels_renew',ext1renew_animals, '', notebook='patterns_time_bins')
# ext2renew_patterns_renew = load_all_animals_vars('patterns_evs_1s_renew_ext2',ext2renew_animals, '', notebook='patterns_time_bins')
# ext2renew_patterns_ext2 = load_all_animals_vars('patterns_evs_1s_ext2_renew',ext2renew_animals, '', notebook='patterns_time_bins')
# ext2renew_labels_renew = load_all_animals_vars('labels_renew',ext2renew_animals, '', notebook='patterns_time_bins')
# ext2renew_labels_ext2 = load_all_animals_vars('labels_ext2',ext2renew_animals, '', notebook='patterns_time_bins')

# %% [markdown]
# #get patterns of CellReg'd cells
# expopre_patterns_expo_first30_05s = load_all_animals_vars('patterns_evs_expopre', expopre_animals, '', notebook='decoding_expoVSpre_30trials')
# expopre_patterns_pre_first30_05s = load_all_animals_vars('patterns_evs_pre_first30', expopre_animals, '', notebook='decoding_expoVSpre_30trials')
# expopre_labels_expo_first30_05s = load_all_animals_vars('labels_expo',expopre_animals, '', notebook='decoding_expoVSpre_30trials')
# expopre_labels_pre_first30_05s = load_all_animals_vars('labels_pre_first30',expopre_animals, '', notebook='decoding_expoVSpre_30trials')
# prepost_patterns_pre_05s = load_all_animals_vars('patterns_evs_05s_pre_post', prepost_animals, '', notebook='patterns_time_bins')
# prepost_patterns_post_05s = load_all_animals_vars('patterns_evs_05s_post_pre', prepost_animals, '', notebook='patterns_time_bins')
# prepost_labels_pre_05s = load_all_animals_vars('labels_pre',prepost_animals, '', notebook='patterns_time_bins')
# prepost_labels_post_05s = load_all_animals_vars('labels_post',prepost_animals, '', notebook='patterns_time_bins')
# preext1_patterns_pre_05s = load_all_animals_vars('patterns_evs_05s_pre_ext1', preext1_animals, '', notebook='patterns_time_bins')
# preext1_patterns_ext1_05s = load_all_animals_vars('patterns_evs_05s_ext1_pre', preext1_animals, '', notebook='patterns_time_bins')
# preext1_labels_pre_05s = load_all_animals_vars('labels_pre',preext1_animals, '', notebook='patterns_time_bins')
# preext1_labels_ext1_05s = load_all_animals_vars('labels_ext1',preext1_animals, '', notebook='patterns_time_bins')
# preext2_patterns_pre_05s = load_all_animals_vars('patterns_evs_05s_pre_ext2', preext2_animals, '', notebook='patterns_time_bins')
# preext2_patterns_ext2_05s = load_all_animals_vars('patterns_evs_05s_ext2_pre', preext2_animals, '', notebook='patterns_time_bins')
# preext2_labels_pre_05s = load_all_animals_vars('labels_pre',preext2_animals, '', notebook='patterns_time_bins')
# preext2_labels_ext2_05s = load_all_animals_vars('labels_ext2',preext2_animals, '', notebook='patterns_time_bins')
# prerenew_patterns_pre_05s = load_all_animals_vars('patterns_evs_05s_pre_renew', prerenew_animals, '', notebook='patterns_time_bins')
# prerenew_patterns_renew_05s = load_all_animals_vars('patterns_evs_05s_renew_pre', prerenew_animals, '', notebook='patterns_time_bins')
# prerenew_labels_pre_05s = load_all_animals_vars('labels_pre',prerenew_animals, '', notebook='patterns_time_bins')
# prerenew_labels_renew_05s = load_all_animals_vars('labels_renew',prerenew_animals, '', notebook='patterns_time_bins')
# postext1_patterns_post_05s = load_all_animals_vars('patterns_evs_05s_post_ext1',postext1_animals, '', notebook='patterns_time_bins')
# postext1_patterns_ext1_05s = load_all_animals_vars('patterns_evs_05s_ext1_post',postext1_animals, '', notebook='patterns_time_bins')
# postext1_labels_post_05s = load_all_animals_vars('labels_post',postext1_animals, '', notebook='patterns_time_bins')
# postext1_labels_ext1_05s = load_all_animals_vars('labels_ext1',postext1_animals, '', notebook='patterns_time_bins')
# postext2_patterns_post_05s = load_all_animals_vars('patterns_evs_05s_post_ext2',postext2_animals, '', notebook='patterns_time_bins')
# postext2_patterns_ext2_05s = load_all_animals_vars('patterns_evs_05s_ext2_post',postext2_animals, '', notebook='patterns_time_bins')
# postext2_labels_post_05s = load_all_animals_vars('labels_post',postext2_animals, '', notebook='patterns_time_bins')
# postext2_labels_ext2_05s = load_all_animals_vars('labels_ext2',postext2_animals, '', notebook='patterns_time_bins')
# postrenew_patterns_post_05s = load_all_animals_vars('patterns_evs_05s_post_renew',postrenew_animals, '', notebook='patterns_time_bins')
# postrenew_patterns_renew_05s = load_all_animals_vars('patterns_evs_05s_renew_post',postrenew_animals, '', notebook='patterns_time_bins')
# postrenew_labels_post_05s = load_all_animals_vars('labels_post',postrenew_animals, '', notebook='patterns_time_bins')
# postrenew_labels_renew_05s = load_all_animals_vars('labels_renew',postrenew_animals, '', notebook='patterns_time_bins')
# ext1ext2_patterns_ext1_05s = load_all_animals_vars('patterns_evs_05s_ext1_ext2', ext1ext2_animals, '', notebook='patterns_time_bins')
# ext1ext2_patterns_ext2_05s = load_all_animals_vars('patterns_evs_05s_ext2_ext1', ext1ext2_animals, '', notebook='patterns_time_bins')
# ext1ext2_labels_ext1_05s = load_all_animals_vars('labels_ext1',ext1ext2_animals, '', notebook='patterns_time_bins')
# ext1ext2_labels_ext2_05s = load_all_animals_vars('labels_ext2',ext1ext2_animals, '', notebook='patterns_time_bins')
# ext1renew_patterns_ext1_05s = load_all_animals_vars('patterns_evs_05s_ext1_renew', ext1renew_animals, '', notebook='patterns_time_bins')
# ext1renew_patterns_renew_05s = load_all_animals_vars('patterns_evs_05s_renew_ext1', ext1renew_animals, '', notebook='patterns_time_bins')
# ext1renew_labels_ext1_05s = load_all_animals_vars('labels_ext1',ext1renew_animals, '', notebook='patterns_time_bins')
# ext1renew_labels_renew_05s = load_all_animals_vars('labels_renew',ext1renew_animals, '', notebook='patterns_time_bins')
# ext2renew_patterns_renew_05s = load_all_animals_vars('patterns_evs_05s_renew_ext2',ext2renew_animals, '', notebook='patterns_time_bins')
# ext2renew_patterns_ext2_05s = load_all_animals_vars('patterns_evs_05s_ext2_renew',ext2renew_animals, '', notebook='patterns_time_bins')
# ext2renew_labels_renew_05s = load_all_animals_vars('labels_renew',ext2renew_animals, '', notebook='patterns_time_bins')
# ext2renew_labels_ext2_05s = load_all_animals_vars('labels_ext2',ext2renew_animals, '', notebook='patterns_time_bins')

# %% [markdown]
# delta_t0 = 0.5
# t_start0 = -4.5
# t_stop0 = 10.5
#
# delta_t0 = 1
# t_start0 = -5
# t_stop0 = 11

# %% [markdown]
# cross_sessions = 'prepost','preext1','preext2','prerenew','postext1','postext2','postrenew','ext1ext2','ext1renew','ext2renew'

# %% [markdown]
# all_comparisons = 'prepost_patterns_pre',\
# 'prepost_patterns_post',\
# 'preext1_patterns_pre',\
# 'preext1_patterns_ext1',\
# 'preext2_patterns_pre',\
# 'preext2_patterns_ext2',\
# 'prerenew_patterns_pre',\
# 'prerenew_patterns_renew',\
# 'postext1_patterns_post',\
# 'postext1_patterns_ext1',\
# 'postext2_patterns_post',\
# 'postext2_patterns_ext2',\
# 'postrenew_patterns_post',\
# 'postrenew_patterns_renew',\
# 'ext1ext2_patterns_ext1',\
# 'ext1ext2_patterns_ext2',\
# 'ext1renew_patterns_ext1',\
# 'ext1renew_patterns_renew',\
# 'ext2renew_patterns_renew',\
# 'ext2renew_patterns_ext2'

# %% [markdown]
# #ani_comparisons = 'expopre','expopost','prepost','preext1','preext2','prerenew','postext1','postext2','postrenew','ext1ext2','ext1renew','ext2renew'
# for comp in all_comparisons:
#     for t in range(16):
#         exec("%s_tb_%s = {}"%(comp,t))
#         for ani in eval('%s_animals'%comp.split('_')[0]):
#             try:
#                 print comp.split('_')[0],
#                 print ani,
#                 print t,
#                 exec("%s_tb_%s['%s'] = %s['%s'][%s]"%(comp,t,ani,comp,ani,t))
#             except IOError as error:
#                 print 'ERROR'
#             continue

# %% [markdown]
# #ani_comparisons = 'expopre','expopost','prepost','preext1','preext2','prerenew','postext1','postext2','postrenew','ext1ext2','ext1renew','ext2renew'
# for comp in all_comparisons:
#     for t in range(30):
#         exec("%s_tb_%s_05s = {}"%(comp,t))
#         for ani in eval('%s_animals'%comp.split('_')[0]):
#             try:
#                 print comp.split('_')[0],
#                 print ani,
#                 print t,
#                 exec("%s_tb_%s_05s['%s'] = %s_05s['%s'][%s]"%(comp,t,ani,comp,ani,t))
#             except IOError as error:
#                 print 'ERROR'
#             continue
