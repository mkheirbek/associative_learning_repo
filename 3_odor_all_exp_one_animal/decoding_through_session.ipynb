# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
# all modules necessary for this nb
import os
import sys
import pickle

import numpy as np
import pylab as pl
from scipy import stats as sstats

# setting parameters for default matplotlib plots
# %matplotlib inline

# %%
pl.style.use('fabiostyle')

# needs to find the library of functions
sys.path.append('../../../code/')  # to be replaced!

import utils as ut
import plots as pt

# %%
NOTEBOOK_NAME = 'decoding_through_session'

# %%
from pickleshare import PickleShareDB

autorestore_folder = os.path.join(os.getcwd(), 'autorestore', NOTEBOOK_NAME)
db = PickleShareDB(autorestore_folder)
import sys
from workspace import *
import IPython
ip = IPython.get_ipython()

# this will restore all the saved variables. ignore the errors listed.
load_workspace(ip, db)

# use `save_worspace(db)` to save variables at the end

# %%
vars_pre = {}
folder = '../pre/notebooks/autorestore/decoding_through_session'
for var in ('scores', 'n_train', 'n_test', 'patterns_evs', 'labels'):
    vars_pre.update({var:ut.load_variable(var, folder=folder)})

# %%
vars_post = {}
folder = '../post/notebooks/autorestore/decoding_through_session'
for var in ('scores', 'n_train', 'n_test', 'patterns_evs', 'labels'):
    vars_post.update({var:ut.load_variable(var, folder=folder)})

# %%
vars_ext1 = {}
folder = '../ext1/notebooks/autorestore/decoding_through_session'
for var in ('scores', 'n_train', 'n_test', 'patterns_evs', 'labels'):
    vars_ext1.update({var:ut.load_variable(var, folder=folder)})

# %%
vars_ext2 = {}
folder = '../ext2/notebooks/autorestore/decoding_through_session'
for var in ('scores', 'n_train', 'n_test', 'patterns_evs', 'labels'):
    vars_ext2.update({var:ut.load_variable(var, folder=folder)})

# %%
vars_renew = {}
folder = '../renew/notebooks/autorestore/decoding_through_session'
for var in ('scores', 'n_train', 'n_test', 'patterns_evs', 'labels'):
    vars_renew.update({var:ut.load_variable(var, folder=folder)})

# %%
n_train, n_test, scores, labels = (vars_pre['n_train'], vars_pre['n_test'],
                                   vars_pre['scores'], vars_pre['labels'])
fig, ax = pl.subplots(1, 1, figsize=(2, 1.5))
ax.plot(range(n_train, len(labels)-n_test), scores*100, lw=1)

ax.set_title('Pre')
ax.set_xlabel('Session #')
ax.set_ylabel('Decoding Performance %')
ax.set_ylim(0, 100)
ax.hlines(50, n_train, len(labels)-n_test, linestyles='dashed', color='k', lw=0.5, zorder=0)
ax.set_xlim(0, 120)
# Out:
# (0, 120)

# %%
n_train, n_test, scores, labels = (vars_post['n_train'], vars_post['n_test'],
                                   vars_post['scores'], vars_post['labels'])
fig, ax = pl.subplots(1, 1, figsize=(2, 1.5))
ax.plot(range(n_train, len(labels)-n_test), scores*100, lw=1)

ax.set_title('Post')
ax.set_xlabel('Session #')
ax.set_ylabel('Decoding Performance %')
ax.set_ylim(0, 100)
ax.hlines(50, n_train, len(labels)-n_test, linestyles='dashed', color='k', lw=0.5, zorder=0)
ax.set_xlim(0, 120)
# Out:
# (0, 120)

# %%
n_train, n_test, scores, labels = (vars_ext1['n_train'], vars_ext1['n_test'],
                                   vars_ext1['scores'], vars_ext1['labels'])
fig, ax = pl.subplots(1, 1, figsize=(2, 1.5))
ax.plot(range(n_train, len(labels)-n_test), scores*100, lw=1)

ax.set_title('Ext1')
ax.set_xlabel('Session #')
ax.set_ylabel('Decoding Performance %')
ax.set_ylim(0, 100)
ax.hlines(50, n_train, len(labels)-n_test, linestyles='dashed', color='k', lw=0.5, zorder=0)
ax.set_xlim(0, 120)
# Out:
# (0, 120)

# %%
n_train, n_test, scores, labels = (vars_ext2['n_train'], vars_ext2['n_test'],
                                   vars_ext2['scores'], vars_ext2['labels'])
fig, ax = pl.subplots(1, 1, figsize=(2, 1.5))
ax.plot(range(n_train, len(labels)-n_test), scores*100, lw=1)

ax.set_title('Ext2')
ax.set_xlabel('Session #')
ax.set_ylabel('Decoding Performance %')
ax.set_ylim(0, 100)
ax.hlines(50, n_train, len(labels)-n_test, linestyles='dashed', color='k', lw=0.5, zorder=0)
ax.set_xlim(0, 120)
# Out:
# (0, 120)

# %%
n_train, n_test, scores, labels = (vars_renew['n_train'], vars_renew['n_test'],
                                   vars_renew['scores'], vars_renew['labels'])
fig, ax = pl.subplots(1, 1, figsize=(2, 1.5))
ax.plot(range(n_train, len(labels)-n_test), scores*100, lw=1)

ax.set_title('Renew')
ax.set_xlabel('Session #')
ax.set_ylabel('Decoding Performance %')
ax.set_ylim(0, 100)
ax.hlines(50, n_train, len(labels)-n_test, linestyles='dashed', color='k', lw=0.5, zorder=0)
ax.set_xlim(0, 120)
# Out:
# (0, 120)

# %%
days = ['pre','post','ext1','ext2','renew']

for day in days:
    what = day
    print (eval("vars_%s"%what))['n_test']
# Out:
# 4
# 4
# 4
# 4
# 4

# %%
days = ['pre','post','ext1','ext2','renew']

fig, ax = pl.subplots(len(days), 1, figsize=(3, 8))

count = 0
for day in days:

    what = day
    n_train, n_test, scores, labels = (eval("vars_%s"%what)['n_train'], eval("vars_%s"%what)['n_test'],
                                      eval("vars_%s"%what)['scores'], eval("vars_%s"%what)['labels'])

    ax[count].plot(range(n_train, len(labels)-n_test), scores*100, lw=1)

    #pt.plot_shaded(range(tstart, tstop), np.r_[eval("vars_ts_%s_scores"%what).values()].T*100, ax=ax[count])
    # ax.plot(range(tstart, tstop), scores_m, lw=1, color='k')
    # ax.fill_between(range(tstart, tstop), scores_m-scores_s, scores_m+scores_s, lw=0, alpha=0.3, zorder=0, color='k')
    
                                       
    ax[count].set_title(day)
    ax[count].set_ylabel('Decoding Performance %')
    ax[count].set_ylim(0, 100)
    ax[count].hlines(50, n_train, len(labels)-n_test, linestyles='dashed', color='k', lw=0.5, zorder=0)
    ax[count].set_xlim(0, 120)

    count = count + 1

# %%
save_workspace(db);
# Out:
# Could not store variable 'IPython'. Skipping...
# Could not store variable 'pt'. Skipping...
# Could not store variable 'sstats'. Skipping...
# Could not store variable 'pl'. Skipping...
# Could not store variable 'di'. Skipping...
# Could not store variable 'ut'. Skipping...
# Could not store variable 'pickle'. Skipping...
# Could not store variable 'ip'. Skipping...
# Could not store variable 'np'. Skipping...
# Could not store variable 'sys'. Skipping...
# Could not store variable 'os'. Skipping...
